# %%
import pandas as pd
import numpy as np


from sklearn.model_selection import train_test_split

from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences

# from ktext.preprocess import processor

# %%
# pip install ktext

# %%
df = pd.read_csv("eng_-french.csv")

# %%
df
# Out:
#                                   English words/sentences  \
# 0                                                     Hi.
# 1                                                    Run!
# 2                                                    Run!
# 3                                                    Who?
# 4                                                    Wow!
# ...                                                   ...
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
#                                    French words/sentences
# 0                                                  Salut!
# 1                                                 Cours !
# 2                                                Courez !
# 3                                                   Qui ?
# 4                                              Ça alors !
# ...                                                   ...
# 175616  « L'économie en partant du haut vers le bas, ç...
# 175617  Une empreinte carbone est la somme de pollutio...
# 175618  La mort est une chose qu'on nous décourage sou...
# 175619  Puisqu'il y a de multiples sites web sur chaqu...
# 175620  Si quelqu'un qui ne connaît pas vos antécédent...
#
# [175621 rows x 2 columns]

# %%
df["English words/sentences count"]=df["English words/sentences"].str.split().str.len()

# %%
df["English words/sentences"].str.split().str.len()
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 175616    34
# 175617    34
# 175618    37
# 175619    43
# 175620    44
# Name: English words/sentences, Length: 175621, dtype: int64

# %%
df["French words/sentences count"]=df["French words/sentences"].str.split().str.len()

# %%
df
# Out:
#                                   English words/sentences  \
# 0                                                     Hi.
# 1                                                    Run!
# 2                                                    Run!
# 3                                                    Who?
# 4                                                    Wow!
# ...                                                   ...
# 175616  Top-down economics never works, said Obama. "T...
# 175617  A carbon footprint is the amount of carbon dio...
# 175618  Death is something that we're often discourage...
# 175619  Since there are usually multiple websites on a...
# 175620  If someone who doesn't know your background sa...
#
#                                    French words/sentences  \
# 0                                                  Salut!
# 1                                                 Cours !
# 2                                                Courez !
# 3                                                   Qui ?
# 4                                              Ça alors !
# ...                                                   ...
# 175616  « L'économie en partant du haut vers le bas, ç...
# 175617  Une empreinte carbone est la somme de pollutio...
# 175618  La mort est une chose qu'on nous décourage sou...
# 175619  Puisqu'il y a de multiples sites web sur chaqu...
# 175620  Si quelqu'un qui ne connaît pas vos antécédent...
#
#         English words/sentences count  French words/sentences count
# 0                                   1                             1
# 1                                   1                             2
# 2                                   1                             2
# 3                                   1                             2
# 4                                   1                             3
# ...                               ...                           ...
# 175616                             34                            47
# 175617                             34                            33
# 175618                             37                            47
# 175619                             43                            49
# 175620                             44                            55
#
# [175621 rows x 4 columns]

# %%
df=df[(df["English words/sentences count"]<6) & (df["French words/sentences count"]<6)]

# %%
df
# Out:
#                               English words/sentences  \
# 0                                                 Hi.
# 1                                                Run!
# 2                                                Run!
# 3                                                Who?
# 4                                                Wow!
# ...                                               ...
# 153098    Tom's great-great-grandfather was a pirate.
# 153107    Unfortunately, the information is accurate.
# 154934   They're having a going-out-of-business sale.
# 154962   This theory is scientifically controversial.
# 156500  The administration makes important decisions.
#
#                                    French words/sentences  \
# 0                                                  Salut!
# 1                                                 Cours !
# 2                                                Courez !
# 3                                                   Qui ?
# 4                                              Ça alors !
# ...                                                   ...
# 153098  L'arrière-arrière-grand-père de Tom était pirate.
# 153107         Malheureusement, l'information est exacte.
# 154934                           Ils ont une liquidation.
# 154962   Cette théorie est scientifiquement controversée.
# 156500  L'administration prend des décisions importantes.
#
#         English words/sentences count  French words/sentences count
# 0                                   1                             1
# 1                                   1                             2
# 2                                   1                             2
# 3                                   1                             2
# 4                                   1                             3
# ...                               ...                           ...
# 153098                              5                             5
# 153107                              5                             4
# 154934                              5                             4
# 154962                              5                             5
# 156500                              5                             5
#
# [54212 rows x 4 columns]

# %%
df= df.drop_duplicates()

# %%
df
# Out:
#                               English words/sentences  \
# 0                                                 Hi.
# 1                                                Run!
# 2                                                Run!
# 3                                                Who?
# 4                                                Wow!
# ...                                               ...
# 153098    Tom's great-great-grandfather was a pirate.
# 153107    Unfortunately, the information is accurate.
# 154934   They're having a going-out-of-business sale.
# 154962   This theory is scientifically controversial.
# 156500  The administration makes important decisions.
#
#                                    French words/sentences  \
# 0                                                  Salut!
# 1                                                 Cours !
# 2                                                Courez !
# 3                                                   Qui ?
# 4                                              Ça alors !
# ...                                                   ...
# 153098  L'arrière-arrière-grand-père de Tom était pirate.
# 153107         Malheureusement, l'information est exacte.
# 154934                           Ils ont une liquidation.
# 154962   Cette théorie est scientifiquement controversée.
# 156500  L'administration prend des décisions importantes.
#
#         English words/sentences count  French words/sentences count
# 0                                   1                             1
# 1                                   1                             2
# 2                                   1                             2
# 3                                   1                             2
# 4                                   1                             3
# ...                               ...                           ...
# 153098                              5                             5
# 153107                              5                             4
# 154934                              5                             4
# 154962                              5                             5
# 156500                              5                             5
#
# [54212 rows x 4 columns]

# %% [markdown]
# ## Diving  Data  into Train Test validate:

# %%
from sklearn.model_selection import train_test_split

train,test = train_test_split(df,test_size=0.2)

# %%
train["English words/sentences count"].max()
# Out:
# 5

# %%
train["French words/sentences count"].max()
# Out:
# 5

# %%
train , valid  = train_test_split(train , test_size=0.2)

# %%
print(train.shape)
print(test.shape)
print(valid.shape)
# Out:
# (34695, 4)
# (10843, 4)
# (8674, 4)

# %% [markdown]
# ## Word Frequency

# %%
freq_x = train["English words/sentences"].str.split(expand=True).stack().value_counts().reset_index()
freq_y = train["French words/sentences"].str.split(expand=True).stack().value_counts().reset_index()

# %%
freq_x.to_csv("English_freq.csv",index=False)
freq_y.to_csv("French_freq.csv",index=False)

# %%
freq_x = pd.read_csv("English_freq.csv")
freq_y = pd.read_csv("French_freq.csv")

# %%
freq_x
# Out:
#            index     0
# 0              I  5981
# 1              a  3401
# 2            you  3379
# 3             is  2913
# 4            the  2303
# ...          ...   ...
# 10473   listens.     1
# 10474   jackpot.     1
# 10475    wrench.     1
# 10476  footsteps     1
# 10477      meal!     1
#
# [10478 rows x 2 columns]

# %%
freq_y
# Out:
#              index     0
# 0                ?  5147
# 1               Je  4613
# 2              est  2314
# 3               Il  2295
# 4              pas  2171
# ...            ...   ...
# 16345   fonctionna     1
# 16346    toussota.     1
# 16347  machiniste.     1
# 16348      Compare     1
# 16349      enfuit.     1
#
# [16350 rows x 2 columns]

# %% [markdown]
# ## Data Preparation

# %%
def get_data(raw_line):
    text=[]
    for raw_line in raw_line:
        text.append("<start> " + raw_line + " <end>")
    return text

# %%
english_train = get_data(list(train["English words/sentences"]))
english_train
# Out:
# ['<start> Nothing will stop his going. <end>',
#  "<start> It's right. <end>",
#  '<start> I joined the army. <end>',
#  '<start> I still like Tom. <end>',
#  '<start> The cup has a crack. <end>',
#  '<start> Tom looks great. <end>',
#  '<start> Are you in danger? <end>',
#  '<start> I am afraid of dying. <end>',
#  '<start> They feared you. <end>',
#  '<start> This is the best method. <end>',
#  '<start> They never gave up. <end>',
#  '<start> I thought I was happy. <end>',
#  "<start> I'm not kidding. <end>",
#  '<start> How did you do that? <end>',
#  "<start> I hadn't thought of that. <end>",
#  '<start> Shake my hand. <end>',
#  '<start> There were no consequences. <end>',
#  '<start> What are you waiting for? <end>',
#  '<start> I like to draw pictures. <end>',
#  "<start> They're going to try. <end>",
#  "<start> That's OK. <end>",
#  "<start> We've had a complaint. <end>",
#  '<start> Tie your shoelaces. <end>',
#  '<start> This is sweet. <end>',
#  "<start> You're very courageous. <end>",
#  '<start> I want to confess. <end>',
#  "<start> He's ready to go. <end>",
#  '<start> This is very true. <end>',
#  '<start> Our investigation is ongoing. <end>',
#  '<start> This is for you. <end>',
#  '<start> They look confused. <end>',
#  '<start> Tom disagreed. <end>',
#  '<start> Nobody knew what to do. <end>',
#  "<start> I'm good at Japanese. <end>",
#  '<start> I heard the door open. <end>',
#  '<start> Your answer is wrong. <end>',
#  "<start> We're all at risk. <end>",
#  '<start> Who did you talk to? <end>',
#  "<start> Don't dodge the question. <end>",
#  "<start> There's one condition. <end>",
#  '<start> Who sent you? <end>',
#  '<start> Maybe you were followed. <end>',
#  '<start> Tom is a great sportsman. <end>',
#  '<start> I require your advice. <end>',
#  "<start> I'll tell him that. <end>",
#  '<start> Can I eat this? <end>',
#  '<start> He loses his temper easily. <end>',
#  '<start> What do you really think? <end>',
#  '<start> Where were you born? <end>',
#  "<start> She's hot. <end>",
#  '<start> Everybody liked Tom. <end>',
#  "<start> It's true! <end>",
#  '<start> Jackson seemed to get better. <end>',
#  '<start> Are you fully recovered? <end>',
#  "<start> Let's start the meeting now. <end>",
#  "<start> You won't be fired. <end>",
#  '<start> Would you like that? <end>',
#  "<start> That's a really good point. <end>",
#  '<start> Take good care of yourself. <end>',
#  '<start> You can do this. <end>',
#  '<start> Empty your bags. <end>',
#  '<start> You have a gum infection. <end>',
#  '<start> May I ask a question? <end>',
#  "<start> This isn't a hospital. <end>",
#  '<start> Get the camera. <end>',
#  '<start> Do you have a match? <end>',
#  "<start> It's ours. <end>",
#  "<start> Let's take a look. <end>",
#  '<start> I called you. <end>',
#  '<start> I smoke. <end>',
#  '<start> He jimmied the lock. <end>',
#  '<start> Do not disturb her. <end>',
#  "<start> It isn't a virus. <end>",
#  '<start> They are reading her book. <end>',
#  '<start> Will you dance with me? <end>',
#  '<start> Stop teasing me. <end>',
#  '<start> What a perfect night! <end>',
#  "<start> I didn't get enough sleep. <end>",
#  "<start> I'm afraid of my boss. <end>",
#  '<start> I am reading a magazine. <end>',
#  "<start> We'll go. <end>",
#  '<start> Bring along your friend. <end>',
#  '<start> Tom was convinced. <end>',
#  "<start> Tom doesn't like singing. <end>",
#  "<start> That's my wish. <end>",
#  '<start> I liked your speech. <end>',
#  '<start> He really ticked me off. <end>',
#  "<start> I don't play games. <end>",
#  '<start> The old man sat down. <end>',
#  "<start> They say she's sick. <end>",
#  "<start> It's starting to snow. <end>",
#  "<start> I'm fixing something. <end>",
#  '<start> He was found mysteriously murdered. <end>',
#  "<start> It's already seven. <end>",
#  "<start> I'll go whenever you like. <end>",
#  "<start> Don't ever say her name. <end>",
#  '<start> Now is your chance. <end>',
#  '<start> What else do you have? <end>',
#  '<start> I know the solution. <end>',
#  '<start> I tried to save you. <end>',
#  '<start> All the seats are occupied. <end>',
#  "<start> Let's do it! <end>",
#  "<start> Let's do it this way. <end>",
#  '<start> He speaks quickly. <end>',
#  '<start> What is your name? <end>',
#  '<start> They are great friends. <end>',
#  '<start> It was just a thought. <end>',
#  '<start> Can you speak French? <end>',
#  "<start> I'm afraid to do that. <end>",
#  '<start> I really tried. <end>',
#  "<start> You're drunk. <end>",
#  "<start> I didn't touch anything. <end>",
#  '<start> I buried it. <end>',
#  '<start> Is he still here? <end>',
#  '<start> This is a big project. <end>',
#  "<start> I'm eating a sandwich. <end>",
#  "<start> That's not really true. <end>",
#  '<start> They constructed a bridge. <end>',
#  "<start> You won't be disappointed. <end>",
#  '<start> Am I really that bad? <end>',
#  '<start> I got lucky. <end>',
#  '<start> They make a great team. <end>',
#  '<start> You look Japanese. <end>',
#  "<start> It's for you. <end>",
#  "<start> I've got lots to say. <end>",
#  '<start> I am afraid of death. <end>',
#  '<start> Help me, please. <end>',
#  '<start> Did you win? <end>',
#  '<start> This is my assistant. <end>',
#  '<start> What a foolish suggestion! <end>',
#  '<start> Your guess is wrong. <end>',
#  "<start> Tom didn't scream. <end>",
#  '<start> Please think it over. <end>',
#  "<start> I'm going to live alone. <end>",
#  '<start> Is he dead? <end>',
#  '<start> Hello everyone! <end>',
#  '<start> He said he was poor. <end>',
#  '<start> I ran upstairs. <end>',
#  '<start> They never did an autopsy. <end>',
#  "<start> You're elusive. <end>",
#  "<start> You're very funny. <end>",
#  '<start> We danced until midnight. <end>',
#  '<start> It made me very happy. <end>',
#  "<start> Where's the catch? <end>",
#  '<start> Tom quickly figured it out. <end>',
#  '<start> Tom usually comes on time. <end>',
#  '<start> Somebody laughed. <end>',
#  "<start> You're being watched. <end>",
#  '<start> No one escaped. <end>',
#  "<start> Tom doesn't need it. <end>",
#  '<start> She just left. <end>',
#  '<start> I hate my roommate. <end>',
#  "<start> Don't rub it in. <end>",
#  '<start> Do you know my husband? <end>',
#  '<start> This decision is final. <end>',
#  '<start> He has no choice. <end>',
#  "<start> We'll fail. <end>",
#  '<start> They were afraid of you. <end>',
#  "<start> What's making you uneasy? <end>",
#  "<start> I'll get it. <end>",
#  '<start> Her smile expressed her thanks. <end>',
#  '<start> I ask your forgiveness. <end>',
#  "<start> He's perfect at everything. <end>",
#  '<start> Tom is unfaithful. <end>',
#  '<start> That might be difficult. <end>',
#  '<start> The house was empty. <end>',
#  "<start> We're so sorry. <end>",
#  '<start> What is your profession? <end>',
#  '<start> Slow down. <end>',
#  '<start> We won. <end>',
#  "<start> I'm out of ideas. <end>",
#  "<start> It's genuine. <end>",
#  '<start> Seriously? <end>',
#  '<start> Move away from me. <end>',
#  "<start> You're reading my mind. <end>",
#  '<start> He crossed the street. <end>',
#  '<start> Did it snow last night? <end>',
#  '<start> May I borrow this book? <end>',
#  '<start> We have a dishwasher. <end>',
#  '<start> This is so relaxing. <end>',
#  '<start> I was very jealous. <end>',
#  "<start> This cat is Tom's. <end>",
#  "<start> It'll probably rain. <end>",
#  "<start> You're so predictable. <end>",
#  '<start> How much did I lose? <end>',
#  "<start> The water's cold. <end>",
#  "<start> You're very clever. <end>",
#  '<start> Are you a good swimmer? <end>',
#  "<start> Let's get cracking! <end>",
#  '<start> Why were you absent yesterday? <end>',
#  '<start> I love trips. <end>',
#  '<start> You must pay in advance. <end>',
#  '<start> Doing that will be difficult. <end>',
#  '<start> Is it raining? <end>',
#  '<start> He broke his word. <end>',
#  '<start> I feel kind of tired. <end>',
#  '<start> Help yourself. <end>',
#  '<start> She is currently in danger. <end>',
#  '<start> I like to play poker. <end>',
#  '<start> Tom turned down the heat. <end>',
#  "<start> I'll buy a Ford. <end>",
#  "<start> Don't light the candle. <end>",
#  '<start> Go with Tom. <end>',
#  "<start> It's driving me crazy. <end>",
#  "<start> That's just false. <end>",
#  '<start> I really have no idea. <end>',
#  '<start> Pardon me for saying so. <end>',
#  '<start> She wore glasses. <end>',
#  "<start> You're very talented. <end>",
#  '<start> Russia is big. <end>',
#  '<start> This is my sister. <end>',
#  '<start> Give me back my hat. <end>',
#  '<start> Well? Will you come? <end>',
#  '<start> Are you a cop? <end>',
#  '<start> He took off his hat. <end>',
#  "<start> Everything's all right now. <end>",
#  '<start> He agreed with me. <end>',
#  '<start> I have no idea. <end>',
#  '<start> I need a new bicycle. <end>',
#  '<start> We are here. <end>',
#  '<start> She seems to be happy. <end>',
#  '<start> Tom likes to play football. <end>',
#  '<start> I like good coffee. <end>',
#  "<start> It's secret. <end>",
#  '<start> I did you a favor. <end>',
#  '<start> No one followed me. <end>',
#  '<start> My time is very expensive. <end>',
#  '<start> Nobody spoke with me. <end>',
#  '<start> Have you got a match? <end>',
#  '<start> Three were wounded. <end>',
#  '<start> It was a forced smile. <end>',
#  '<start> I am a teacher, too. <end>',
#  '<start> I heard the question. <end>',
#  '<start> Take whichever you like. <end>',
#  '<start> We have to start somewhere. <end>',
#  '<start> You can do it. <end>',
#  "<start> It'll be hot. <end>",
#  '<start> I seldom hear from him. <end>',
#  '<start> I love your outfit. <end>',
#  '<start> His book is very interesting. <end>',
#  '<start> The budget must be balanced. <end>',
#  "<start> I'm acquainted with Tom. <end>",
#  '<start> I eat fruit. <end>',
#  "<start> This work doesn't pay. <end>",
#  '<start> This is all very confusing. <end>',
#  '<start> We have enough time. <end>',
#  '<start> Everyone escaped. <end>',
#  "<start> We'll find it. <end>",
#  "<start> We're from here. <end>",
#  '<start> Call the cops. <end>',
#  '<start> The company accepted his application. <end>',
#  '<start> Get on a horse. <end>',
#  '<start> I have a secret. <end>',
#  '<start> I need to do that. <end>',
#  '<start> I want to be pampered. <end>',
#  '<start> Are you having fun? <end>',
#  '<start> This reminds me of home. <end>',
#  "<start> I'm happy enough. <end>",
#  '<start> Now is your chance. <end>',
#  '<start> I can survive. <end>',
#  '<start> He gets up early. <end>',
#  '<start> He rejected our offer. <end>',
#  '<start> The dog followed me. <end>',
#  '<start> I saw the pictures. <end>',
#  '<start> A horse runs quickly. <end>',
#  "<start> I'm looking for my cellphone. <end>",
#  '<start> Spring is coming. <end>',
#  '<start> We are brothers. <end>',
#  '<start> Tom is a staunch conservative. <end>',
#  '<start> He kept his promise. <end>',
#  '<start> This room is cramped. <end>',
#  "<start> I'm game. <end>",
#  "<start> I heard that he'd died. <end>",
#  "<start> That's fantastic. <end>",
#  '<start> This is big. <end>',
#  "<start> I don't like your friends. <end>",
#  '<start> The baby was sound asleep. <end>',
#  '<start> He got bored quickly. <end>',
#  '<start> Look down at the floor. <end>',
#  "<start> I've decided to study kanji. <end>",
#  '<start> Did you complete the work? <end>',
#  "<start> Let's take a picture here. <end>",
#  '<start> I wanted to surprise Tom. <end>',
#  "<start> Tom isn't a lawyer yet. <end>",
#  "<start> I don't have a knife. <end>",
#  '<start> Look under the seat. <end>',
#  '<start> You seem busy. <end>',
#  '<start> He soon walked away. <end>',
#  '<start> Let me finish. <end>',
#  '<start> That soon changed. <end>',
#  '<start> Are you ready for Christmas? <end>',
#  "<start> He's a very nice boy. <end>",
#  '<start> He does not like us. <end>',
#  '<start> This is preposterous. <end>',
#  "<start> We'll stay here. <end>",
#  '<start> The price includes tax. <end>',
#  "<start> They won't make it. <end>",
#  '<start> I live here. <end>',
#  '<start> Are we leaving? <end>',
#  '<start> Why are you interested? <end>',
#  '<start> Where are our friends? <end>',
#  '<start> He fell asleep right away. <end>',
#  '<start> He was intrigued. <end>',
#  "<start> It's really impressive. <end>",
#  '<start> Did you recognize Tom? <end>',
#  '<start> The reception was warm. <end>',
#  '<start> He sells fruit. <end>',
#  '<start> That was our first encounter. <end>',
#  "<start> We haven't seen anyone. <end>",
#  '<start> I no longer study French. <end>',
#  '<start> I daydreamed all day. <end>',
#  '<start> Exercise outdoors. <end>',
#  '<start> Does that amuse you? <end>',
#  '<start> This is an active volcano. <end>',
#  '<start> There are seven of us. <end>',
#  '<start> I forgot my email address. <end>',
#  '<start> Tom is multilingual. <end>',
#  '<start> Do you hear me? <end>',
#  "<start> That hasn't happened yet. <end>",
#  '<start> Get your hands off me. <end>',
#  '<start> She took up his offer. <end>',
#  '<start> Do you have them? <end>',
#  '<start> Admission was free. <end>',
#  "<start> I'm a management consultant. <end>",
#  "<start> You're biased. <end>",
#  '<start> May I put it here? <end>',
#  '<start> He listened to my opinion. <end>',
#  '<start> He flew to Paris. <end>',
#  "<start> That's the one. <end>",
#  '<start> Are you dyslexic? <end>',
#  '<start> Are you all right? <end>',
#  '<start> I felt scared. <end>',
#  "<start> She's my classmate. <end>",
#  '<start> He handles horses well. <end>',
#  '<start> Are you afraid of it? <end>',
#  '<start> That was everything I had. <end>',
#  "<start> I'll take you to Tom. <end>",
#  '<start> I never saw her again. <end>',
#  '<start> I had a similar experience. <end>',
#  "<start> Let's move the sofa. <end>",
#  '<start> His students adored him. <end>',
#  '<start> You really are hopeless. <end>',
#  "<start> Your socks don't match. <end>",
#  '<start> I lost three kilograms. <end>',
#  '<start> Turn the lights out now. <end>',
#  "<start> He doesn't understand you. <end>",
#  '<start> You look perfect. <end>',
#  '<start> What should I write here? <end>',
#  '<start> Close your books. <end>',
#  "<start> I'll come right now. <end>",
#  "<start> Of course, you're correct. <end>",
#  "<start> You're pretty. <end>",
#  '<start> I thought I heard you. <end>',
#  '<start> I never do any exercise. <end>',
#  '<start> Here we are. <end>',
#  '<start> Is anyone looking? <end>',
#  '<start> I fell for it. <end>',
#  '<start> We learned French. <end>',
#  "<start> Do as you're told. <end>",
#  "<start> You don't seem convinced. <end>",
#  '<start> Your cat will survive. <end>',
#  '<start> It amazed me. <end>',
#  '<start> I feel bad today. <end>',
#  '<start> They really hate each other. <end>',
#  "<start> What's the big rush? <end>",
#  "<start> That's a great poem. <end>",
#  "<start> Where's your school? <end>",
#  '<start> I was just joking. <end>',
#  '<start> She might know the answer. <end>',
#  '<start> Are you a Buddhist? <end>',
#  '<start> Several plans were proposed. <end>',
#  '<start> Your mother is very young. <end>',
#  '<start> He demands immediate payment. <end>',
#  "<start> We're different. <end>",
#  "<start> Here's my phone number. <end>",
#  '<start> Will you wait for me? <end>',
#  '<start> I understand your reasons. <end>',
#  '<start> Find somebody else. <end>',
#  '<start> Did you ask the price? <end>',
#  '<start> I have lost the key. <end>',
#  "<start> I don't owe you anything. <end>",
#  '<start> This is a surprise. <end>',
#  "<start> I'm a farmer. <end>",
#  '<start> Take whichever you want. <end>',
#  "<start> I've got time. <end>",
#  '<start> Are you expecting Tom? <end>',
#  "<start> This question isn't easy. <end>",
#  "<start> I've learned so much here. <end>",
#  '<start> It is almost three. <end>',
#  '<start> I was momentarily blinded. <end>',
#  "<start> Here's one for you. <end>",
#  "<start> You're very wise. <end>",
#  '<start> Tom is in the park. <end>',
#  '<start> Put yourself in my position. <end>',
#  '<start> Do it somewhere else. <end>',
#  "<start> They aren't alone. <end>",
#  "<start> It's not just a game. <end>",
#  '<start> Read as much as possible. <end>',
#  '<start> I made a lucky guess. <end>',
#  '<start> The ocean was calm. <end>',
#  '<start> Natto is sticky. <end>',
#  '<start> We all work too hard. <end>',
#  '<start> I feel like seeing you. <end>',
#  '<start> You did this. <end>',
#  "<start> You're young and strong. <end>",
#  '<start> Why is this so hard? <end>',
#  '<start> Did I wake you up? <end>',
#  "<start> Let's go downtown. <end>",
#  '<start> No one believed you. <end>',
#  "<start> Let's eat before we go. <end>",
#  '<start> I have a fish tank. <end>',
#  '<start> What exactly did you do? <end>',
#  '<start> Open the windows. <end>',
#  '<start> Could you leave us alone? <end>',
#  '<start> Are they really friends? <end>',
#  '<start> Do you like baseball? <end>',
#  '<start> Your fries are getting cold. <end>',
#  '<start> You need a hobby. <end>',
#  "<start> Why doesn't anybody help you? <end>",
#  '<start> Can you see the picture? <end>',
#  "<start> I'll try to contact Tom. <end>",
#  "<start> I'm only joking. <end>",
#  '<start> He unbuckled his belt. <end>',
#  '<start> The prisoners were set free. <end>',
#  "<start> I'll spare you the details. <end>",
#  '<start> It is threatening to rain. <end>',
#  '<start> I did some checking. <end>',
#  "<start> Don't bite your nails. <end>",
#  '<start> He is willing enough. <end>',
#  '<start> Why were you absent yesterday? <end>',
#  '<start> Be careful, Tom! <end>',
#  '<start> His name sounds familiar. <end>',
#  '<start> Everybody knows that. <end>',
#  "<start> Nothing's been changed. <end>",
#  '<start> It went viral. <end>',
#  '<start> He and I are teachers. <end>',
#  '<start> Translate this text. <end>',
#  '<start> Tom does good work. <end>',
#  "<start> You look like you're busy. <end>",
#  '<start> I believe in God. <end>',
#  '<start> This is typical. <end>',
#  '<start> What have you done? <end>',
#  '<start> Can you see? <end>',
#  '<start> You cannot be serious. <end>',
#  '<start> Do I make myself clear? <end>',
#  "<start> I'll leave Tom alone. <end>",
#  '<start> We are under his command. <end>',
#  '<start> I postponed the event. <end>',
#  "<start> We'll keep in touch. <end>",
#  '<start> You have my attention already. <end>',
#  "<start> You're talented. <end>",
#  "<start> I'm going to make everything. <end>",
#  '<start> I love hiking. <end>',
#  "<start> He's my partner. <end>",
#  '<start> Write an essay on "Friendship". <end>',
#  '<start> You are strong. <end>',
#  "<start> I'm convinced. <end>",
#  "<start> It's all gone. <end>",
#  '<start> I felt guilty. <end>',
#  '<start> Do you know my name? <end>',
#  '<start> Is Tom from Boston? <end>',
#  '<start> Be merciful. <end>',
#  '<start> Do you play any sports? <end>',
#  "<start> Let's talk seriously. <end>",
#  '<start> They were all hysterical. <end>',
#  "<start> It's sort of strange. <end>",
#  '<start> Tom is eating potato chips. <end>',
#  "<start> I'm cold. <end>",
#  "<start> That's not very original. <end>",
#  '<start> The leaves fell. <end>',
#  '<start> Look at that dog. <end>',
#  '<start> They had an argument. <end>',
#  '<start> It was locked. <end>',
#  '<start> Potentially, that could happen again. <end>',
#  '<start> This was a great idea. <end>',
#  "<start> It's a cautionary tale. <end>",
#  '<start> She has a book. <end>',
#  "<start> You're going to die. <end>",
#  '<start> I still care. <end>',
#  '<start> The teachers greeted the children. <end>',
#  '<start> Your room is ready now. <end>',
#  "<start> I'm not sure about that. <end>",
#  '<start> Try to understand this. <end>',
#  '<start> Tom took a cold shower. <end>',
#  '<start> Do you have a shoehorn? <end>',
#  '<start> He went skiing. <end>',
#  "<start> She's hot. <end>",
#  '<start> He turned Christian. <end>',
#  '<start> He heard a noise. <end>',
#  '<start> Why are you so secretive? <end>',
#  '<start> Drop it! <end>',
#  '<start> Is that your room? <end>',
#  '<start> We were bored. <end>',
#  '<start> When do you use it? <end>',
#  '<start> You can fix all this. <end>',
#  "<start> It's a rumor. <end>",
#  '<start> Be careful! <end>',
#  '<start> I feel blue. <end>',
#  '<start> Nobody can stop me! <end>',
#  '<start> It tastes very good. <end>',
#  "<start> Aren't you hot? <end>",
#  '<start> I read his book. <end>',
#  "<start> That's a nice story. <end>",
#  "<start> Aren't you embarrassed? <end>",
#  '<start> Have you got a match? <end>',
#  '<start> We appreciate your help. <end>',
#  '<start> He burned himself badly. <end>',
#  "<start> You won't catch anything. <end>",
#  '<start> Get a doctor. <end>',
#  '<start> Everything went black. <end>',
#  '<start> Just sign here. <end>',
#  '<start> Close the window, will you? <end>',
#  "<start> It's cooler here. <end>",
#  '<start> Are you losing weight? <end>',
#  '<start> Find yourself a seat. <end>',
#  '<start> Why are you blaming us? <end>',
#  "<start> He's a sweet guy. <end>",
#  '<start> My idea is better. <end>',
#  '<start> Tom likes cheeseburgers. <end>',
#  '<start> I cut classes. <end>',
#  "<start> I'm going back. <end>",
#  "<start> Don't pick it up. <end>",
#  "<start> We're all done. <end>",
#  "<start> You're the teacher. <end>",
#  "<start> He's a smooth talker. <end>",
#  '<start> We all laughed. <end>',
#  '<start> Everything was happening so fast. <end>',
#  "<start> This'll be different. <end>",
#  '<start> The water is clean. <end>',
#  '<start> They unwrapped their sandwiches. <end>',
#  '<start> Please write with a pen. <end>',
#  '<start> They did not listen. <end>',
#  '<start> The law is the law. <end>',
#  '<start> Have you finished it? <end>',
#  '<start> I tried. <end>',
#  '<start> I was very careful. <end>',
#  '<start> Call me back. <end>',
#  '<start> That is a boat. <end>',
#  "<start> I'm loyal. <end>",
#  '<start> We live near the school. <end>',
#  "<start> I'm not going to die. <end>",
#  '<start> Quit complaining. <end>',
#  '<start> Your daughter is very pretty. <end>',
#  '<start> It is to be expected. <end>',
#  '<start> Many people do this. <end>',
#  '<start> You look terrific. <end>',
#  '<start> Thanks for the invitation, Tom. <end>',
#  '<start> I have no food. <end>',
#  '<start> I made you a surprise. <end>',
#  '<start> Listen, all of you. <end>',
#  '<start> I see. <end>',
#  '<start> Meet me there at midnight. <end>',
#  '<start> Just relax. <end>',
#  "<start> I've been all over. <end>",
#  "<start> You're incorrigible. <end>",
#  '<start> You ruined my life. <end>',
#  '<start> Are you having fun? <end>',
#  '<start> Sadly, many Japanese people died. <end>',
#  '<start> Are you all set? <end>',
#  "<start> Don't leave me. <end>",
#  '<start> Tom is OK. <end>',
#  "<start> We're better than they are. <end>",
#  '<start> I recognized the name. <end>',
#  '<start> Are you busy tomorrow morning? <end>',
#  "<start> I've changed clothes. <end>",
#  '<start> Watch your speed. <end>',
#  '<start> Please come this way. <end>',
#  '<start> I need some paper. <end>',
#  "<start> Don't make me suffer. <end>",
#  '<start> Have a nice trip. <end>',
#  '<start> Everything is OK. <end>',
#  '<start> We all knew it. <end>',
#  '<start> They study in the afternoon. <end>',
#  "<start> It's night. <end>",
#  '<start> You may enter now. <end>',
#  '<start> Nobody can hear you. <end>',
#  '<start> You are so childish sometimes. <end>',
#  "<start> I'll set you free. <end>",
#  '<start> Please throw this away. <end>',
#  '<start> Your tire is flat. <end>',
#  "<start> Where's the kitchen? <end>",
#  '<start> He was perfect. <end>',
#  '<start> Lock the safe. <end>',
#  '<start> I drank a lot. <end>',
#  '<start> Tom was quiet all day. <end>',
#  "<start> Don't come here. <end>",
#  '<start> He will also go. <end>',
#  '<start> What month is this? <end>',
#  '<start> The car is very fast. <end>',
#  '<start> Sing a song with me. <end>',
#  '<start> Tom walked in. <end>',
#  "<start> What's inside? <end>",
#  '<start> What did you drink? <end>',
#  '<start> I read your report. <end>',
#  '<start> I fell in love. <end>',
#  "<start> We're proud of that. <end>",
#  '<start> Tom should learn French. <end>',
#  '<start> When did you start? <end>',
#  "<start> You've often said so yourself. <end>",
#  '<start> I do appreciate that. <end>',
#  '<start> We looked ridiculous. <end>',
#  "<start> We've got enough space here. <end>",
#  "<start> There's no doubt. <end>",
#  "<start> You've suffered enough. <end>",
#  '<start> His wife is French. <end>',
#  '<start> I have a new car. <end>',
#  '<start> Tom gave me this watch. <end>',
#  '<start> I feel honored. <end>',
#  "<start> I can't help myself. <end>",
#  '<start> It is a luxury cruise. <end>',
#  '<start> They must really hate me. <end>',
#  '<start> He removed his shirt. <end>',
#  '<start> Tom is a moron. <end>',
#  '<start> Are you unlucky? <end>',
#  '<start> They work for me. <end>',
#  '<start> I was extremely angry. <end>',
#  "<start> I'm still here. <end>",
#  '<start> Tom tried to leave. <end>',
#  '<start> Have you seen my purse? <end>',
#  '<start> He was naive. <end>',
#  '<start> She decided to marry him. <end>',
#  '<start> I have a private teacher. <end>',
#  '<start> Ask me again in October. <end>',
#  '<start> I hope Tom is objective. <end>',
#  '<start> Leaves are falling. <end>',
#  '<start> Tom has lost his wallet. <end>',
#  "<start> Tom's different. <end>",
#  '<start> You three are very lucky. <end>',
#  '<start> Do you like waffles? <end>',
#  "<start> Everybody's dead. <end>",
#  '<start> Close the door, please. <end>',
#  '<start> I want a donut. <end>',
#  '<start> You look like a kid. <end>',
#  '<start> Who said that? <end>',
#  '<start> That really made sense. <end>',
#  '<start> I have a grenade. <end>',
#  "<start> Isn't this wonderful? <end>",
#  '<start> Are there kids? <end>',
#  '<start> I have no excuse. <end>',
#  '<start> His clothes are worn out. <end>',
#  '<start> My cat is black. <end>',
#  '<start> Be creative. <end>',
#  "<start> That's my money. <end>",
#  '<start> Tom wants to know why. <end>',
#  '<start> How big you are! <end>',
#  '<start> I listen to jazz sometimes. <end>',
#  '<start> Should we wait? <end>',
#  "<start> You're kidding! <end>",
#  "<start> It's one of those moments. <end>",
#  '<start> Give me my glasses. <end>',
#  '<start> Changes came quickly. <end>',
#  '<start> The day started very well. <end>',
#  '<start> Tom pays his taxes. <end>',
#  '<start> That noise woke me up. <end>',
#  "<start> Today is Valentine's Day. <end>",
#  "<start> You're resourceful. <end>",
#  "<start> What's this street called? <end>",
#  "<start> Do you think that's true? <end>",
#  "<start> It's my job. <end>",
#  '<start> You can use mine. <end>',
#  '<start> We got separated. <end>',
#  '<start> This tea is very hot. <end>',
#  '<start> I paid the bill. <end>',
#  "<start> How's your mother? <end>",
#  '<start> Please leave right away. <end>',
#  "<start> Aren't you convinced? <end>",
#  "<start> It's really awesome. <end>",
#  '<start> Now eat your supper. <end>',
#  '<start> I am eighteen years old. <end>',
#  "<start> He doesn't like fish. <end>",
#  '<start> Watch carefully. <end>',
#  '<start> You have a big nose. <end>',
#  '<start> I like to dream. <end>',
#  '<start> He came by bus. <end>',
#  '<start> No one died. <end>',
#  "<start> It's important. <end>",
#  "<start> You're very timid. <end>",
#  '<start> That helps a lot. <end>',
#  '<start> Tell us a joke. <end>',
#  '<start> Tom lives in Boston. <end>',
#  '<start> Have a nice time. <end>',
#  '<start> These gifts are for you. <end>',
#  '<start> She took a deep breath. <end>',
#  '<start> What are you saying? <end>',
#  '<start> I pay my own way. <end>',
#  '<start> He was disappointed. <end>',
#  '<start> Be cool. <end>',
#  '<start> We lost sight of him. <end>',
#  '<start> This is not funny. <end>',
#  '<start> You have to be prepared. <end>',
#  '<start> Take one of these. <end>',
#  '<start> I think they know us. <end>',
#  "<start> Let's go to the hospital. <end>",
#  '<start> Are you ready to leave? <end>',
#  '<start> Those are all important. <end>',
#  '<start> Keep writing. <end>',
#  '<start> He was very nervous. <end>',
#  '<start> He slept an hour. <end>',
#  "<start> You're the master. <end>",
#  "<start> I'm involved. <end>",
#  "<start> We could've done better. <end>",
#  '<start> Why would anybody come here? <end>',
#  "<start> You won't believe it. <end>",
#  "<start> I'm stubborn. <end>",
#  '<start> The idea was good. <end>',
#  '<start> I beg you. <end>',
#  '<start> You might meet him. <end>',
#  '<start> Can you come with me? <end>',
#  '<start> He came by car. <end>',
#  '<start> My neighbor is nice. <end>',
#  '<start> I am talking with Tom. <end>',
#  '<start> Tom gave me thirty dollars. <end>',
#  '<start> Are you always that busy? <end>',
#  '<start> Help me! <end>',
#  '<start> We all work too hard. <end>',
#  '<start> I need to sleep. <end>',
#  '<start> Take care! <end>',
#  '<start> Sorry, something went wrong. <end>',
#  "<start> The radio doesn't work. <end>",
#  '<start> The house is on fire! <end>',
#  '<start> Try to enjoy yourselves. <end>',
#  '<start> I built it. <end>',
#  '<start> Your feet are dirty. <end>',
#  "<start> You're so impatient. <end>",
#  '<start> Do you drink beer? <end>',
#  "<start> She doesn't get outdoors much. <end>",
#  '<start> Write me. <end>',
#  '<start> Do you feel sick? <end>',
#  '<start> What are you doing today? <end>',
#  "<start> They've suffered enough. <end>",
#  '<start> They all speak French. <end>',
#  '<start> Stay with us. <end>',
#  "<start> You're biased. <end>",
#  '<start> I was horrified. <end>',
#  '<start> Why did you do it? <end>',
#  '<start> Would that make you happy? <end>',
#  "<start> It's so bad, it's hilarious. <end>",
#  "<start> It's a big concern. <end>",
#  "<start> You're foolish. <end>",
#  '<start> Look behind you. <end>',
#  '<start> Let me put something on. <end>',
#  '<start> I plan on being early. <end>',
#  '<start> The tide is coming in. <end>',
#  "<start> I hope that they're OK. <end>",
#  "<start> I wasn't able to escape. <end>",
#  '<start> The room is dark. <end>',
#  '<start> It is rather warm today. <end>',
#  '<start> I need 30 minutes. <end>',
#  '<start> Lock your doors. <end>',
#  '<start> This is offensive. <end>',
#  '<start> Do you speak French? <end>',
#  '<start> Something has to be done. <end>',
#  '<start> I usually eat outside. <end>',
#  "<start> That's bad news. <end>",
#  '<start> I have a Canadian neighbor. <end>',
#  "<start> You're so impatient. <end>",
#  '<start> You look terrific. <end>',
#  '<start> Do you like tennis? <end>',
#  "<start> Let's order a pizza. <end>",
#  "<start> I'll be there right away. <end>",
#  "<start> It's not supposed to happen. <end>",
#  '<start> I admit I was surprised. <end>',
#  "<start> You're satisfied. <end>",
#  "<start> Nothing's going to happen. <end>",
#  "<start> You're very astute. <end>",
#  '<start> We went on foot. <end>',
#  '<start> Go to the store. <end>',
#  '<start> Clearly you are mistaken. <end>',
#  '<start> Are you listening to me? <end>',
#  '<start> Look out for pickpockets. <end>',
#  '<start> The ground is still wet. <end>',
#  '<start> This is ludicrous. <end>',
#  '<start> Everyone smiled. <end>',
#  '<start> Get on the bus. <end>',
#  '<start> The old man sat down. <end>',
#  '<start> He is my close friend. <end>',
#  '<start> You may open the window. <end>',
#  "<start> Everyone's fine. <end>",
#  '<start> I feel like singing. <end>',
#  "<start> I've already explained that. <end>",
#  "<start> Don't be upset. <end>",
#  '<start> I need paint. <end>',
#  "<start> I don't have any evidence. <end>",
#  '<start> Is this seat taken? <end>',
#  '<start> Dublin is in Ireland. <end>',
#  "<start> You're very observant. <end>",
#  '<start> I miss my cat. <end>',
#  '<start> I am engaged to her. <end>',
#  "<start> They don't despise you. <end>",
#  '<start> We must wait. <end>',
#  "<start> We're trying to work. <end>",
#  '<start> I have hay fever. <end>',
#  '<start> I broke up with him. <end>',
#  '<start> We ran out of gas. <end>',
#  '<start> Why did we say that? <end>',
#  '<start> The light bulb burst. <end>',
#  "<start> You'll get over this. <end>",
#  '<start> He tricked me. <end>',
#  "<start> Tom hasn't eaten anything yet. <end>",
#  '<start> Go to bed. <end>',
#  '<start> This button is loose. <end>',
#  "<start> Don't answer that. <end>",
#  "<start> I'm still kind of hungry. <end>",
#  "<start> Isn't that ours? <end>",
#  '<start> How should I know? <end>',
#  "<start> He's henpecked. <end>",
#  '<start> He denied having done it. <end>',
#  "<start> They'll take care of you. <end>",
#  '<start> You have visitors. <end>',
#  '<start> I promised to do that. <end>',
#  '<start> You were clearly mistaken. <end>',
#  "<start> I believe that's it. <end>",
#  "<start> I'm not hungry anymore. <end>",
#  '<start> I should move to Boston. <end>',
#  '<start> Tom punched Mary. <end>',
#  '<start> I shut the window. <end>',
#  "<start> We've been busy. <end>",
#  '<start> I lost my watch yesterday. <end>',
#  '<start> I can comfort her. <end>',
#  '<start> What is your destination? <end>',
#  '<start> Are you guys armed? <end>',
#  '<start> I said come alone. <end>',
#  '<start> I understand the problem. <end>',
#  '<start> Tom often manipulates people. <end>',
#  "<start> Everything's going to be fine. <end>",
#  '<start> I looked for the key. <end>',
#  "<start> The money's on the table. <end>",
#  "<start> We're busy. <end>",
#  "<start> I'm a light sleeper. <end>",
#  "<start> They're animals. <end>",
#  "<start> That's a very good question. <end>",
#  '<start> He should have come. <end>',
#  '<start> I sell cars. <end>',
#  "<start> It's already eleven. <end>",
#  '<start> I still make mistakes. <end>',
#  '<start> A revolt broke out. <end>',
#  "<start> You're not a teenager yet. <end>",
#  '<start> You must stop him. <end>',
#  "<start> What's worrying you? <end>",
#  '<start> That was a close one. <end>',
#  "<start> That's terrible. <end>",
#  '<start> You stay here. <end>',
#  '<start> Please allow me to go. <end>',
#  "<start> You're not dressed. <end>",
#  '<start> I am off today. <end>',
#  '<start> Have you been mistreated? <end>',
#  '<start> We exchanged greetings. <end>',
#  '<start> I was sorry. <end>',
#  "<start> It's not very easy. <end>",
#  "<start> Tom doesn't like any sport. <end>",
#  '<start> I was just teasing. <end>',
#  "<start> She's pregnant. <end>",
#  '<start> The heat is overwhelming. <end>',
#  "<start> You're all fired. <end>",
#  "<start> Don't wait too long. <end>",
#  '<start> He lives in Osaka. <end>',
#  "<start> It wasn't mine. <end>",
#  '<start> I know your type. <end>',
#  "<start> I'm trying to be happy. <end>",
#  "<start> I've remarried. <end>",
#  "<start> That's a lot of food. <end>",
#  "<start> They didn't see anything. <end>",
#  "<start> He's their only child. <end>",
#  '<start> I made a deal. <end>',
#  "<start> We'll give it back. <end>",
#  '<start> This looks kind of cute. <end>',
#  '<start> They all did it. <end>',
#  '<start> Iceland belonged to Denmark. <end>',
#  '<start> Please keep me informed. <end>',
#  '<start> This room is empty. <end>',
#  "<start> She didn't like him. <end>",
#  '<start> I love playing Chopin. <end>',
#  "<start> Tom's stoned. <end>",
#  '<start> This bucket leaks. <end>',
#  '<start> Well done! <end>',
#  '<start> I have information. <end>',
#  "<start> I didn't see it. <end>",
#  '<start> You have overstepped your authority. <end>',
#  '<start> Are you vegetarian? <end>',
#  '<start> We need to stop. <end>',
#  '<start> Look here. <end>',
#  "<start> Aren't you tired? <end>",
#  '<start> Put some clothes on. <end>',
#  '<start> She did come here. <end>',
#  '<start> I almost died. <end>',
#  "<start> I've come to accept this. <end>",
#  '<start> That seems clear. <end>',
#  '<start> Be watchful. <end>',
#  '<start> I appreciate the hospitality. <end>',
#  "<start> It's better than the movie. <end>",
#  '<start> That boy is running. <end>',
#  "<start> It's still my birthday. <end>",
#  '<start> She is the editor-in-chief. <end>',
#  '<start> I got upset. <end>',
#  '<start> Tom talked about Boston. <end>',
#  "<start> You're very sophisticated. <end>",
#  '<start> We found something. <end>',
#  '<start> I can help you. <end>',
#  '<start> I wanted to see you. <end>',
#  '<start> You should have told him. <end>',
#  '<start> Please hurry. <end>',
#  '<start> Have you seen this man? <end>',
#  '<start> This chair is too small. <end>',
#  '<start> Tom is a man. <end>',
#  '<start> I really appreciate the offer. <end>',
#  '<start> They love each other deeply. <end>',
#  '<start> The door was unlocked. <end>',
#  '<start> We have a witness. <end>',
#  "<start> I'd like to stand. <end>",
#  '<start> You looked exhausted. <end>',
#  '<start> All but one were present. <end>',
#  '<start> The threat is real. <end>',
#  '<start> You drive. <end>',
#  '<start> Your plan seems excellent. <end>',
#  '<start> Pickpockets target tourists. <end>',
#  '<start> I burned the cake. <end>',
#  "<start> They could've killed you. <end>",
#  '<start> Did you finish your paper? <end>',
#  '<start> I went there today. <end>',
#  '<start> Tom knows that. <end>',
#  "<start> You can't go out. <end>",
#  '<start> They followed you here. <end>',
#  "<start> It's Saturday. <end>",
#  '<start> My father is a doctor. <end>',
#  '<start> Anybody hurt? <end>',
#  '<start> You should eat. <end>',
#  '<start> Why are you sitting there? <end>',
#  '<start> Tom is very straightforward. <end>',
#  '<start> I continue to be optimistic. <end>',
#  "<start> I'm aware of that. <end>",
#  '<start> Did you foresee this? <end>',
#  '<start> Sing me a song. <end>',
#  "<start> I didn't know this. <end>",
#  '<start> I know where he lives. <end>',
#  '<start> Wait until you see this. <end>',
#  '<start> How did you reply? <end>',
#  '<start> Tom is still very unhappy. <end>',
#  "<start> I've lost my briefcase. <end>",
#  '<start> It was all planned. <end>',
#  '<start> He is my classmate. <end>',
#  "<start> You're tired. <end>",
#  '<start> Look at that tall building. <end>',
#  '<start> She hit him. <end>',
#  '<start> The lights are on. <end>',
#  '<start> I sometimes drive too fast. <end>',
#  '<start> This movie is really scary. <end>',
#  '<start> I like to play basketball. <end>',
#  '<start> The door was locked. <end>',
#  "<start> What don't you have? <end>",
#  '<start> He dropped it. <end>',
#  '<start> Do I need to transfer? <end>',
#  "<start> I'm extroverted. <end>",
#  '<start> You are not Japanese. <end>',
#  "<start> Where's my grandfather? <end>",
#  '<start> Do you speak French, too? <end>',
#  '<start> What is your name? <end>',
#  "<start> It's a bit flimsy. <end>",
#  '<start> Turn it off. <end>',
#  '<start> This bed is heavy. <end>',
#  '<start> Close the window. <end>',
#  '<start> Tom has no insurance. <end>',
#  '<start> What language are you speaking? <end>',
#  '<start> I lay on my bed. <end>',
#  '<start> Is there more? <end>',
#  '<start> You were so strong. <end>',
#  '<start> We have enough money. <end>',
#  "<start> I'm proud of myself. <end>",
#  '<start> What souvenirs did you buy? <end>',
#  '<start> Please give me a break. <end>',
#  '<start> This room is too big. <end>',
#  "<start> He's so young. <end>",
#  "<start> I'll do that tomorrow. <end>",
#  "<start> We've been warned. <end>",
#  '<start> They have kids. <end>',
#  "<start> Let's begin on page 30. <end>",
#  '<start> Money has changed his life. <end>',
#  '<start> A housewife should be economical. <end>',
#  '<start> Do you live here? <end>',
#  '<start> Put that in writing. <end>',
#  '<start> Bears are quite dangerous. <end>',
#  '<start> They look bored. <end>',
#  '<start> Do you have any kids? <end>',
#  '<start> You have my sympathies. <end>',
#  "<start> Don't make me choose. <end>",
#  '<start> He continued the experiment. <end>',
#  '<start> Do you have a moment? <end>',
#  "<start> You weren't even there. <end>",
#  '<start> She is thirty-one. <end>',
#  '<start> You are wrong. <end>',
#  '<start> I slept for three hours. <end>',
#  '<start> It was a wonderful feeling. <end>',
#  '<start> What a lovely dress! <end>',
#  "<start> I'm getting poorer. <end>",
#  '<start> I got something for you. <end>',
#  '<start> Do you like rap? <end>',
#  '<start> I have a boring job. <end>',
#  "<start> You're part of the problem. <end>",
#  "<start> They're speaking French. <end>",
#  '<start> Do you know the way? <end>',
#  '<start> Keep on smiling. <end>',
#  ...]

# %%
frence_train = get_data(list(train["French words/sentences"]))
frence_train
# Out:
# ["<start> Rien ne l'arrêtera. <end>",
#  "<start> C'est juste. <end>",
#  "<start> J'ai rejoint l'armée. <end>",
#  "<start> J'aime toujours Tom. <end>",
#  '<start> La tasse a une fêlure. <end>',
#  '<start> Tom est superbe. <end>',
#  '<start> Es-tu en danger\xa0? <end>',
#  "<start> J'ai peur de mourir. <end>",
#  '<start> Elles te craignaient. <end>',
#  "<start> C'est la meilleur méthode. <end>",
#  "<start> Ils n'ont jamais abandonné. <end>",
#  "<start> Je pensais que j'étais heureuse. <end>",
#  '<start> Je ne blague pas. <end>',
#  '<start> Comment as-tu fait cela\u202f? <end>',
#  "<start> Je n'y avais pas songé. <end>",
#  '<start> Serre-moi la main. <end>',
#  "<start> Il n'y eut aucune conséquence. <end>",
#  "<start> Qu'attends-tu ? <end>",
#  "<start> J'aime dessiner. <end>",
#  '<start> Elles vont essayer. <end>',
#  '<start> Pas de problème. <end>',
#  '<start> Nous avons eu une plainte. <end>',
#  '<start> Attache tes lacets. <end>',
#  "<start> C'est gentil. <end>",
#  '<start> Vous êtes fort courageuse. <end>',
#  '<start> Je veux me confesser. <end>',
#  '<start> Il est prêt à partir. <end>',
#  "<start> C'est vrai de vrai. <end>",
#  '<start> Notre enquête est en cours. <end>',
#  '<start> Ceci est pour vous. <end>',
#  "<start> Ils ont l'air désorientés. <end>",
#  '<start> Tom était en désaccord. <end>',
#  '<start> Personne ne savait quoi faire. <end>',
#  '<start> Je parle bien japonais. <end>',
#  "<start> J'ai entendu la porte s'ouvrir. <end>",
#  '<start> Ta réponse est erronée. <end>',
#  '<start> Nous sommes toutes en danger. <end>',
#  '<start> Avec qui parlais-tu\u202f? <end>',
#  "<start> N'élude pas la question ! <end>",
#  '<start> Il y a une condition. <end>',
#  "<start> Qui t'a envoyé ? <end>",
#  '<start> Peut-être avez-vous été suivis. <end>',
#  '<start> Thomas est un grand sportif. <end>',
#  '<start> Je requiers vos conseils. <end>',
#  '<start> Je lui dirai ça. <end>',
#  '<start> Puis-je manger ceci\u202f? <end>',
#  "<start> Il s'emporte facilement. <end>",
#  '<start> Que penses-tu vraiment ? <end>',
#  '<start> Où êtes-vous née ? <end>',
#  '<start> Elle est chaude. <end>',
#  '<start> Tout le monde aimait Tom. <end>',
#  "<start> C'est vrai\u202f! <end>",
#  '<start> Jackson semblait se rétablir. <end>',
#  '<start> Êtes-vous complètement remises ? <end>',
#  '<start> Commençons la réunion maintenant. <end>',
#  '<start> On ne vous virera pas. <end>',
#  '<start> Aimerais-tu cela ? <end>',
#  "<start> C'est un vraiment bon argument. <end>",
#  '<start> Prends bien soin de toi. <end>',
#  '<start> Tu peux faire ceci. <end>',
#  '<start> Videz vos sacs. <end>',
#  '<start> Vos gencives sont infectées. <end>',
#  '<start> Puis-je poser une question\u202f? <end>',
#  "<start> Ce n'est pas un hôpital. <end>",
#  "<start> Prends l'appareil photo. <end>",
#  '<start> As-tu une allumette\u202f? <end>',
#  "<start> C'est à nous. <end>",
#  "<start> Jetons-y un coup d'œil. <end>",
#  '<start> Je vous ai appelé. <end>',
#  '<start> Je fume. <end>',
#  '<start> Il força la serrure. <end>',
#  '<start> Ne la dérange pas. <end>',
#  "<start> Ce n'est pas un virus. <end>",
#  '<start> Elles lisent son livre. <end>',
#  '<start> Danseras-tu avec moi ? <end>',
#  '<start> Arrêtez de me taquiner ! <end>',
#  '<start> Quelle nuit merveilleuse ! <end>',
#  "<start> Je n'ai pas dormi assez. <end>",
#  "<start> J'ai peur de mon patron. <end>",
#  '<start> Je lis un magazine. <end>',
#  '<start> Nous irons. <end>',
#  '<start> Amenez votre amie. <end>',
#  '<start> Tom était convaincu. <end>',
#  "<start> Tom n'aime pas chanter. <end>",
#  "<start> C'est mon désir. <end>",
#  "<start> J'ai aimé votre discours. <end>",
#  "<start> Il m'a vraiment énervé. <end>",
#  '<start> Je ne joue pas. <end>',
#  "<start> Le vieil homme s'assit. <end>",
#  "<start> Elles disent qu'elle est malade. <end>",
#  '<start> Il commence à neiger. <end>',
#  '<start> Je répare quelque chose. <end>',
#  '<start> On le trouva mystérieusement assassiné. <end>',
#  '<start> Il est déjà 7 heures. <end>',
#  "<start> J'irai où tu veux. <end>",
#  '<start> Ne prononcez jamais son nom. <end>',
#  '<start> Voilà votre chance. <end>',
#  "<start> Qu'as-tu d'autre ? <end>",
#  '<start> Je connais la solution. <end>',
#  "<start> J'ai essayé de te sauver. <end>",
#  '<start> Tous les fauteuils sont occupés. <end>',
#  '<start> Mettons-nous y ! <end>',
#  '<start> Faisons-le de cette manière. <end>',
#  '<start> Il parle vite. <end>',
#  '<start> Comment vous appelez-vous\u202f? <end>',
#  '<start> Elles sont de grandes amies. <end>',
#  "<start> C'était juste une idée. <end>",
#  '<start> Parlez-vous français\u202f? <end>',
#  "<start> J'ai peur de faire ça. <end>",
#  "<start> J'ai vraiment essayé. <end>",
#  '<start> Tu es saoul. <end>',
#  "<start> Je n'ai rien touché. <end>",
#  "<start> Je l'ai enterré. <end>",
#  '<start> Est-il encore là? <end>',
#  "<start> C'est un gros projet. <end>",
#  '<start> Je mange un sandwich. <end>',
#  "<start> Ce n'est pas vraiment vrai. <end>",
#  '<start> Ils ont construit un pont. <end>',
#  '<start> Vous ne serez pas déçue. <end>',
#  '<start> Suis-je si mauvais\xa0? <end>',
#  "<start> J'ai eu du bol. <end>",
#  '<start> Elles forment une grande équipe. <end>',
#  "<start> Vous avez l'air japonaises. <end>",
#  "<start> C'est pour vous. <end>",
#  "<start> J'ai beaucoup à dire. <end>",
#  "<start> J'ai peur de la mort. <end>",
#  '<start> Aidez-moi, je vous en supplie. <end>',
#  "<start> L'avez-vous emporté ? <end>",
#  "<start> C'est mon assistante. <end>",
#  '<start> Quelle suggestion stupide\xa0! <end>',
#  '<start> Votre hypothèse est erronée. <end>',
#  "<start> Tom n'a pas crié. <end>",
#  '<start> Veuillez y réfléchir. <end>',
#  '<start> Je vais vivre seule. <end>',
#  '<start> Il est mort ? <end>',
#  '<start> Salut tout le monde\u202f! <end>',
#  "<start> Il dit qu'il était pauvre. <end>",
#  "<start> J'ai couru à l'étage. <end>",
#  "<start> Ils n'ont jamais pratiqué d'autopsie. <end>",
#  '<start> Tu es insaisissable. <end>',
#  '<start> Vous êtes très marrants. <end>',
#  "<start> On a dansé jusqu'à minuit. <end>",
#  "<start> Ça m'a rendue très heureuse. <end>",
#  '<start> Où est le truc ? <end>',
#  "<start> Tom l'a rapidement compris. <end>",
#  "<start> Habituellement Tom vient à l'heure. <end>",
#  "<start> Quelqu'un a rigolé. <end>",
#  '<start> On te regarde. <end>',
#  "<start> Personne ne s'est évadé. <end>",
#  "<start> Tom n'en a pas besoin. <end>",
#  '<start> Elle vient juste de partir. <end>',
#  '<start> Je déteste ma colocataire. <end>',
#  '<start> Ne le serine pas ! <end>',
#  '<start> Connaissez-vous mon mari ? <end>',
#  '<start> Cette décision est définitive. <end>',
#  "<start> Il n'a pas le choix. <end>",
#  '<start> Nous échouerons. <end>',
#  '<start> Ils avaient peur de toi. <end>',
#  "<start> Qu'est-ce qui vous gêne\xa0? <end>",
#  '<start> Je vais aller le chercher. <end>',
#  '<start> Son sourire exprimait sa gratitude. <end>',
#  '<start> Je te demande pardon. <end>',
#  '<start> Il est parfait en tout. <end>',
#  '<start> Tom est infidèle. <end>',
#  '<start> Ça pourrait être difficile. <end>',
#  '<start> La maison était vide. <end>',
#  '<start> Nous sommes tellement désolés. <end>',
#  '<start> Quel est votre emploi ? <end>',
#  '<start> Ralentis ! <end>',
#  "<start> Nous l'emportâmes. <end>",
#  "<start> Je suis à court d'idées. <end>",
#  "<start> C'est la vérité. <end>",
#  '<start> Sérieusement ? <end>',
#  '<start> Éloigne-toi de moi. <end>',
#  '<start> Vous lisez mes pensées. <end>',
#  '<start> Il a traversé la rue. <end>',
#  '<start> A-t-il neigé cette nuit? <end>',
#  '<start> Puis-je emprunter ce livre\u202f? <end>',
#  '<start> Nous avons un lave-vaisselle. <end>',
#  "<start> C'est tellement relaxant. <end>",
#  "<start> J'étais très jaloux. <end>",
#  "<start> C'est le chat de Tom. <end>",
#  '<start> Il pleuvra probablement. <end>',
#  '<start> Vous êtes tellement prévisibles ! <end>',
#  '<start> Combien ai-je perdu ? <end>',
#  "<start> L'eau est froide. <end>",
#  '<start> Tu es très ingénieux. <end>',
#  '<start> Êtes-vous bon nageur\xa0? <end>',
#  '<start> Démarrons ! <end>',
#  '<start> Pourquoi étiez-vous absente hier\u202f? <end>',
#  "<start> J'aime les voyages. <end>",
#  "<start> Vous devez payer d'avance. <end>",
#  '<start> Faire cela sera difficile. <end>',
#  '<start> Pleut-il ? <end>',
#  '<start> Il a rompu sa parole. <end>',
#  '<start> Je me sens comme fatigué. <end>',
#  '<start> Sers-toi. <end>',
#  '<start> Elle est en danger. <end>',
#  "<start> J'aime jouer au poker. <end>",
#  '<start> Tom baissa le chauffage. <end>',
#  "<start> J'achèterai une Ford. <end>",
#  "<start> N'allume pas la bougie ! <end>",
#  '<start> Va avec Tom. <end>',
#  '<start> Ça me rend dingue. <end>',
#  "<start> C'est juste faux. <end>",
#  "<start> Je n'ai vraiment aucune idée. <end>",
#  '<start> Pardonne-moi de dire ça. <end>',
#  '<start> Elle a porté des lunettes. <end>',
#  '<start> Vous êtes fort talentueux. <end>',
#  '<start> La Russie est grande. <end>',
#  "<start> C'est ma sœur. <end>",
#  '<start> Rends-moi mon chapeau. <end>',
#  '<start> Alors ? Viendras-tu ? <end>',
#  '<start> Êtes-vous flic ? <end>',
#  '<start> Il a retiré son chapeau. <end>',
#  '<start> Tout va bien maintenant. <end>',
#  "<start> Il était d'accord avec moi. <end>",
#  "<start> Je n'ai aucune idée. <end>",
#  "<start> J'ai besoin d'un nouveau vélo. <end>",
#  '<start> Nous y sommes. <end>',
#  '<start> Elle semble être heureuse. <end>',
#  '<start> Tom aime jouer au football. <end>',
#  "<start> J'aime du bon café. <end>",
#  "<start> C'est secret. <end>",
#  '<start> Je vous ai rendu service. <end>',
#  "<start> Personne ne m'a suivi. <end>",
#  '<start> Mon temps coûte très cher. <end>',
#  "<start> Personne n'a parlé avec moi. <end>",
#  '<start> Avez-vous une allumette ? <end>',
#  '<start> Trois furent blessés. <end>',
#  "<start> C'était un sourire emprunté. <end>",
#  '<start> Je suis également enseignant. <end>',
#  "<start> J'ai entendu la question. <end>",
#  '<start> Prends ce que tu aimes. <end>',
#  '<start> Nous devons commencer quelque part. <end>',
#  '<start> Tu peux le faire. <end>',
#  '<start> Il va faire chaud. <end>',
#  "<start> J'entends rarement parler de lui. <end>",
#  "<start> J'aime votre tenue. <end>",
#  '<start> Son livre est très intéressant. <end>',
#  '<start> Le budget doit être équilibré. <end>',
#  '<start> Je connais Tom. <end>',
#  '<start> Je mange des fruits. <end>',
#  '<start> Ce travail ne paie pas. <end>',
#  '<start> Tout ceci est très déroutant. <end>',
#  '<start> Nous avons assez de temps. <end>',
#  "<start> Tout le monde s'est enfui. <end>",
#  '<start> On va la trouver. <end>',
#  "<start> Nous sommes d'ici. <end>",
#  '<start> Appellez les flics ! <end>',
#  '<start> La société accepta sa candidature. <end>',
#  '<start> Enfourche un cheval\xa0! <end>',
#  "<start> J'ai un secret. <end>",
#  "<start> J'ai besoin de faire ça. <end>",
#  '<start> Je veux être choyé. <end>',
#  '<start> Passez-vous du bon temps ? <end>',
#  '<start> Ça me rappelle chez moi. <end>',
#  '<start> Je suis assez contente. <end>',
#  "<start> C'est maintenant ta chance. <end>",
#  '<start> Je peux survivre. <end>',
#  '<start> Il se lève tôt. <end>',
#  '<start> Il a rejeté notre proposition. <end>',
#  '<start> Le chien me suivit. <end>',
#  "<start> J'ai vu les images. <end>",
#  '<start> Un cheval court vite. <end>',
#  '<start> Je cherche mon cellulaire. <end>',
#  '<start> Le printemps approche. <end>',
#  '<start> Nous sommes frères. <end>',
#  '<start> Tom est un fervent conservateur. <end>',
#  '<start> Il tint sa promesse. <end>',
#  '<start> Cette pièce est étroite. <end>',
#  '<start> Je suis de la partie. <end>',
#  "<start> J'ai entendu qu'il était décédé. <end>",
#  "<start> C'est fantastique. <end>",
#  "<start> C'est gros. <end>",
#  "<start> Je n'apprécie pas vos amies. <end>",
#  '<start> Le bébé était complètement endormi. <end>',
#  "<start> Il s'est vite lassé. <end>",
#  '<start> Regarde le sol. <end>',
#  "<start> J'ai décidé d'étudier les kanji. <end>",
#  '<start> Avez-vous terminé le travail\u202f? <end>',
#  '<start> Prenons une photo ici. <end>',
#  '<start> Je voulais surprendre Tom. <end>',
#  "<start> Tom n'est pas encore avocat. <end>",
#  "<start> Je n'ai pas de couteau. <end>",
#  '<start> Regardez sous le siège. <end>',
#  '<start> Vous semblez occupée. <end>',
#  '<start> Il est vite parti. <end>',
#  '<start> Laisse-moi finir. <end>',
#  '<start> Cela\xa0a\xa0vite\xa0changé. <end>',
#  '<start> Es-tu prêt pour Noël\xa0? <end>',
#  "<start> C'est un garçon très chouette. <end>",
#  '<start> Il ne nous apprécie pas. <end>',
#  "<start> C'est grotesque. <end>",
#  '<start> Nous resterons ici. <end>',
#  '<start> Le prix comprend la TVA. <end>',
#  "<start> Ils n'y parviendront pas. <end>",
#  "<start> J'habite ici. <end>",
#  '<start> Y allons-nous ? <end>',
#  '<start> Pourquoi êtes-vous intéressées ? <end>',
#  '<start> Où sont nos amis ? <end>',
#  "<start> Il s'endormit immédiatement. <end>",
#  '<start> Il a été intrigué. <end>',
#  "<start> C'est vraiment impressionnant. <end>",
#  '<start> As-tu reconnu Tom ? <end>',
#  "<start> L'accueil était chaleureux. <end>",
#  '<start> Il vend des fruits. <end>',
#  '<start> Ce fut notre rencontre initiale. <end>',
#  "<start> Nous n'avons vu personne. <end>",
#  '<start> Je n’étudie plus le français. <end>',
#  "<start> J'ai rêvassé toute la journée. <end>",
#  "<start> Fais de l'exercice à l'extérieur. <end>",
#  "<start> Est-ce que ça t'amuse\xa0? <end>",
#  "<start> C'est un volcan actif. <end>",
#  '<start> Nous sommes sept. <end>',
#  "<start> J'ai oublié mon mél. <end>",
#  '<start> Tom est multilingue. <end>',
#  "<start> M'entendez-vous ? <end>",
#  "<start> Ce n'est pas encore arrivé. <end>",
#  '<start> Bas les pattes ! <end>',
#  '<start> Elle accepta sa proposition. <end>',
#  '<start> Tu les as ? <end>',
#  "<start> L'entrée était gratuite. <end>",
#  '<start> Je suis conseiller en gestion. <end>',
#  '<start> Tu es partial. <end>',
#  '<start> Puis-je le mettre ici\u202f? <end>',
#  '<start> Il a écouté mon opinion. <end>',
#  "<start> Il s'est envolé pour Paris. <end>",
#  "<start> C'est celui-là. <end>",
#  '<start> Êtes-vous dyslexique\xa0? <end>',
#  '<start> Tout va bien ? <end>',
#  '<start> Je me sentis apeuré. <end>',
#  "<start> C'est ma camarade de classe. <end>",
#  '<start> Il manie bien les chevaux. <end>',
#  '<start> En avez-vous peur ? <end>',
#  "<start> C'était tout ce que j'avais. <end>",
#  "<start> Je t'amène chez Tom. <end>",
#  '<start> Je ne la revis jamais. <end>',
#  "<start> J'ai fait une expérience semblable. <end>",
#  '<start> Déplaçons le canapé. <end>',
#  '<start> Les étudiants l’adoraient. <end>',
#  '<start> Tu es vraiment désespérant. <end>',
#  '<start> Vos chaussettes sont dépareillées. <end>',
#  '<start> Je perdis trois kilos. <end>',
#  '<start> Éteignez les lumières, maintenant ! <end>',
#  '<start> Il ne vous comprend pas. <end>',
#  "<start> Vous avez l'air parfaits. <end>",
#  '<start> Que devrais-je écrire ici ? <end>',
#  '<start> Fermez vos livres. <end>',
#  "<start> J'arrive tout de suite. <end>",
#  '<start> Évidemment, tu as raison. <end>',
#  '<start> Vous êtes jolie. <end>',
#  '<start> Je pensais vous avoir entendue. <end>',
#  "<start> Je ne fais jamais d'exercice. <end>",
#  '<start> Nous y voilà ! <end>',
#  '<start> Quiconque regarde-t-il ? <end>',
#  '<start> Je me suis fait prendre. <end>',
#  '<start> Nous avons appris le français. <end>',
#  '<start> Faites comme on vous dit. <end>',
#  "<start> Tu n'as pas l'air convaincue. <end>",
#  '<start> Votre chat survivra. <end>',
#  "<start> Ça m'a épaté. <end>",
#  "<start> Je me sens mal aujourd'hui. <end>",
#  '<start> Elles se détestent vraiment. <end>',
#  '<start> Quelle est cette précipitation ? <end>',
#  "<start> C'est un grand poème. <end>",
#  '<start> Où est votre école ? <end>',
#  '<start> Je ne faisais que plaisanter. <end>',
#  '<start> Elle pourrait connaître la réponse. <end>',
#  '<start> Es-tu bouddhiste ? <end>',
#  '<start> Plusieurs plans furent proposés. <end>',
#  '<start> Votre mère est très jeune. <end>',
#  '<start> Il exige le paiement immédiat. <end>',
#  '<start> Nous sommes différents. <end>',
#  '<start> Voici mon numéro de téléphone. <end>',
#  "<start> M'attendras-tu ? <end>",
#  '<start> Je comprends tes raisons. <end>',
#  "<start> Trouve quelqu'un d'autre. <end>",
#  '<start> Avez-vous demandé le prix ? <end>',
#  "<start> J'ai perdu la clé. <end>",
#  '<start> Je ne vous dois rien. <end>',
#  "<start> C'est une surprise. <end>",
#  '<start> Je suis fermier. <end>',
#  '<start> Prends celui qui te chante. <end>',
#  '<start> Je dispose de temps. <end>',
#  '<start> Attendez-vous Tom ? <end>',
#  "<start> Cette question n'est pas simple. <end>",
#  "<start> J'ai tant appris ici. <end>",
#  '<start> Il est presque quinze heures. <end>',
#  "<start> J'ai été momentanément aveuglée. <end>",
#  '<start> En voici un pour toi. <end>',
#  '<start> Vous êtes très avisées. <end>',
#  '<start> Tom est dans le parc. <end>',
#  '<start> Mets-toi à ma place. <end>',
#  '<start> Fais-le ailleurs. <end>',
#  '<start> Ils ne sont pas seuls. <end>',
#  "<start> Ce n'est pas qu'un jeu. <end>",
#  '<start> Lisez autant que possible\u2009! <end>',
#  "<start> J'ai hasardé une heureuse hypothèse. <end>",
#  "<start> L'océan était calme. <end>",
#  '<start> Le natto est collant. <end>',
#  '<start> Nous travaillons tous trop dur. <end>',
#  "<start> J'ai envie de te voir. <end>",
#  '<start> Vous avez fait ceci. <end>',
#  '<start> Vous êtes jeune et forte. <end>',
#  '<start> Pourquoi est-ce si difficile\xa0? <end>',
#  '<start> Vous ai-je réveillé ? <end>',
#  '<start> Rendons-nous en ville ! <end>',
#  "<start> Personne ne t'a cru. <end>",
#  '<start> Mangeons avant de partir. <end>',
#  "<start> J'ai un aquarium. <end>",
#  "<start> Qu'as-tu fait, exactement ? <end>",
#  '<start> Ouvrez les fenêtres ! <end>',
#  '<start> Pourriez-vous nous laisser seules ? <end>',
#  '<start> Sont-ils vraiment amis ? <end>',
#  '<start> Aimez-vous le base-ball\xa0? <end>',
#  '<start> Tes frites refroidissent. <end>',
#  '<start> Il te faut un passe-temps. <end>',
#  "<start> Pourquoi personne ne t'aide\u202f? <end>",
#  "<start> Peux-tu voir l'image ? <end>",
#  "<start> J'essaierai de contacter Tom. <end>",
#  '<start> Je ne fais que blaguer. <end>',
#  '<start> Il a débouclé sa ceinture. <end>',
#  '<start> Les prisonnières furent libérées. <end>',
#  '<start> Je vous épargne les détails. <end>',
#  '<start> Il menace de pleuvoir. <end>',
#  "<start> J'ai procédé à des vérifications. <end>",
#  '<start> Ne ronge pas tes ongles. <end>',
#  '<start> Il a suffisamment de volonté. <end>',
#  '<start> Pourquoi étais-tu absente hier\u202f? <end>',
#  '<start> Fais attention, Tom ! <end>',
#  "<start> Son nom m'est familier. <end>",
#  '<start> Tout le monde le sait. <end>',
#  "<start> Rien n'a été changé. <end>",
#  '<start> Cela devint une épidémie. <end>',
#  '<start> Lui et moi sommes professeurs. <end>',
#  '<start> Traduisez ce texte. <end>',
#  '<start> Tom fait du bon travail. <end>',
#  "<start> Tu as l'air occupé. <end>",
#  '<start> Je crois en Dieu. <end>',
#  "<start> C'est classique. <end>",
#  "<start> Qu'avez-vous fait ? <end>",
#  '<start> Arrivez-vous à voir ? <end>',
#  '<start> Tu plaisantes ! <end>',
#  '<start> Me fais-je bien comprendre ? <end>',
#  '<start> Je laisserai Tom seul. <end>',
#  '<start> Nous sommes sous son commandement. <end>',
#  '<start> Je remis la manifestation. <end>',
#  '<start> Nous resterons en contact. <end>',
#  '<start> Tu as déjà mon attention. <end>',
#  '<start> Vous êtes talentueux. <end>',
#  '<start> Je vais tout faire. <end>',
#  "<start> J'adore les excursions. <end>",
#  "<start> C'est mon partenaire. <end>",
#  '<start> Écrivez une rédaction sur "L\'amitié". <end>',
#  '<start> Tu es fort. <end>',
#  "<start> J'en suis convaincu. <end>",
#  '<start> Tout a disparu. <end>',
#  '<start> Je me sentis coupable. <end>',
#  '<start> Connais-tu mon nom ? <end>',
#  '<start> Tom est-il de Boston ? <end>',
#  '<start> Soyez miséricordieuses ! <end>',
#  '<start> Pratiques-tu quelque sport\u202f? <end>',
#  '<start> Parlons sérieusement. <end>',
#  '<start> Elles étaient toutes hystériques. <end>',
#  "<start> C'est en quelque sorte étrange. <end>",
#  '<start> Tom mange des chips. <end>',
#  "<start> J'ai froid. <end>",
#  "<start> Ce n'est pas très original. <end>",
#  '<start> Les feuilles sont tombées. <end>',
#  '<start> Vise ce chien ! <end>',
#  '<start> Ils se sont querellés. <end>',
#  "<start> C'était verrouillé. <end>",
#  '<start> Potentiellement, cela pourrait se reproduire. <end>',
#  "<start> C'était une brillante idée. <end>",
#  "<start> C'est un conte moral. <end>",
#  '<start> Elle a un livre. <end>',
#  '<start> Vous allez mourir. <end>',
#  "<start> Je m'en soucie encore. <end>",
#  '<start> Les instituteurs saluèrent les enfants. <end>',
#  '<start> Votre chambre est prête, maintenant. <end>',
#  "<start> Je n'en suis pas sûre. <end>",
#  '<start> Essaie de comprendre ceci. <end>',
#  '<start> Tom prit une douche froide. <end>',
#  '<start> Avez-vous un chausse-pied ? <end>',
#  '<start> Il est allé skier. <end>',
#  '<start> Elle est très attirante. <end>',
#  '<start> Il se convertit au christianisme. <end>',
#  '<start> Il a entendu un bruit. <end>',
#  '<start> Pourquoi êtes-vous aussi secrets ? <end>',
#  '<start> Laisse-le tomber ! <end>',
#  '<start> Est-ce ta chambre\u202f? <end>',
#  '<start> Nous nous ennuyions. <end>',
#  "<start> Quand l'employez-vous ? <end>",
#  '<start> Tu peux réparer tout ça. <end>',
#  "<start> C'est une rumeur. <end>",
#  '<start> Soyez prudent ! <end>',
#  '<start> Je me sens déprimé. <end>',
#  "<start> Personne ne peut m'arrêter ! <end>",
#  '<start> Ça a très bon goût. <end>',
#  "<start> N'avez-vous pas chaud ? <end>",
#  '<start> Je lis son livre. <end>',
#  "<start> C'est une belle histoire. <end>",
#  "<start> N'êtes-vous pas gêné ? <end>",
#  "<start> Disposes-tu d'une allumette ? <end>",
#  '<start> Nous apprécions ton aide. <end>',
#  "<start> Il s'est gravement brulé. <end>",
#  "<start> Tu n'attraperas rien. <end>",
#  '<start> Allez chercher un médecin ! <end>',
#  '<start> Tout devint noir. <end>',
#  '<start> Signez juste ici. <end>',
#  '<start> Fermez la fenêtre, voulez-vous\xa0? <end>',
#  '<start> Il fait plus frais ici. <end>',
#  '<start> Perdez-vous du poids ? <end>',
#  '<start> Trouvez-vous une place. <end>',
#  '<start> Pourquoi tu nous accuses ? <end>',
#  "<start> C'est un gentil garçon. <end>",
#  '<start> Mon idée est mieux. <end>',
#  '<start> Tom aime les cheeseburgers. <end>',
#  "<start> J'ai séché les cours. <end>",
#  "<start> J'y retourne. <end>",
#  '<start> Ne le ramassez pas. <end>',
#  '<start> Nous en avons terminé. <end>',
#  "<start> C'est toi le professeur. <end>",
#  "<start> C'est un baratineur. <end>",
#  '<start> Nous avons toutes ri. <end>',
#  '<start> Tout se passait si vite. <end>',
#  '<start> Ça sera différent. <end>',
#  "<start> L'eau est propre. <end>",
#  '<start> Ils ont déballé leurs sandwichs. <end>',
#  '<start> Veuillez écrire avec un stylo. <end>',
#  "<start> Elles n'écoutèrent pas. <end>",
#  '<start> La loi est la loi. <end>',
#  "<start> L'avez-vous terminé\u202f? <end>",
#  "<start> J'ai tenté. <end>",
#  "<start> J'ai fait très attention. <end>",
#  '<start> Rappelle-moi. <end>',
#  "<start> C'est un bateau. <end>",
#  '<start> Je suis loyal. <end>',
#  "<start> Nous vivons près de l'école. <end>",
#  '<start> Je ne vais pas mourir. <end>',
#  '<start> Cesse de te plaindre ! <end>',
#  '<start> Ta fille est très jolie. <end>',
#  "<start> On doit s'y attendre. <end>",
#  '<start> Beaucoup de gens font ça. <end>',
#  "<start> Tu as l'air terrible. <end>",
#  "<start> Merci pour l'invitation, Tom. <end>",
#  "<start> Je n'ai pas de nourriture. <end>",
#  "<start> Je t'ai préparé une surprise. <end>",
#  '<start> Écoutez, vous tous. <end>',
#  '<start> Je comprends. <end>',
#  "<start> Rencontrez-m'y à minuit. <end>",
#  '<start> Détends-toi. <end>',
#  "<start> J'ai été partout. <end>",
#  '<start> Tu es incorrigible. <end>',
#  '<start> Vous avez ruiné ma vie. <end>',
#  '<start> Vous amusez-vous bien ? <end>',
#  '<start> Malheureusement, de nombreux Japonais moururent. <end>',
#  '<start> Vous êtes tous prêts\u202f? <end>',
#  '<start> Ne me quitte pas. <end>',
#  '<start> Tom va bien. <end>',
#  "<start> Nous sommes meilleures qu'elles. <end>",
#  "<start> J'ai reconnu le nom. <end>",
#  '<start> Êtes-vous occupés demain matin\xa0? <end>',
#  "<start> J'ai changé de vêtements. <end>",
#  '<start> Surveille ta vitesse. <end>',
#  "<start> Par ici, s'il vous plait. <end>",
#  "<start> J'ai besoin de papier. <end>",
#  '<start> Ne me fais pas souffrir. <end>',
#  '<start> Faites un bon voyage ! <end>',
#  '<start> Tout va bien. <end>',
#  '<start> Nous le savions toutes. <end>',
#  "<start> Elles étudient l'après-midi. <end>",
#  '<start> Il fait nuit. <end>',
#  '<start> Vous pouvez entrer, maintenant. <end>',
#  "<start> Personne ne peut t'entendre. <end>",
#  '<start> Tu es parfois si puéril. <end>',
#  '<start> Je te libèrerai. <end>',
#  "<start> S'il te plaît, jette ça. <end>",
#  '<start> Ton pneu est crevé. <end>',
#  '<start> Où est la cuisine\xa0? <end>',
#  '<start> Il a été parfait. <end>',
#  '<start> Verrouillez le coffre-fort. <end>',
#  "<start> J'ai beaucoup bu. <end>",
#  "<start> Tom était silencieux aujourd'hui. <end>",
#  '<start> Ne venez pas ici ! <end>',
#  '<start> Il ira aussi. <end>',
#  '<start> Quel mois sommes-nous\xa0? <end>',
#  '<start> La voiture est très rapide. <end>',
#  '<start> Chantez une chanson avec moi. <end>',
#  '<start> Tom entra. <end>',
#  "<start> Qu'y a-t-il à l'intérieur\xa0? <end>",
#  "<start> Qu'as-tu bu ? <end>",
#  "<start> J'ai lu ton rapport. <end>",
#  '<start> Je suis tombée amoureuse. <end>',
#  '<start> Nous en sommes fiers. <end>',
#  '<start> Tom devrait apprendre le français. <end>',
#  '<start> Quand as-tu commencé ? <end>',
#  "<start> Vous l'avez souvent dit vous-même. <end>",
#  "<start> J'apprécie vraiment cela. <end>",
#  "<start> Nous avons eu l'air ridicule. <end>",
#  "<start> Nous avons suffisamment d'espace ici. <end>",
#  "<start> Il n'y a aucun doute. <end>",
#  '<start> Vous avez assez souffert. <end>',
#  '<start> Son épouse est française. <end>',
#  "<start> J'ai une voiture neuve. <end>",
#  "<start> Tom m'a donné cette montre. <end>",
#  '<start> Je me sens honorée. <end>',
#  "<start> C'est plus fort que moi. <end>",
#  "<start> C'est une croisière de luxe. <end>",
#  '<start> Ils doivent vraiment me détester. <end>',
#  '<start> Il tomba la chemise. <end>',
#  '<start> Tom est un idiot. <end>',
#  '<start> Êtes-vous malchanceux\xa0? <end>',
#  '<start> Ils travaillent pour moi. <end>',
#  "<start> J'étais furieux. <end>",
#  '<start> Je suis encore ici. <end>',
#  '<start> Tom a essayé de partir. <end>',
#  '<start> Avez-vous vu mon porte-monnaie ? <end>',
#  '<start> Il était crédule. <end>',
#  "<start> Elle a décidé de l'épouser. <end>",
#  "<start> J'ai un prof particulier. <end>",
#  '<start> Redemande-moi ça en octobre. <end>',
#  "<start> J'espère que Tom est objectif. <end>",
#  '<start> Les feuilles tombent. <end>',
#  '<start> Tom a perdu son porte-monnaie. <end>',
#  '<start> Tom est différent. <end>',
#  '<start> Vous trois êtes très chanceuses. <end>',
#  '<start> Aimez-vous les gaufres\xa0? <end>',
#  '<start> Tout le monde a crevé. <end>',
#  '<start> Veuillez fermer la porte. <end>',
#  '<start> Je veux un beignet. <end>',
#  "<start> Tu as l'air d'un enfant. <end>",
#  '<start> Qui a dit cela\u202f? <end>',
#  '<start> Cela fait vraiment sens. <end>',
#  "<start> J'ai une grenade. <end>",
#  "<start> Ceci n'est-il pas merveilleux ? <end>",
#  '<start> Y a-t-il des enfants ? <end>',
#  "<start> Je suis dépourvu d'excuse. <end>",
#  '<start> Ses vêtements sont usés. <end>',
#  '<start> Mon chat est noir. <end>',
#  '<start> Sois créatif ! <end>',
#  "<start> C'est mon argent. <end>",
#  '<start> Tom veut savoir pourquoi. <end>',
#  '<start> Que tu es grande\u202f! <end>',
#  "<start> J'écoute parfois du jazz. <end>",
#  '<start> Devrions-nous attendre ? <end>',
#  '<start> Vous plaisantez ! <end>',
#  "<start> C'est l'un de ces moments. <end>",
#  '<start> Donnez-moi mes lunettes. <end>',
#  '<start> Les changements sont rapidement survenus. <end>',
#  '<start> La journée commençait très bien. <end>',
#  '<start> Tom paie ses impôts. <end>',
#  "<start> Ce bruit m'a réveillé. <end>",
#  "<start> Aujourd'hui est la Saint-Valentin. <end>",
#  '<start> Vous êtes pleine de ressources. <end>',
#  "<start> Comment s'appelle cette rue\u202f? <end>",
#  "<start> Penses-tu que c'est vrai\xa0? <end>",
#  "<start> C'est mon métier. <end>",
#  '<start> Tu peux utiliser le mien. <end>',
#  '<start> Nous avons été séparés. <end>',
#  '<start> Ce thé est très chaud. <end>',
#  "<start> Je réglais l'addition. <end>",
#  '<start> Comment va votre mère\u202f? <end>',
#  '<start> Veuillez partir sans délai. <end>',
#  "<start> N'es-tu pas convaincue? <end>",
#  "<start> C'est vraiment génial. <end>",
#  '<start> Maintenant, mange ton dîner. <end>',
#  "<start> J'ai dix-huit ans. <end>",
#  "<start> Il n'aime pas le poisson. <end>",
#  '<start> Regarde attentivement ! <end>',
#  '<start> Tu as un gros nez. <end>',
#  "<start> J'aime rêver. <end>",
#  '<start> Il vint en bus. <end>',
#  "<start> Personne n'est mort. <end>",
#  "<start> C'est important. <end>",
#  '<start> Tu es fort craintif. <end>',
#  '<start> Cela aide beaucoup. <end>',
#  '<start> Raconte-nous une blague. <end>',
#  '<start> Tom vit à Boston. <end>',
#  '<start> Passe du bon temps ! <end>',
#  '<start> Ces cadeaux sont pour toi. <end>',
#  '<start> Elle prit une profonde respiration. <end>',
#  '<start> Que dis-tu ? <end>',
#  '<start> Je peux me gérer seul. <end>',
#  '<start> Il fut déçu. <end>',
#  '<start> Sois détendu ! <end>',
#  "<start> Nous l'avons perdu de vue. <end>",
#  "<start> Ce n'est pas marrant. <end>",
#  '<start> Tu dois être préparé. <end>',
#  "<start> Prends l'un de ceux-là ! <end>",
#  "<start> Je pense qu'ils nous connaissent. <end>",
#  "<start> Allons à l'hôpital. <end>",
#  '<start> Êtes-vous prêt à partir\xa0? <end>',
#  '<start> Ceux-là sont tous importants. <end>',
#  '<start> Continue à écrire. <end>',
#  '<start> Il était très nerveux. <end>',
#  '<start> Il a dormi une heure. <end>',
#  '<start> Vous êtes le maître. <end>',
#  '<start> Je suis impliqué. <end>',
#  '<start> Nous aurions pu faire mieux. <end>',
#  '<start> Pourquoi quiconque viendrait-il ici ? <end>',
#  '<start> Vous ne le croirez pas. <end>',
#  '<start> Je suis têtu. <end>',
#  "<start> L'idée était bonne. <end>",
#  '<start> Je vous en supplie. <end>',
#  '<start> Peut-être le rencontreras-tu. <end>',
#  '<start> Peux-tu venir avec moi\xa0? <end>',
#  '<start> Il vint en voiture. <end>',
#  '<start> Ma voisine est gentille. <end>',
#  '<start> Je parle avec Tom. <end>',
#  '<start> Tom me donna trente dollars. <end>',
#  '<start> Es-tu toujours aussi occupé ? <end>',
#  '<start> Aide-moi ! <end>',
#  '<start> Nous travaillons toutes trop dur. <end>',
#  "<start> J'ai besoin de dormir. <end>",
#  '<start> Soyez prudente ! <end>',
#  '<start> Désolé, quelque chose a foiré. <end>',
#  '<start> La radio ne fonctionne pas. <end>',
#  '<start> La maison brûle ! <end>',
#  "<start> Essayez d'en profiter. <end>",
#  "<start> Je l'ai construit. <end>",
#  '<start> Vos pieds sont sales. <end>',
#  '<start> Vous êtes tellement impatiente. <end>',
#  '<start> Bois-tu de la bière ? <end>',
#  '<start> Elle ne sort pas beaucoup. <end>',
#  '<start> Écrivez-moi ! <end>',
#  '<start> Te sens-tu malade\u202f? <end>',
#  "<start> Que fais-tu aujourd'hui\u202f? <end>",
#  '<start> Ils ont assez souffert. <end>',
#  '<start> Elles parlent toutes français. <end>',
#  '<start> Restez avec nous. <end>',
#  '<start> Tu es partiale. <end>',
#  "<start> J'ai été horrifié. <end>",
#  "<start> Pourquoi l'avez-vous fait ? <end>",
#  '<start> Cela vous rendrait-il heureux\xa0? <end>',
#  "<start> C'est tellement mauvais, c'est hilarant. <end>",
#  "<start> C'est une grande préoccupation. <end>",
#  '<start> Vous êtes imprudents. <end>',
#  '<start> Regardez derrière vous. <end>',
#  '<start> Laisse-moi mettre quelque chose. <end>',
#  "<start> Je prévois d'être en avance. <end>",
#  '<start> La marée monte. <end>',
#  "<start> J'espère qu'ils vont bien. <end>",
#  "<start> Je n'ai pas pu m'échapper. <end>",
#  '<start> La chambre est sombre. <end>',
#  "<start> Il fait assez chaud aujourd'hui. <end>",
#  "<start> J'ai besoin de 30 minutes. <end>",
#  '<start> Verrouille tes portes ! <end>',
#  "<start> C'est offensant. <end>",
#  '<start> Parles-tu français\u202f? <end>',
#  '<start> Quelque chose doit être fait. <end>',
#  "<start> D'ordinaire, je mange dehors. <end>",
#  '<start> Ce sont de mauvaises nouvelles. <end>',
#  "<start> J'ai une voisine canadienne. <end>",
#  '<start> Vous êtes tellement impatientes. <end>',
#  "<start> Vous avez l'air terrible. <end>",
#  '<start> Vous aimez le tennis\u202f? <end>',
#  '<start> Commandons une pizza. <end>',
#  '<start> Je serai là sans tarder. <end>',
#  "<start> Ce n'est pas supposé arriver. <end>",
#  "<start> J'admets avoir été surprise. <end>",
#  '<start> Vous êtes contents. <end>',
#  '<start> Il ne se passera rien. <end>',
#  '<start> Vous êtes fort astucieuses. <end>',
#  '<start> Nous sommes allés à pied. <end>',
#  '<start> Rends-toi au magasin ! <end>',
#  '<start> Assurément vous vous trompez. <end>',
#  "<start> M'écoutes-tu ? <end>",
#  '<start> Prenez garde aux pickpockets. <end>',
#  '<start> Le sol est encore humide. <end>',
#  "<start> C'est ridicule. <end>",
#  '<start> Tout le monde a souri. <end>',
#  '<start> Grimpez dans le bus ! <end>',
#  "<start> Le vieil homme s'est assis. <end>",
#  "<start> C'est mon ami intime. <end>",
#  '<start> Vous pouvez ouvrir la fenêtre. <end>',
#  '<start> Tout le monde va bien. <end>',
#  "<start> J'ai envie de chanter. <end>",
#  "<start> J'ai déjà expliqué ça. <end>",
#  '<start> Ne soyez pas fâchées ! <end>',
#  "<start> J'ai besoin de peinture. <end>",
#  "<start> Je n'ai aucune preuve. <end>",
#  '<start> Cette place est-elle libre\u202f? <end>',
#  '<start> Dublin est en Irlande. <end>',
#  '<start> Vous êtes très observateur. <end>',
#  '<start> Mon chat me manque. <end>',
#  '<start> Je suis fiancé avec elle. <end>',
#  '<start> Elles ne vous méprisent pas. <end>',
#  '<start> Il nous faut attendre. <end>',
#  '<start> Nous essayons de travailler. <end>',
#  "<start> J'ai le rhume des foins. <end>",
#  '<start> Je rompis avec lui. <end>',
#  "<start> Nous fûmes à court d'essence. <end>",
#  '<start> Pourquoi avons-nous dit cela\xa0? <end>',
#  "<start> L'ampoule lumineuse éclata. <end>",
#  "<start> Tu t'en remettras. <end>",
#  "<start> Il m'a arnaquée. <end>",
#  "<start> Tom n'a encore rien mangé. <end>",
#  '<start> Va au lit ! <end>',
#  '<start> Ce bouton pendouille. <end>',
#  '<start> Ne répondez pas à cela. <end>',
#  "<start> J'ai encore plutôt faim. <end>",
#  "<start> N'est-ce pas à nous ? <end>",
#  '<start> Comment le saurais-je\u202f? <end>',
#  '<start> Il est harcelé. <end>',
#  "<start> Il a nié l'avoir fait. <end>",
#  '<start> Elles prendront soin de vous. <end>',
#  '<start> Vous avez des visiteurs. <end>',
#  "<start> J'ai promis de faire ça. <end>",
#  '<start> Vous vous trompiez clairement. <end>',
#  "<start> Je crois que c'est tout. <end>",
#  '<start> Je n’ai plus faim. <end>',
#  '<start> Je devrais aller à Boston. <end>',
#  '<start> Tom frappa Mary. <end>',
#  "<start> J'ai fermé la fenêtre. <end>",
#  '<start> Nous avons été occupés. <end>',
#  "<start> J'ai perdu ma montre hier. <end>",
#  '<start> Je peux la consoler. <end>',
#  '<start> Quelle est votre destination ? <end>',
#  '<start> Êtes-vous armés ? <end>',
#  "<start> J'ai dit de venir seul. <end>",
#  '<start> Je comprends le problème. <end>',
#  '<start> Tom manipule souvent les gens. <end>',
#  '<start> Tout va bien se passer. <end>',
#  '<start> Je cherchais la clef. <end>',
#  "<start> L'argent est sur la table. <end>",
#  '<start> Nous sommes occupés. <end>',
#  "<start> J'ai le sommeil léger. <end>",
#  '<start> Ce sont des animaux. <end>',
#  "<start> C'est une très bonne question. <end>",
#  '<start> Il aurait dû venir. <end>',
#  '<start> Je vends des voitures. <end>',
#  '<start> Il est déjà onze heures. <end>',
#  '<start> Je fais encore des erreurs. <end>',
#  '<start> Une révolte éclata. <end>',
#  "<start> Vous n'êtes pas encore adolescent. <end>",
#  "<start> Tu dois l'arrêter. <end>",
#  "<start> Qu'est-ce qui vous inquiète ? <end>",
#  "<start> C'était moins une. <end>",
#  "<start> C'est terrible ! <end>",
#  '<start> Vous restez ici. <end>',
#  "<start> Veuillez me permettre d'y aller. <end>",
#  "<start> Tu n'es pas habillée. <end>",
#  "<start> Je suis en congé, aujourd'hui. <end>",
#  '<start> Avez-vous été maltraité\xa0? <end>',
#  '<start> Nous échangeâmes des salutations. <end>',
#  '<start> Je fus désolée. <end>',
#  "<start> Ce n'est pas très facile. <end>",
#  "<start> Tom n'aime aucun sport. <end>",
#  '<start> Je ne faisais que plaisanter. <end>',
#  '<start> Elle attend famille. <end>',
#  '<start> Il fait une chaleur écrasante. <end>',
#  '<start> Vous êtes tous licenciés. <end>',
#  "<start> N'attends pas trop. <end>",
#  '<start> Il habite à Osaka. <end>',
#  "<start> Ce n'était pas la mienne. <end>",
#  '<start> Je connais ton genre. <end>',
#  "<start> J'essaye d'être heureux. <end>",
#  '<start> Je me suis remariée. <end>',
#  "<start> C'est beaucoup de nourriture. <end>",
#  "<start> Elles n'ont rien vu. <end>",
#  "<start> C'est leur unique enfant. <end>",
#  "<start> J'ai conclu une affaire. <end>",
#  '<start> On va le rendre. <end>',
#  "<start> Ça a l'air assez mignon. <end>",
#  "<start> Ils l'ont tous fait. <end>",
#  "<start> L'Islande a appartenu au Danemark. <end>",
#  '<start> Veuillez me tenir informé. <end>',
#  '<start> Cette chambre est vide. <end>',
#  "<start> Elle ne l'aimait pas. <end>",
#  "<start> J'adore jouer du Chopin. <end>",
#  '<start> Tom est défoncé. <end>',
#  '<start> Ce seau fuit. <end>',
#  '<start> Bien cuit\u202f! <end>',
#  "<start> J'ai des informations. <end>",
#  "<start> Je ne l'ai pas vu. <end>",
#  '<start> Vous avez outrepassé votre autorité. <end>',
#  '<start> Es-tu végétarien ? <end>',
#  '<start> Nous devons arrêter. <end>',
#  '<start> Regardez ici. <end>',
#  "<start> N'es-tu pas fatigué\u202f? <end>",
#  '<start> Mets des vêtements ! <end>',
#  '<start> Elle est bien venue ici. <end>',
#  '<start> Je suis presque mort. <end>',
#  "<start> J'ai fini par accepter cela. <end>",
#  '<start> Cela semble clair. <end>',
#  '<start> Soyez prudent ! <end>',
#  "<start> J'apprécie l'hospitalité. <end>",
#  "<start> C'est mieux que le film. <end>",
#  '<start> Ce garçon court. <end>',
#  "<start> C'est quand même mon anniversaire. <end>",
#  '<start> Elle est l’éditeur en chef. <end>',
#  '<start> Je me suis fâché. <end>',
#  '<start> Tom parla de Boston. <end>',
#  '<start> Vous êtes fort élégantes. <end>',
#  '<start> Nous trouvâmes quelque chose. <end>',
#  "<start> Je peux t'aider. <end>",
#  '<start> Je voulais te voir. <end>',
#  '<start> Tu aurais dû lui dire. <end>',
#  "<start> Dépêchez-vous s'il vous plaît. <end>",
#  '<start> Avez-vous vu cet homme? <end>',
#  '<start> Cette chaise est trop petite. <end>',
#  '<start> Tom est un homme. <end>',
#  "<start> J'apprécie vraiment la proposition. <end>",
#  "<start> Ils s'aiment profondément l'un l'autre. <end>",
#  '<start> La porte était déverrouillée. <end>',
#  '<start> Nous avons un témoin. <end>',
#  "<start> J'aimerais me présenter. <end>",
#  "<start> Tu as l'air épuisé. <end>",
#  '<start> Tous sauf un étaient présents. <end>',
#  '<start> La menace est réelle. <end>',
#  '<start> Toi, conduis ! <end>',
#  '<start> Ton plan semble excellent. <end>',
#  '<start> Les tire-laines ciblent les touristes. <end>',
#  "<start> J'ai brûlé le gâteau. <end>",
#  '<start> Ils auraient pu te tuer. <end>',
#  '<start> As-tu fini ton papier ? <end>',
#  "<start> J'y suis allée aujourd'hui. <end>",
#  '<start> Tom sait ça. <end>',
#  '<start> Tu ne peux pas sortir. <end>',
#  "<start> Elles t'y ont suivie. <end>",
#  "<start> C'est samedi. <end>",
#  '<start> Mon père est docteur. <end>',
#  '<start> Quiconque a-t-il été blessé ? <end>',
#  '<start> Vous devriez manger. <end>',
#  '<start> Pourquoi es-tu assise là ? <end>',
#  '<start> Tom est très direct. <end>',
#  '<start> Je reste optimiste. <end>',
#  "<start> J'en suis consciente. <end>",
#  "<start> L'as-tu prévu ? <end>",
#  '<start> Chantez-moi une chanson. <end>',
#  "<start> Je l'ignorais. <end>",
#  '<start> Je sais où il habite. <end>',
#  '<start> Attends de voir ça ! <end>',
#  "<start> Qu'avez-vous répondu\u202f? <end>",
#  '<start> Tom est toujours très malheureux. <end>',
#  "<start> J'ai perdu mon attaché-case. <end>",
#  '<start> Tout avait été prévu. <end>',
#  "<start> C'est mon camarade de classe. <end>",
#  '<start> Tu es fatigué. <end>',
#  '<start> Regarde ce grand bâtiment ! <end>',
#  "<start> Elle l'a frappé. <end>",
#  '<start> Les voyants sont allumés. <end>',
#  '<start> Je conduis parfois trop vite. <end>',
#  '<start> Ce film fait vraiment peur. <end>',
#  "<start> J'aime jouer au basket-ball. <end>",
#  '<start> La porte était verrouillée. <end>',
#  "<start> Que n'as-tu pas\u202f? <end>",
#  '<start> Il laissa tomber. <end>',
#  '<start> Y a-t-il une correspondance\u202f? <end>',
#  '<start> Je suis extraverti. <end>',
#  "<start> Vous n'êtes pas japonaises. <end>",
#  '<start> Où est mon grand-père\xa0? <end>',
#  '<start> Parlez-vous aussi français\u202f? <end>',
#  '<start> Quel est ton nom ? <end>',
#  "<start> C'est un peu léger. <end>",
#  '<start> Éteins-le ! <end>',
#  '<start> Ce lit pèse lourd. <end>',
#  '<start> Fermez la fenêtre. <end>',
#  "<start> Tom n'a pas d'assurance. <end>",
#  '<start> Quelle langue parlez-vous ? <end>',
#  "<start> J'étais étendue sur mon lit. <end>",
#  '<start> Y a-t-il plus\xa0? <end>',
#  '<start> Vous étiez tellement forts. <end>',
#  "<start> Nous disposons de suffisamment d'argent. <end>",
#  '<start> Je suis fier de moi. <end>',
#  '<start> Quels souvenirs as-tu acheté ? <end>',
#  "<start> Lâche-moi, s'il te plait. <end>",
#  '<start> Cette pièce est trop grande. <end>',
#  '<start> Il est si jeune. <end>',
#  '<start> Je ferai ça demain. <end>',
#  '<start> On\xa0nous\xa0a\xa0averties. <end>',
#  '<start> Ils ont des enfants. <end>',
#  '<start> Commençons en page trente. <end>',
#  "<start> L'argent a changé sa vie. <end>",
#  '<start> Une ménagère devrait être économe. <end>',
#  '<start> Résides-tu ici ? <end>',
#  '<start> Mets ça par écrit. <end>',
#  '<start> Les ours sont très dangereux. <end>',
#  "<start> Ils ont l'air de s'ennuyer. <end>",
#  '<start> Avez-vous des gosses ? <end>',
#  '<start> Vous avez toute ma sympathie. <end>',
#  "<start> Ne m'oblige pas à choisir. <end>",
#  "<start> Il poursuivit l'expérience. <end>",
#  '<start> Avez-vous un instant\u202f? <end>',
#  "<start> Tu n'étais même pas là. <end>",
#  '<start> Elle a 31 ans. <end>',
#  '<start> Vous avez tort. <end>',
#  "<start> J'ai dormi trois heures. <end>",
#  '<start> Ce fut une sensation merveilleuse. <end>',
#  '<start> Quelle robe ravissante ! <end>',
#  "<start> Je m'appauvris. <end>",
#  "<start> J'ai quelque chose pour vous. <end>",
#  '<start> Tu aimes le rap\u202f? <end>',
#  "<start> J'ai un travail chiant. <end>",
#  '<start> Vous faites partie du problème. <end>',
#  '<start> Elles parlent en français. <end>',
#  '<start> Connaissez-vous le chemin\u202f? <end>',
#  '<start> Reste souriant. <end>',
#  ...]

# %%
english_valid = get_data(list(valid["English words/sentences"]))
english_valid
# Out:
# ['<start> Watch out for that man. <end>',
#  '<start> This is unacceptable. <end>',
#  '<start> She was crying with pain. <end>',
#  '<start> They were tired of waiting. <end>',
#  "<start> We aren't always right. <end>",
#  '<start> You have my respect. <end>',
#  '<start> He picked up a stone. <end>',
#  '<start> Do you like to sing? <end>',
#  "<start> It wasn't enough. <end>",
#  "<start> Let's establish some ground rules. <end>",
#  '<start> I take it back. <end>',
#  '<start> He loves toys. <end>',
#  '<start> Tom found your cap. <end>',
#  '<start> Give me an example. <end>',
#  '<start> Tom is making a mistake. <end>',
#  "<start> It was wonderful, wasn't it? <end>",
#  '<start> Everything is ready here. <end>',
#  '<start> Is that bothering you? <end>',
#  '<start> Do you have enough time? <end>',
#  '<start> Everyone waited. <end>',
#  '<start> I took a bath. <end>',
#  '<start> This dictionary is mine. <end>',
#  '<start> The bridge is closed. <end>',
#  '<start> This is inefficient. <end>',
#  '<start> My family is small. <end>',
#  "<start> I'm going crazy. <end>",
#  '<start> Tom bolted the door. <end>',
#  '<start> Be quiet and listen. <end>',
#  '<start> Many fish died. <end>',
#  "<start> I don't like your smile. <end>",
#  '<start> He wanted to meet me. <end>',
#  '<start> Tom made a pilgrimage. <end>',
#  '<start> We must do it again. <end>',
#  '<start> Can you clean your bedroom? <end>',
#  '<start> Tell the truth. <end>',
#  "<start> You're vulgar. <end>",
#  '<start> Do you have any money? <end>',
#  "<start> Don't move. <end>",
#  '<start> Diet is important. <end>',
#  '<start> That was our goal. <end>',
#  '<start> Why are you sitting there? <end>',
#  "<start> I'm rather busy. <end>",
#  "<start> You're not that smart. <end>",
#  '<start> Only one man survived. <end>',
#  "<start> I should've said no. <end>",
#  "<start> I'm tired of Boston. <end>",
#  '<start> I admit I did that. <end>',
#  '<start> He is likely to come. <end>',
#  '<start> Do you have a violin? <end>',
#  '<start> She has no manners. <end>',
#  "<start> It wasn't that big. <end>",
#  '<start> Sorry, something went wrong. <end>',
#  "<start> The king's son was kidnapped. <end>",
#  "<start> It's not safe. <end>",
#  '<start> He walked away. <end>',
#  "<start> I'm devastated. <end>",
#  '<start> See you later. <end>',
#  "<start> You don't know anything. <end>",
#  '<start> Eat something. <end>',
#  '<start> Why is that baby crying? <end>',
#  "<start> I'm not afraid of heights. <end>",
#  "<start> We'll try. <end>",
#  '<start> He never loses hope. <end>',
#  "<start> She's never fallen in love. <end>",
#  '<start> What does she say? <end>',
#  '<start> Am I not right? <end>',
#  "<start> We're not involved. <end>",
#  "<start> I'll buy that. <end>",
#  '<start> Tom comforted Mary. <end>',
#  '<start> Do you feel lucky? <end>',
#  '<start> He kept me waiting. <end>',
#  '<start> Are you getting tired? <end>',
#  "<start> That's hardly likely. <end>",
#  '<start> Thank you for the soup. <end>',
#  '<start> It snowed hard yesterday. <end>',
#  '<start> Do you want to stop? <end>',
#  "<start> How's your sister? <end>",
#  '<start> What am I up against? <end>',
#  "<start> You're so picky. <end>",
#  '<start> I think about you often. <end>',
#  '<start> I needed help. <end>',
#  "<start> You've been warned. <end>",
#  '<start> She has beautiful handwriting. <end>',
#  '<start> She pinched him. <end>',
#  "<start> You could've ruined everything. <end>",
#  '<start> I grew up here. <end>',
#  '<start> Your ideas are welcome. <end>',
#  "<start> It's a happy thing. <end>",
#  '<start> You must control yourself. <end>',
#  '<start> Who was killed? <end>',
#  "<start> They'll kill me. <end>",
#  '<start> I love cooking. <end>',
#  '<start> Could you be more specific? <end>',
#  '<start> When can you start? <end>',
#  '<start> I really miss my girlfriend. <end>',
#  '<start> Did you sleep well? <end>',
#  '<start> Fasten your seat belt. <end>',
#  '<start> They understood that. <end>',
#  '<start> I know how this works. <end>',
#  '<start> Tom helped. <end>',
#  '<start> I trusted them. <end>',
#  '<start> Would you like some coffee? <end>',
#  '<start> Can you play an instrument? <end>',
#  '<start> Wait here. <end>',
#  '<start> Do you want to drink? <end>',
#  '<start> He works at a bank. <end>',
#  '<start> I want to thank you. <end>',
#  '<start> Tom talks quickly. <end>',
#  '<start> You know too much. <end>',
#  "<start> I'll be your teacher. <end>",
#  "<start> I'm strong enough. <end>",
#  '<start> I feel your pain. <end>',
#  '<start> I did it like this. <end>',
#  '<start> No one believed us. <end>',
#  "<start> We're comedians. <end>",
#  '<start> He wrote a letter. <end>',
#  '<start> I was paraphrasing. <end>',
#  '<start> I used my imagination. <end>',
#  '<start> Nothing is perfect. <end>',
#  '<start> They finished 13th. <end>',
#  "<start> I'm sending you a book. <end>",
#  "<start> You're very attractive. <end>",
#  "<start> You're incredible. <end>",
#  '<start> I have the dictionary. <end>',
#  '<start> I want something to eat. <end>',
#  "<start> You've got three months left. <end>",
#  '<start> Do you have the keys? <end>',
#  '<start> Why are you saying goodbye? <end>',
#  '<start> I need to be alone. <end>',
#  '<start> When will you start? <end>',
#  '<start> Do you drink beer? <end>',
#  "<start> That's my favorite part. <end>",
#  '<start> This is good to know. <end>',
#  '<start> Tom has a laid-back personality. <end>',
#  '<start> Where is Tom buried? <end>',
#  '<start> This is a real surprise. <end>',
#  "<start> Aren't you satisfied? <end>",
#  "<start> I don't believe you. <end>",
#  '<start> I know the feeling. <end>',
#  "<start> He'll return at six. <end>",
#  '<start> Take a look at that. <end>',
#  '<start> Can you read this manuscript? <end>',
#  '<start> I need a room. <end>',
#  "<start> She's busy. <end>",
#  '<start> I really like your work. <end>',
#  '<start> I did my best. <end>',
#  '<start> I had a great teacher. <end>',
#  '<start> I know the potential consequences. <end>',
#  '<start> The sky is cloudy today. <end>',
#  '<start> Tom is staying. <end>',
#  "<start> I'll do better this time. <end>",
#  '<start> They struggled. <end>',
#  '<start> Are you still interested? <end>',
#  "<start> Who's your teacher? <end>",
#  '<start> It was sunny yesterday. <end>',
#  '<start> He ripped his shirt open. <end>',
#  "<start> We're in trouble. <end>",
#  '<start> It was amazing. <end>',
#  "<start> Will six o'clock suit you? <end>",
#  '<start> My brother is an idiot. <end>',
#  '<start> Tom is important. <end>',
#  '<start> She let the secret out. <end>',
#  '<start> Are you hungry now? <end>',
#  '<start> I made a deal. <end>',
#  '<start> I have a wife. <end>',
#  '<start> Do you have one? <end>',
#  "<start> I can't wait. <end>",
#  '<start> She put on socks. <end>',
#  '<start> Can you forgive me? <end>',
#  '<start> We just got here. <end>',
#  '<start> Did you empty the dishwasher? <end>',
#  '<start> They left. <end>',
#  '<start> My cat is black. <end>',
#  "<start> I'll solve that problem. <end>",
#  "<start> They're Christians. <end>",
#  '<start> Let Tom decide. <end>',
#  '<start> The crowd cheered. <end>',
#  '<start> My brother works in France. <end>',
#  '<start> Do you have any grandchildren? <end>',
#  '<start> It was an extraordinary year. <end>',
#  '<start> Check that. <end>',
#  '<start> Here is my key. <end>',
#  '<start> Is your gun loaded? <end>',
#  '<start> Give me a second chance. <end>',
#  '<start> Can you speak English? <end>',
#  "<start> That's my umbrella. <end>",
#  "<start> Tom didn't notice a thing. <end>",
#  '<start> Do you wear glasses? <end>',
#  "<start> How'd you do it? <end>",
#  '<start> I work for Tom. <end>',
#  '<start> Do you actually live here? <end>',
#  '<start> Bring me something to eat. <end>',
#  '<start> Are you actually threatening me? <end>',
#  '<start> I make the rules. <end>',
#  '<start> You are welcome here. <end>',
#  '<start> Tom waited a while. <end>',
#  '<start> Here comes our teacher. <end>',
#  "<start> I don't like to lose. <end>",
#  "<start> Don't push this button. <end>",
#  "<start> I'm early. <end>",
#  "<start> Nobody's going to hire you. <end>",
#  '<start> I rewrote it. <end>',
#  "<start> He's in pain. <end>",
#  '<start> Tom looks very anxious. <end>',
#  "<start> It's an inside joke. <end>",
#  '<start> I made reservations. <end>',
#  '<start> I love apples. <end>',
#  '<start> Tom must be proud. <end>',
#  "<start> It's a coincidence. <end>",
#  '<start> Follow my advice. <end>',
#  "<start> He's leaving for Tokyo tomorrow. <end>",
#  '<start> Do you actually believe this? <end>',
#  '<start> Why were you so slow? <end>',
#  "<start> That's why I called. <end>",
#  '<start> I followed the recipe. <end>',
#  '<start> I found that fascinating. <end>',
#  '<start> Tom is close to thirty. <end>',
#  '<start> This contract is totally ridiculous. <end>',
#  '<start> I missed my train. <end>',
#  '<start> Tom keeps his word. <end>',
#  '<start> The class went wild. <end>',
#  '<start> I thought you were kidding. <end>',
#  '<start> No one is at fault. <end>',
#  '<start> I like sweets. <end>',
#  "<start> Let's see what happens. <end>",
#  '<start> I started that. <end>',
#  "<start> Tom wasn't sure. <end>",
#  '<start> Tom is a shrewd businessman. <end>',
#  '<start> We must destroy the evidence. <end>',
#  '<start> Tom corrected himself. <end>',
#  '<start> Control yourself! <end>',
#  "<start> They're able to sing. <end>",
#  '<start> What have I told you? <end>',
#  '<start> Be proud of yourself. <end>',
#  "<start> They wouldn't have recognized Tom. <end>",
#  '<start> Take off your clothes. <end>',
#  "<start> I'm laying you off. <end>",
#  "<start> They're useless. <end>",
#  '<start> I was at school. <end>',
#  "<start> I'm a little bit hungry. <end>",
#  '<start> I have to find that. <end>',
#  "<start> You'll be perfect for this. <end>",
#  '<start> You have many books. <end>',
#  "<start> It's not my business. <end>",
#  '<start> I like it that way. <end>',
#  '<start> Do as you want. <end>',
#  '<start> I love to party. <end>',
#  "<start> This is what'll happen. <end>",
#  '<start> We carried out that plan. <end>',
#  "<start> I'm shocked. <end>",
#  '<start> Do you want some candy? <end>',
#  '<start> They have already begun. <end>',
#  '<start> Let me handle it. <end>',
#  '<start> It was only a dream. <end>',
#  '<start> I really misjudged you. <end>',
#  '<start> The worst is already over. <end>',
#  '<start> What are you playing with? <end>',
#  "<start> That's no longer allowed. <end>",
#  '<start> They were soldiers. <end>',
#  '<start> This is silly. <end>',
#  '<start> It has no parallel. <end>',
#  "<start> Now everything's going smoothly. <end>",
#  '<start> Who exactly were they? <end>',
#  "<start> I'll prove it to you. <end>",
#  "<start> He doesn't listen to me. <end>",
#  '<start> I was studying. <end>',
#  '<start> Call a plumber. <end>',
#  "<start> How's everything going? <end>",
#  "<start> They're looking for Tom. <end>",
#  '<start> You caught me off-guard. <end>',
#  '<start> I am not going anywhere. <end>',
#  '<start> Do you have any evidence? <end>',
#  '<start> I have plenty of friends. <end>',
#  "<start> Let's proceed. <end>",
#  '<start> I am interested in swimming. <end>',
#  '<start> I want to workout. <end>',
#  '<start> I bought a watch. <end>',
#  '<start> Can you guys understand Tom? <end>',
#  '<start> He heard a noise. <end>',
#  '<start> He likes hunting. <end>',
#  '<start> Here is my bicycle. <end>',
#  '<start> Could we talk in private? <end>',
#  '<start> When was she born? <end>',
#  '<start> Give it to me straight. <end>',
#  '<start> Tom hated that. <end>',
#  "<start> I wasn't competitive enough. <end>",
#  '<start> You saved us all. <end>',
#  '<start> Get in the car. <end>',
#  '<start> He looks like your brother. <end>',
#  '<start> Tom is aggressive. <end>',
#  '<start> My joints ache. <end>',
#  '<start> Nobody answered. <end>',
#  '<start> He suddenly fell ill. <end>',
#  '<start> How do I eat this? <end>',
#  "<start> We're standing. <end>",
#  "<start> You're not very funny. <end>",
#  '<start> Tom is a history teacher. <end>',
#  '<start> I was unharmed. <end>',
#  '<start> What is that? <end>',
#  '<start> My idea was much better. <end>',
#  '<start> They had different ideas. <end>',
#  '<start> What is art? <end>',
#  '<start> We all have flaws. <end>',
#  '<start> He is a good doctor. <end>',
#  '<start> The food is good. <end>',
#  "<start> We're back early. <end>",
#  '<start> Do you have a passport? <end>',
#  '<start> It makes all the difference. <end>',
#  '<start> Would that make you happy? <end>',
#  '<start> We got too close. <end>',
#  '<start> Recess ended. <end>',
#  "<start> Don't sell yourself short. <end>",
#  '<start> Lunch is included. <end>',
#  '<start> The result was disappointing. <end>',
#  '<start> You have no idea. <end>',
#  "<start> I'll never forget this experience. <end>",
#  '<start> Can he speak English? <end>',
#  '<start> Everyone knew that. <end>',
#  '<start> I no longer live here. <end>',
#  '<start> We made the decision together. <end>',
#  '<start> I really like garlic. <end>',
#  '<start> I have a girlfriend. <end>',
#  '<start> All men are created equal. <end>',
#  "<start> That's the one we want. <end>",
#  "<start> I'm considering resigning. <end>",
#  '<start> The fog has lifted. <end>',
#  '<start> He needs the money. <end>',
#  '<start> This is unfortunate. <end>',
#  '<start> How are we feeling today? <end>',
#  '<start> How much should they get? <end>',
#  "<start> It's not that deep. <end>",
#  '<start> Get me some coffee. <end>',
#  '<start> Did I hurt his feelings? <end>',
#  '<start> Do your very best. <end>',
#  '<start> The bird spread its wings. <end>',
#  "<start> I didn't cheat. <end>",
#  '<start> I put on my trousers. <end>',
#  "<start> You've got a cute friend. <end>",
#  '<start> Show me your hand. <end>',
#  '<start> My work is almost finished. <end>',
#  '<start> Could you drive more slowly? <end>',
#  "<start> They're out of their minds. <end>",
#  "<start> It's really awesome. <end>",
#  '<start> Is it safe? <end>',
#  '<start> Are you waiting for something? <end>',
#  '<start> Stop me if you can. <end>',
#  '<start> Tom solved the mystery. <end>',
#  '<start> Do you have paper? <end>',
#  '<start> Excuse me? <end>',
#  '<start> What did they expect? <end>',
#  '<start> He accepted reluctantly. <end>',
#  '<start> The rumor was without foundation. <end>',
#  '<start> They questioned him. <end>',
#  '<start> Is it yours? <end>',
#  '<start> Be nice. <end>',
#  "<start> I'm allowing you to go. <end>",
#  '<start> This building is ancient. <end>',
#  '<start> Electricity is very useful. <end>',
#  "<start> We're just nervous. <end>",
#  '<start> Can you beat that? <end>',
#  '<start> Tom turned his headlights off. <end>',
#  '<start> My brother polished the silver. <end>',
#  '<start> You promised. <end>',
#  '<start> Tom left for Australia. <end>',
#  "<start> I'll sleep on the couch. <end>",
#  '<start> You seem happy. <end>',
#  "<start> They're nice guys. <end>",
#  '<start> Your fly is open! <end>',
#  '<start> What happened to the dog? <end>',
#  '<start> We all have our secrets. <end>',
#  '<start> Mary is extremely attractive. <end>',
#  '<start> This is our home. <end>',
#  '<start> Tom is preparing dinner. <end>',
#  "<start> But I wasn't afraid. <end>",
#  '<start> I went inside. <end>',
#  '<start> The doors are shut. <end>',
#  '<start> When will he come? <end>',
#  "<start> That's very good news. <end>",
#  '<start> Wipe your face clean. <end>',
#  '<start> I know how to win. <end>',
#  '<start> You pay me very well. <end>',
#  "<start> I'm sore all over. <end>",
#  "<start> That's a sign. <end>",
#  '<start> Tom was proud of you. <end>',
#  '<start> We just got here. <end>',
#  '<start> You need to work together. <end>',
#  "<start> Let's split the bill. <end>",
#  "<start> I'm the boss. <end>",
#  "<start> I've had a busy morning. <end>",
#  '<start> This movie is rated R. <end>',
#  '<start> This is my favorite part. <end>',
#  '<start> She cried bitterly. <end>',
#  '<start> She looks like a teacher. <end>',
#  '<start> Is that your cat? <end>',
#  '<start> Are you being followed? <end>',
#  '<start> I know what to say. <end>',
#  '<start> Tom nodded quickly. <end>',
#  '<start> Please sit. <end>',
#  '<start> Tom arrived at midnight. <end>',
#  '<start> The fuse has blown. <end>',
#  '<start> I was wrong. <end>',
#  '<start> Are you productive? <end>',
#  '<start> I love to cook. <end>',
#  '<start> Tom is a doctor. <end>',
#  "<start> Don't be so silly. <end>",
#  '<start> He saved us all. <end>',
#  '<start> She took me by surprise. <end>',
#  "<start> Don't ask me for money. <end>",
#  "<start> I'll write to you soon. <end>",
#  '<start> There you are. <end>',
#  '<start> I let the cat in. <end>',
#  '<start> A whale is a mammal. <end>',
#  '<start> Keep an eye on him. <end>',
#  '<start> I love a challenge. <end>',
#  '<start> A man must be honest. <end>',
#  '<start> Unemployment is rising. <end>',
#  '<start> I was very nervous. <end>',
#  '<start> Our guests are arriving. <end>',
#  '<start> I often read. <end>',
#  '<start> Today is September first. <end>',
#  '<start> I feel protected. <end>',
#  '<start> You can go there. <end>',
#  '<start> Do you remember? <end>',
#  '<start> She was aching all over. <end>',
#  '<start> Can we prove it? <end>',
#  '<start> He bit his lip. <end>',
#  '<start> Please give me the letter. <end>',
#  '<start> Her mother always accompanies her. <end>',
#  '<start> He looked for the key. <end>',
#  "<start> That's ugly. <end>",
#  '<start> Why were you in prison? <end>',
#  '<start> Did you sleep all right? <end>',
#  '<start> He has the Joker. <end>',
#  '<start> Good job! <end>',
#  '<start> Tom is a billionaire. <end>',
#  '<start> Be calm. <end>',
#  '<start> They live downstairs. <end>',
#  '<start> Make an offer. <end>',
#  '<start> Could I change rooms? <end>',
#  '<start> Did you invite him? <end>',
#  '<start> Playing cards is interesting. <end>',
#  "<start> I don't buy that. <end>",
#  '<start> How would you translate it? <end>',
#  '<start> I got fined. <end>',
#  '<start> This is getting awkward. <end>',
#  '<start> I must insist. <end>',
#  '<start> She lives in comfort. <end>',
#  "<start> We don't like rain. <end>",
#  '<start> Tom is an HR consultant. <end>',
#  "<start> It's too early. <end>",
#  '<start> Who ordered that? <end>',
#  '<start> The system worked. <end>',
#  "<start> The baby's sleeping. <end>",
#  '<start> A gentle wind is blowing. <end>',
#  '<start> You have a good lawyer. <end>',
#  '<start> Did you miss me? <end>',
#  '<start> Why did Tom want it? <end>',
#  '<start> I have a bad cold. <end>',
#  '<start> What would you call that? <end>',
#  '<start> Be kind. <end>',
#  '<start> What can you teach me? <end>',
#  '<start> They are watching a movie. <end>',
#  '<start> Tom, you should see this. <end>',
#  '<start> It was superb. <end>',
#  "<start> I'm not denying that. <end>",
#  '<start> That serves you right. <end>',
#  "<start> It's not right. <end>",
#  "<start> It's just a fad. <end>",
#  '<start> You are blushing. <end>',
#  '<start> How did you make it? <end>',
#  "<start> You've missed the boat. <end>",
#  '<start> Is this natural? <end>',
#  '<start> They do that sometimes. <end>',
#  '<start> Help yourself, please. <end>',
#  '<start> Open the door. <end>',
#  '<start> The fuel gauge is broken. <end>',
#  '<start> I was very tired. <end>',
#  "<start> Let's get married. <end>",
#  '<start> Why are they so upset? <end>',
#  '<start> The water pipe burst. <end>',
#  "<start> I'm weak. <end>",
#  '<start> I called you. <end>',
#  '<start> The war lasted two years. <end>',
#  '<start> How did the exam go? <end>',
#  '<start> I hope Tom says no. <end>',
#  "<start> We're in pain. <end>",
#  '<start> Tom has passed away. <end>',
#  '<start> They are all alike. <end>',
#  "<start> I don't have any friends. <end>",
#  "<start> We've been warned. <end>",
#  '<start> That man is strong. <end>',
#  "<start> That's a strange question. <end>",
#  '<start> Nobody came. <end>',
#  '<start> What a strange man! <end>',
#  '<start> Do you like horror movies? <end>',
#  '<start> Do your own job. <end>',
#  '<start> She also speaks French. <end>',
#  '<start> I love winter. <end>',
#  '<start> When were you born? <end>',
#  "<start> You're the oldest. <end>",
#  "<start> That's hardly believable. <end>",
#  "<start> We could've made a fortune. <end>",
#  "<start> I'm living in the city. <end>",
#  '<start> Get on your knees. <end>',
#  "<start> I'm willing to help him. <end>",
#  '<start> They canceled. <end>',
#  '<start> She gave him a sweater. <end>',
#  "<start> We can't win. <end>",
#  '<start> Tom bought a Japanese-Chinese dictionary. <end>',
#  '<start> Drive carefully. <end>',
#  '<start> The long wait is over. <end>',
#  "<start> You're safe. <end>",
#  '<start> Please open the window. <end>',
#  '<start> You were happy. <end>',
#  "<start> He's a professional photographer. <end>",
#  '<start> You sound nervous. <end>',
#  "<start> They're mine. <end>",
#  "<start> I'll go now. <end>",
#  '<start> Did you enjoy that? <end>',
#  "<start> You're a good man. <end>",
#  '<start> My father is not talkative. <end>',
#  '<start> Please be careful. <end>',
#  '<start> Is he dead? <end>',
#  '<start> I hate you. <end>',
#  '<start> He wants that a lot. <end>',
#  "<start> They're going to try. <end>",
#  '<start> Your behavior was disgraceful. <end>',
#  "<start> I'm a medic. <end>",
#  '<start> She apologized for her delay. <end>',
#  "<start> There's no harm in trying. <end>",
#  '<start> We made friends with them. <end>',
#  '<start> Hands off. <end>',
#  "<start> It's only money. <end>",
#  '<start> The company abandoned that project. <end>',
#  '<start> This is a misunderstanding. <end>',
#  '<start> Let me put something on. <end>',
#  '<start> She did it again. <end>',
#  '<start> Look out! <end>',
#  '<start> Watch out! <end>',
#  "<start> We're plastered. <end>",
#  "<start> I'm worried about the future. <end>",
#  '<start> Jump. <end>',
#  '<start> My children like school. <end>',
#  "<start> We're broke. <end>",
#  '<start> You have a bright future. <end>',
#  '<start> She sells vegetables. <end>',
#  '<start> Stay away from that. <end>',
#  "<start> Tom can't win. <end>",
#  '<start> Are you sleepy? <end>',
#  '<start> You can do that. <end>',
#  '<start> Who wants that? <end>',
#  "<start> It's disappointing. <end>",
#  '<start> I need you right now. <end>',
#  '<start> Are you still not convinced? <end>',
#  '<start> Give me a ring tomorrow. <end>',
#  '<start> Can you find out? <end>',
#  '<start> What can you see? <end>',
#  "<start> That's a shame. <end>",
#  '<start> I will stop you. <end>',
#  '<start> You need to do this. <end>',
#  "<start> It's dangerous to play here. <end>",
#  '<start> What a nerve! <end>',
#  '<start> These are probably yours. <end>',
#  '<start> We have a relationship. <end>',
#  "<start> They're bad. <end>",
#  '<start> That was only the beginning. <end>',
#  "<start> I'm not eating this. <end>",
#  "<start> He's not in. <end>",
#  '<start> Whose turn is it next? <end>',
#  "<start> I've heard the rumor. <end>",
#  '<start> I caught it. <end>',
#  "<start> You're very shy. <end>",
#  '<start> Would you like another beer? <end>',
#  "<start> I hope he's wrong. <end>",
#  '<start> It was an amazing experience. <end>',
#  "<start> Let's not exaggerate the facts. <end>",
#  '<start> How much should they get? <end>',
#  '<start> Were you successful? <end>',
#  "<start> We didn't kiss. <end>",
#  "<start> Do you think I'm joking? <end>",
#  '<start> Your necklace is beautiful. <end>',
#  '<start> He got ahead of me. <end>',
#  '<start> Tom has chosen you. <end>',
#  "<start> I don't believe that. <end>",
#  '<start> We need a volunteer. <end>',
#  '<start> They have been busy. <end>',
#  '<start> He failed the exam. <end>',
#  '<start> How are things coming along? <end>',
#  '<start> Excuse me a minute. <end>',
#  '<start> This is just a paperweight. <end>',
#  '<start> I want to be noticed. <end>',
#  "<start> I don't have an alibi. <end>",
#  '<start> I am right. <end>',
#  '<start> They went crazy. <end>',
#  "<start> Don't move. <end>",
#  '<start> Traffic is bad today. <end>',
#  '<start> Anything could happen. <end>',
#  '<start> This is my old bicycle. <end>',
#  '<start> The poor girl went blind. <end>',
#  '<start> Tie your shoe. <end>',
#  '<start> She recognized him immediately. <end>',
#  '<start> Is that a fact? <end>',
#  "<start> I'm doing this for them. <end>",
#  '<start> Her older daughter is married. <end>',
#  '<start> You are impossible. <end>',
#  '<start> Tom is already back. <end>',
#  '<start> I let you catch me. <end>',
#  '<start> Put on the hat. <end>',
#  "<start> You're mean. <end>",
#  '<start> He showed her the way. <end>',
#  "<start> You're a survivor. <end>",
#  "<start> There isn't any food left. <end>",
#  '<start> You have to keep fit. <end>',
#  "<start> I'm extroverted. <end>",
#  "<start> You're the teacher. <end>",
#  '<start> He has a hairy chest. <end>',
#  "<start> You're really absent-minded. <end>",
#  "<start> He'll never beat me. <end>",
#  "<start> Tom's left. <end>",
#  "<start> I've lost my glasses. <end>",
#  '<start> You never gave up. <end>',
#  '<start> Let me think about that. <end>',
#  "<start> I didn't shoot anyone. <end>",
#  '<start> Are you a golfer? <end>',
#  '<start> The bus was almost empty. <end>',
#  "<start> You're overreacting. <end>",
#  '<start> Her hair is turning gray. <end>',
#  '<start> We made friends with them. <end>',
#  '<start> Get off my back! <end>',
#  "<start> You're surrounded. <end>",
#  '<start> Can you make a salad? <end>',
#  '<start> Do you have any pencils? <end>',
#  '<start> I enjoy a challenge. <end>',
#  '<start> Is it clear? <end>',
#  '<start> I kept my mouth shut. <end>',
#  '<start> She abandoned her children. <end>',
#  "<start> Who's dieting? <end>",
#  '<start> Their meeting was inevitable. <end>',
#  "<start> I'm staying. <end>",
#  "<start> Don't try to fool me. <end>",
#  '<start> All the seats are booked. <end>',
#  '<start> I saw him naked. <end>',
#  "<start> You're a prisoner. <end>",
#  "<start> You're not alone. <end>",
#  '<start> Write with your left hand. <end>',
#  "<start> You've grown up, Tom. <end>",
#  '<start> Shame on you. <end>',
#  '<start> He seems tired. <end>',
#  "<start> That's actually pretty cool. <end>",
#  '<start> I heard the good news. <end>',
#  '<start> Was this your idea? <end>',
#  '<start> This is too much. <end>',
#  "<start> He's right behind you. <end>",
#  '<start> I like classical music. <end>',
#  '<start> They refused. <end>',
#  '<start> She became pregnant. <end>',
#  '<start> The fire alarm rang. <end>',
#  '<start> Had you been drinking? <end>',
#  '<start> Tom seems to be objective. <end>',
#  '<start> Are you registered? <end>',
#  "<start> That's a constructive suggestion! <end>",
#  '<start> This hat is mine. <end>',
#  "<start> You're not that interesting. <end>",
#  '<start> It was long. <end>',
#  '<start> You are not a coward. <end>',
#  '<start> I always keep my word. <end>',
#  '<start> We can talk outside. <end>',
#  '<start> There is little water left. <end>',
#  '<start> They want this. <end>',
#  '<start> Hurry up. <end>',
#  '<start> He gave in. <end>',
#  '<start> Follow me. <end>',
#  '<start> We worked together. <end>',
#  '<start> Do you have them? <end>',
#  "<start> Don't light the candle. <end>",
#  "<start> I'm sincere. <end>",
#  '<start> You are a good person. <end>',
#  '<start> It was really overpriced. <end>',
#  '<start> I was in charge. <end>',
#  '<start> Stay right there. <end>',
#  "<start> Who's talking? <end>",
#  '<start> I can do it. <end>',
#  '<start> What causes that? <end>',
#  '<start> There were no jobs. <end>',
#  '<start> Are you watching your weight? <end>',
#  '<start> As a result, prices rose. <end>',
#  '<start> Catch him. <end>',
#  '<start> Where is your money? <end>',
#  '<start> It would be perfect. <end>',
#  '<start> Can you light the way? <end>',
#  '<start> No one is amused. <end>',
#  '<start> Knock on the door. <end>',
#  '<start> Please bill us separately. <end>',
#  '<start> She cried bitterly. <end>',
#  '<start> They smiled at each other. <end>',
#  "<start> It's the next logical step. <end>",
#  '<start> No one does that. <end>',
#  '<start> I party too much. <end>',
#  '<start> I looked in the cupboard. <end>',
#  '<start> Get ready for some action. <end>',
#  '<start> My wife is a vegetarian. <end>',
#  '<start> Put it on the wall. <end>',
#  '<start> Times are changing. <end>',
#  '<start> No Canadians were injured. <end>',
#  '<start> This case is important. <end>',
#  "<start> You're very forward. <end>",
#  '<start> I have a sore knee. <end>',
#  "<start> He's sexy. <end>",
#  '<start> The woman is naked. <end>',
#  "<start> You're very timid. <end>",
#  '<start> She sleeps with two pillows. <end>',
#  '<start> I was here first. <end>',
#  '<start> Tom is a good person. <end>',
#  '<start> She grew roses. <end>',
#  '<start> My children are adults now. <end>',
#  '<start> I let the team down. <end>',
#  '<start> No need to worry. <end>',
#  "<start> I'll arrange it. <end>",
#  '<start> How are we feeling today? <end>',
#  '<start> Did you get enough sleep? <end>',
#  '<start> Tom became a Catholic. <end>',
#  "<start> You're very forward. <end>",
#  '<start> Is anybody home? <end>',
#  '<start> We chartered a bus. <end>',
#  '<start> We have to do this. <end>',
#  '<start> How exciting! <end>',
#  '<start> Tom loves Mary. <end>',
#  '<start> He was a bookkeeper. <end>',
#  '<start> Where are the police? <end>',
#  '<start> Catch Tom. <end>',
#  "<start> You're very sophisticated. <end>",
#  '<start> It was extremely simple. <end>',
#  '<start> She is aggressive. <end>',
#  '<start> I want you to talk. <end>',
#  '<start> I had second thoughts. <end>',
#  '<start> My stepfather was diabetic. <end>',
#  '<start> Where are the forks? <end>',
#  '<start> He is always joking. <end>',
#  "<start> That's something of an understatement. <end>",
#  '<start> I own this car. <end>',
#  '<start> Tom hates sports. <end>',
#  '<start> She liked that. <end>',
#  '<start> Get my rifle. <end>',
#  "<start> Your opinion doesn't matter. <end>",
#  '<start> Fortunately, the weather was good. <end>',
#  '<start> Everybody does that. <end>',
#  '<start> He has a square jaw. <end>',
#  '<start> What do you mean? <end>',
#  '<start> Are they satisfied? <end>',
#  '<start> What are the symptoms? <end>',
#  '<start> He was outraged. <end>',
#  '<start> I want many things. <end>',
#  '<start> The banks are closed today. <end>',
#  "<start> I'm afraid of flying. <end>",
#  '<start> When will you stop scheming? <end>',
#  '<start> We like Tom. <end>',
#  '<start> Would you like one? <end>',
#  '<start> Can I change the channel? <end>',
#  '<start> No investigation is required. <end>',
#  "<start> I didn't mean it. <end>",
#  '<start> This is for my friend. <end>',
#  '<start> I just got a job. <end>',
#  '<start> Flashy people irritate him. <end>',
#  '<start> Where exactly did you go? <end>',
#  "<start> I'll leave you to it. <end>",
#  "<start> We'll be happy to cooperate. <end>",
#  '<start> Do you want a car? <end>',
#  "<start> You're arrogant. <end>",
#  '<start> She aimed at the target. <end>',
#  "<start> You've got a great memory. <end>",
#  '<start> Take everything. <end>',
#  '<start> Fetch me my hat. <end>',
#  '<start> No one saw anything. <end>',
#  '<start> Tom is always joking. <end>',
#  '<start> I cried all morning. <end>',
#  '<start> This flashlight is getting dim. <end>',
#  '<start> I know where she is. <end>',
#  "<start> I didn't do anything illegal. <end>",
#  '<start> Please relax. <end>',
#  '<start> He is sadly mistaken. <end>',
#  "<start> It's a rumor. <end>",
#  "<start> It's a beautiful job. <end>",
#  "<start> I'll go anyway. <end>",
#  '<start> What did you just say? <end>',
#  '<start> The rooms are deserted. <end>',
#  '<start> How are you all? <end>',
#  "<start> What's worrying you? <end>",
#  '<start> Are you hurt? <end>',
#  '<start> I never use this anymore. <end>',
#  '<start> I made breakfast. <end>',
#  '<start> I learned something today. <end>',
#  '<start> Do you want children? <end>',
#  "<start> You're off the hook. <end>",
#  "<start> Don't lose sleep over that. <end>",
#  '<start> Coffee, please. <end>',
#  "<start> Don't cheat. <end>",
#  "<start> You're incredibly talented. <end>",
#  "<start> I'm able to ski. <end>",
#  '<start> We all lie. <end>',
#  '<start> He has an intriguing personality. <end>',
#  '<start> She kissed him. <end>',
#  '<start> It tasted sweet. <end>',
#  '<start> This is your dog. <end>',
#  "<start> You're very timid. <end>",
#  '<start> That did occur to me. <end>',
#  "<start> Tom isn't bothering me. <end>",
#  '<start> Take a rest. <end>',
#  "<start> Mary's husband abused her. <end>",
#  '<start> We train together. <end>',
#  "<start> Everybody's having a good time. <end>",
#  '<start> I could intervene. <end>',
#  '<start> That sounds very tempting. <end>',
#  "<start> I'm not insane. <end>",
#  '<start> I run every morning. <end>',
#  '<start> This is wrong. <end>',
#  "<start> It's really infuriating. <end>",
#  '<start> What did you say? <end>',
#  '<start> Buy low, sell high. <end>',
#  "<start> Let's ask a travel agent. <end>",
#  '<start> That took guts. <end>',
#  "<start> I'll do all the talking. <end>",
#  '<start> I want that blue jacket. <end>',
#  "<start> It's nothing I can't handle. <end>",
#  '<start> Why were you fired? <end>',
#  "<start> Somebody's waiting for you. <end>",
#  "<start> I'll stay here. <end>",
#  '<start> My mother was furious. <end>',
#  '<start> They were busy. <end>',
#  '<start> Were you really angry? <end>',
#  '<start> This is not our problem. <end>',
#  '<start> Can I speak to you? <end>',
#  '<start> Give me some milk. <end>',
#  '<start> Yesterday was a good day. <end>',
#  '<start> Do your own job. <end>',
#  "<start> We'll do it together. <end>",
#  '<start> He often quotes from Shakespeare. <end>',
#  "<start> Don't look down on others. <end>",
#  "<start> It's a true story. <end>",
#  '<start> It has rained since yesterday. <end>',
#  '<start> No money was stolen. <end>',
#  '<start> This is our house. <end>',
#  '<start> This is not happening. <end>',
#  "<start> We're smart. <end>",
#  '<start> He decided to quit smoking. <end>',
#  '<start> This is going very well. <end>',
#  "<start> I'll never deceive you. <end>",
#  "<start> I'm disorganized. <end>",
#  '<start> That one is really good. <end>',
#  '<start> You are very brave. <end>',
#  '<start> She shook hands with him. <end>',
#  '<start> Were you even tempted? <end>',
#  '<start> Read it to me. <end>',
#  '<start> Let me handle this. <end>',
#  "<start> You're psyched. <end>",
#  '<start> We lost our chance. <end>',
#  '<start> We saw you. <end>',
#  "<start> Don't tell anyone this. <end>",
#  '<start> Mary is a single mom. <end>',
#  "<start> Tom didn't leave Mary. <end>",
#  '<start> I need your help. <end>',
#  '<start> Is the water deep? <end>',
#  '<start> Who kissed you? <end>',
#  '<start> Come immediately. <end>',
#  '<start> There were 30 survivors. <end>',
#  '<start> Are these your daughters? <end>',
#  "<start> He's a bit tipsy. <end>",
#  "<start> That's how it was. <end>",
#  '<start> Do you have enough energy? <end>',
#  '<start> Everything has a price. <end>',
#  "<start> What're you talking about? <end>",
#  '<start> Is something happening? <end>',
#  '<start> Are you relaxed? <end>',
#  '<start> They released the prisoner. <end>',
#  '<start> Everybody loves him. <end>',
#  '<start> I want some potatoes. <end>',
#  '<start> I risked everything. <end>',
#  "<start> I'm unhappy. <end>",
#  '<start> I have time. <end>',
#  '<start> I lit the candle. <end>',
#  "<start> Who's in control? <end>",
#  "<start> This computer doesn't work. <end>",
#  '<start> What do you need? <end>',
#  '<start> The basket was empty. <end>',
#  "<start> I'm not going. <end>",
#  "<start> Where's the phone? <end>",
#  '<start> I feel so helpless. <end>',
#  '<start> I stopped smoking. <end>',
#  '<start> I freaked out. <end>',
#  "<start> You're trustworthy. <end>",
#  '<start> Why are you so concerned? <end>',
#  '<start> Dogs are barking. <end>',
#  '<start> Keep up with the times. <end>',
#  '<start> They asked us for advice. <end>',
#  "<start> It's one of mine. <end>",
#  '<start> I made a decision. <end>',
#  "<start> That's only a temporary solution. <end>",
#  '<start> I was happy there. <end>',
#  "<start> You aren't my mother. <end>",
#  '<start> Nobody can help you. <end>',
#  "<start> It's an excellent wine. <end>",
#  '<start> Did I hurt your feelings? <end>',
#  "<start> We're leaving here. <end>",
#  '<start> Do you really mean it? <end>',
#  "<start> Don't tease me. <end>",
#  '<start> Did I hurt you? <end>',
#  "<start> I've had coffee already. <end>",
#  '<start> I am a college student. <end>',
#  "<start> I'll be nice. <end>",
#  '<start> Tom really loves his country. <end>',
#  '<start> You like everyone. <end>',
#  '<start> Are they dead? <end>',
#  '<start> Your French is improving. <end>',
#  "<start> It'll happen. <end>",
#  '<start> They have an extra bed. <end>',
#  '<start> This is my bicycle. <end>',
#  '<start> I study Japanese history. <end>',
#  '<start> That street is very noisy. <end>',
#  '<start> I feel really proud. <end>',
#  '<start> I trust you. <end>',
#  '<start> Tom loves you all. <end>',
#  '<start> He has brown eyes. <end>',
#  "<start> I've got them all. <end>",
#  "<start> I didn't write anything. <end>",
#  "<start> They should've noticed me. <end>",
#  '<start> No one will believe us. <end>',
#  '<start> She shrieked. <end>',
#  '<start> I missed a lot. <end>',
#  '<start> Run for it! <end>',
#  '<start> You look Japanese. <end>',
#  '<start> I saw him naked. <end>',
#  "<start> I'll wait here. <end>",
#  '<start> Tom never said no. <end>',
#  '<start> Can I see this? <end>',
#  '<start> I left the room. <end>',
#  "<start> That's really impressive. <end>",
#  '<start> This is extremely hard. <end>',
#  '<start> Tom and Mary were frightened. <end>',
#  '<start> Make me happy. <end>',
#  "<start> She's too loud. <end>",
#  '<start> A horse is an animal. <end>',
#  '<start> Do you like singing? <end>',
#  '<start> Why are you so stubborn? <end>',
#  '<start> Open the windows. <end>',
#  '<start> Is that normal? <end>',
#  '<start> I have to paint it. <end>',
#  '<start> I fixed it. <end>',
#  '<start> I do have one question. <end>',
#  '<start> I want to hear this. <end>',
#  '<start> I can still hear you. <end>',
#  '<start> I was really shocked. <end>',
#  '<start> He tricked me. <end>',
#  "<start> I'm not going. <end>",
#  '<start> The speaker is young. <end>',
#  "<start> I've got claustrophobia. <end>",
#  '<start> It was incredibly dangerous. <end>',
#  '<start> They were playing tennis. <end>',
#  '<start> They have already begun. <end>',
#  '<start> Tom was right after all. <end>',
#  "<start> I'm going to my sister's. <end>",
#  '<start> The experiment ended in failure. <end>',
#  '<start> He missed class. <end>',
#  "<start> It's a very difficult situation. <end>",
#  "<start> I'm too hungry to study. <end>",
#  '<start> Do you like fish? <end>',
#  '<start> Get away from me. <end>',
#  '<start> Tom just confessed. <end>',
#  '<start> Which browser are you using? <end>',
#  '<start> See you in the morning. <end>',
#  '<start> Tom works too much. <end>',
#  '<start> The challenges are enormous. <end>',
#  '<start> This is boring. <end>',
#  '<start> Take a wild guess. <end>',
#  '<start> I need time. <end>',
#  "<start> It's been raining since Monday. <end>",
#  '<start> I felt scared. <end>',
#  '<start> He was imprisoned. <end>',
#  '<start> We count everything. <end>',
#  '<start> She looked away terrified. <end>',
#  '<start> Listen to your mother. <end>',
#  '<start> Tom became weak. <end>',
#  '<start> I forgot my wallet. <end>',
#  "<start> I'm not hungry yet. <end>",
#  '<start> He proofread my manuscript. <end>',
#  '<start> I was disgusted. <end>',
#  '<start> I itch everywhere. <end>',
#  '<start> You have one hour. <end>',
#  '<start> My door is always open. <end>',
#  "<start> I'll drive Tom home. <end>",
#  "<start> They can't do that. <end>",
#  '<start> He seems to think so. <end>',
#  "<start> You're very understanding. <end>",
#  "<start> I don't like kids. <end>",
#  "<start> You don't look Japanese. <end>",
#  "<start> You're articulate. <end>",
#  '<start> Are your hands clean? <end>',
#  '<start> He seemed really nervous. <end>',
#  '<start> How may I help you? <end>',
#  "<start> We're staying. <end>",
#  '<start> You blew it, Tom. <end>',
#  "<start> It's not my problem anymore. <end>",
#  ...]

# %%
frence_valid = get_data(list(valid["French words/sentences"]))
frence_valid
# Out:
# ['<start> Occupe-toi de cet homme-là. <end>',
#  "<start> C'est inacceptable. <end>",
#  '<start> Elle pleurait de douleur. <end>',
#  "<start> Elles étaient fatiguées d'attendre. <end>",
#  "<start> Nous n'avons pas toujours raison. <end>",
#  '<start> Vous avez mon respect. <end>',
#  '<start> Il ramassa une pierre. <end>',
#  '<start> Vous aimez chanter ? <end>',
#  "<start> Ce n'était pas suffisant. <end>",
#  '<start> Établissons quelques règles de base. <end>',
#  '<start> Je le reprends. <end>',
#  '<start> Il adore les jouets. <end>',
#  '<start> Tom a retrouvé ta casquette. <end>',
#  '<start> Donnez-moi un exemple. <end>',
#  '<start> Tom fait une erreur. <end>',
#  "<start> C'était merveilleux, n'est-ce pas\xa0? <end>",
#  '<start> Tout est prêt ici. <end>',
#  '<start> Cela te tracasse-t-il ? <end>',
#  '<start> As-tu assez de temps ? <end>',
#  '<start> Tout le monde a attendu. <end>',
#  "<start> J'ai pris un bain. <end>",
#  '<start> Ce dictionnaire est à moi. <end>',
#  '<start> Le pont est fermé. <end>',
#  "<start> C'est inefficace. <end>",
#  '<start> Ma famille est petite. <end>',
#  '<start> Je deviens fou. <end>',
#  '<start> Tom verrouilla la porte. <end>',
#  '<start> Ne dites rien et écoutez. <end>',
#  '<start> Beaucoup de poissons ont péri. <end>',
#  "<start> Je n'aime pas ton sourire. <end>",
#  '<start> Il voulait me rencontrer. <end>',
#  '<start> Tom a fait un pèlerinage. <end>',
#  '<start> Nous devons le refaire. <end>',
#  '<start> Peux-tu ranger ta chambre\xa0? <end>',
#  '<start> Dis la vérité. <end>',
#  '<start> Tu es grossière. <end>',
#  "<start> As-tu de l'argent\u202f? <end>",
#  '<start> Ne bouge pas. <end>',
#  '<start> Le régime alimentaire est important. <end>',
#  "<start> C'était notre but. <end>",
#  '<start> Pourquoi êtes-vous assis là ? <end>',
#  '<start> Je suis plutôt occupé. <end>',
#  "<start> Tu n'es pas si malin. <end>",
#  '<start> Un seul homme survécut. <end>',
#  "<start> J'aurais dû dire non. <end>",
#  '<start> Je suis fatiguée de Boston. <end>',
#  "<start> J'admets avoir fait cela. <end>",
#  '<start> Il va probablement venir. <end>',
#  '<start> As-tu un violon\u202f? <end>',
#  '<start> Elle est dépourvue de manières. <end>',
#  "<start> Il n'était pas si gros. <end>",
#  '<start> Désolée, quelque chose a foiré. <end>',
#  '<start> Le Prince a été enlevé. <end>',
#  "<start> Ce n'est pas sûr. <end>",
#  '<start> Il est parti. <end>',
#  '<start> Je suis anéanti. <end>',
#  '<start> On se voit plus tard. <end>',
#  '<start> Tu ne sais rien. <end>',
#  '<start> Mange quelque chose ! <end>',
#  '<start> Pourquoi ce bébé pleure-t-il\xa0? <end>',
#  "<start> Je n'ai pas le vertige. <end>",
#  '<start> Nous tenterons. <end>',
#  "<start> Il ne perd jamais l'espoir. <end>",
#  "<start> Elle n'est jamais tombée amoureuse. <end>",
#  '<start> Que dit-elle ? <end>',
#  "<start> N'ai-je pas raison\u202f? <end>",
#  '<start> Nous ne sommes pas impliqués. <end>',
#  "<start> J'achèterai ça. <end>",
#  '<start> Tom a consolé Marie. <end>',
#  '<start> Vous sentez-vous en veine ? <end>',
#  '<start> Il me fit attendre. <end>',
#  '<start> Commencez-vous à être fatiguées ? <end>',
#  "<start> C'est très improbable. <end>",
#  '<start> Merci pour la soupe. <end>',
#  '<start> Il a beaucoup neigé hier. <end>',
#  "<start> Veux-tu t'arrêter ? <end>",
#  '<start> Comment va ta sœur\xa0? <end>',
#  '<start> À quoi suis-je confrontée ? <end>',
#  '<start> Vous êtes tellement difficile ! <end>',
#  '<start> Je pense souvent à vous. <end>',
#  "<start> Il me fallut de l'aide. <end>",
#  '<start> Vous avez été prévenue. <end>',
#  '<start> Elle a une belle écriture. <end>',
#  "<start> Elle l'a pincé. <end>",
#  '<start> Vous auriez pu tout gâcher. <end>',
#  "<start> J'ai grandi ici. <end>",
#  '<start> Vos idées sont les bienvenues. <end>',
#  "<start> C'est une chose heureuse. <end>",
#  '<start> Il te faut te contrôler. <end>',
#  '<start> Qui a été tué\xa0? <end>',
#  '<start> Ils me tueront. <end>',
#  "<start> J'adore cuisiner. <end>",
#  '<start> Pourriez-vous être plus précis\u202f? <end>',
#  '<start> Quand pouvez-vous commencer ? <end>',
#  '<start> Ma nana me manque vraiment. <end>',
#  '<start> As-tu bien dormi ? <end>',
#  '<start> Attachez votre ceinture. <end>',
#  "<start> Ils l'ont compris. <end>",
#  '<start> Je sais comment cela fonctionne. <end>',
#  '<start> Tom aida. <end>',
#  '<start> Je leur ai fait confiance. <end>',
#  '<start> Voulez-vous du café\u202f? <end>',
#  "<start> Sais-tu jouer d'un instrument ? <end>",
#  '<start> Attendez là. <end>',
#  '<start> Veux-tu boire ? <end>',
#  '<start> Il travaille dans une banque. <end>',
#  '<start> Je veux te remercier. <end>',
#  '<start> Tom parle rapidement. <end>',
#  '<start> Vous en savez trop. <end>',
#  '<start> Je vais être votre institutrice. <end>',
#  '<start> Je suis suffisamment forte. <end>',
#  '<start> Je compatis à votre douleur. <end>',
#  "<start> Je l'ai fait ainsi. <end>",
#  '<start> Personne ne nous crut. <end>',
#  '<start> Nous sommes comédiens. <end>',
#  '<start> Il a écrit une lettre. <end>',
#  '<start> Je paraphrasais. <end>',
#  "<start> J'ai employé mon imagination. <end>",
#  "<start> Rien n'est parfait. <end>",
#  '<start> Ils ont terminé 13e. <end>',
#  "<start> Je t'envoie un livre. <end>",
#  '<start> Vous êtes très attirants. <end>',
#  '<start> Tu es incroyable. <end>',
#  "<start> J'ai le dictionnaire. <end>",
#  '<start> Je veux manger quelque chose. <end>',
#  '<start> Il vous reste trois mois. <end>',
#  '<start> Avez-vous les clés ? <end>',
#  '<start> Pourquoi dites-vous adieu ? <end>',
#  "<start> J'ai besoin d'être seul. <end>",
#  '<start> Quand commencerez-vous\xa0? <end>',
#  '<start> Buvez-vous de la bière ? <end>',
#  "<start> C'est mon passage préféré. <end>",
#  "<start> C'est bon à savoir. <end>",
#  "<start> Tom est quelqu'un de décontracté. <end>",
#  '<start> Où Tom est-il enterré\xa0? <end>',
#  "<start> C'est une vraie surprise. <end>",
#  "<start> N'es-tu pas satisfait\xa0? <end>",
#  '<start> Je ne te crois pas. <end>',
#  '<start> Je connais ce sentiment. <end>',
#  '<start> Il reviendra à six heures. <end>',
#  '<start> Jette un œil là-dessus. <end>',
#  '<start> Peux-tu lire ce manuscrit ? <end>',
#  '<start> Il me faut une chambre. <end>',
#  '<start> Elle est occupée. <end>',
#  "<start> J'apprécie vraiment votre travail. <end>",
#  "<start> J'ai fait de mon mieux. <end>",
#  "<start> J'avais un excellent professeur. <end>",
#  '<start> Je connais les conséquences potentielles. <end>',
#  "<start> Le ciel est couvert aujourd'hui. <end>",
#  '<start> Tom reste. <end>',
#  '<start> Je ferai mieux cette fois. <end>',
#  '<start> Ils ont eu du mal. <end>',
#  '<start> Êtes-vous toujours intéressés ? <end>',
#  '<start> Qui est ton institutrice\u202f? <end>',
#  '<start> Le temps était ensoleillé hier. <end>',
#  '<start> Il a arraché sa chemise. <end>',
#  '<start> On est dans le pétrin. <end>',
#  "<start> C'était incroyable. <end>",
#  '<start> Six heures vous conviendrait-il\u202f? <end>',
#  '<start> Mon frère est un imbécile. <end>',
#  '<start> Tom est important. <end>',
#  '<start> Elle a divulgué le secret. <end>',
#  '<start> As-tu faim maintenant\u202f? <end>',
#  "<start> J'ai conclu un contrat. <end>",
#  "<start> J'ai une femme. <end>",
#  '<start> En as-tu un\u202f? <end>',
#  '<start> Je suis impatient. <end>',
#  '<start> Elle mit des chaussettes. <end>',
#  '<start> Pouvez-vous me pardonner\u202f? <end>',
#  "<start> Nous venons d'arriver ici. <end>",
#  '<start> As-tu vidé le lave-vaisselle ? <end>',
#  '<start> Elles sont parties. <end>',
#  '<start> Ma chatte est noire. <end>',
#  "<start> J'ai résolu le problème. <end>",
#  '<start> Ils sont chrétiens. <end>',
#  '<start> Laissez Tom décider. <end>',
#  '<start> La foule a applaudi. <end>',
#  '<start> Mon frère travaille en France. <end>',
#  '<start> Avez-vous des petits enfants ? <end>',
#  "<start> Ç'a été une année extraordinaire. <end>",
#  '<start> Vérifiez cela. <end>',
#  '<start> Voici ma clef. <end>',
#  '<start> Ton arme est-elle chargée\u202f? <end>',
#  '<start> Donne-moi une seconde chance. <end>',
#  '<start> Savez-vous parler anglais\u202f? <end>',
#  '<start> C’est mon parapluie. <end>',
#  "<start> Tom n'a rien remarqué. <end>",
#  '<start> Portes-tu des lunettes ? <end>',
#  '<start> Comment avez-vous fait ? <end>',
#  '<start> Je travaille pour Tom. <end>',
#  '<start> Vivez-vous réellement ici ? <end>',
#  '<start> Apporte-moi quelque chose à manger. <end>',
#  '<start> Me menaces-tu vraiment ? <end>',
#  '<start> Je décide des règles. <end>',
#  '<start> Tu es le bienvenue. <end>',
#  '<start> Tom a attendu un moment. <end>',
#  '<start> Voilà notre professeur. <end>',
#  "<start> Je n'aime pas perdre. <end>",
#  "<start> N'appuyez pas sur ce bouton. <end>",
#  '<start> Je suis en avance. <end>',
#  '<start> Personne ne va vous employer. <end>',
#  "<start> Je l'ai réécrit. <end>",
#  '<start> Il souffre. <end>',
#  '<start> Tom semble très anxieux. <end>',
#  "<start> C'est une blague d'initiés. <end>",
#  "<start> J'ai émis des reserves. <end>",
#  "<start> J'adore les pommes. <end>",
#  '<start> Tom doit être fier. <end>',
#  "<start> C'est une coïncidence. <end>",
#  '<start> Suivez mon conseil. <end>',
#  '<start> Il part pour Tokyo demain. <end>',
#  '<start> Crois-tu vraiment ça\xa0? <end>',
#  '<start> Pourquoi étais-tu si lent\xa0? <end>',
#  "<start> C'est pourquoi j'ai appelé. <end>",
#  '<start> Je suivis la recette. <end>',
#  "<start> J'ai trouvé cela fascinant. <end>",
#  '<start> Tom a environ trente ans. <end>',
#  '<start> Ce contrat est totalement ridicule. <end>',
#  "<start> J'ai manqué mon train. <end>",
#  '<start> Tom tient parole. <end>',
#  "<start> La classe s'est déchaînée. <end>",
#  "<start> J'ai pensé que vous plaisantiez. <end>",
#  "<start> Personne n'est fautif. <end>",
#  "<start> J'aime les sucreries. <end>",
#  '<start> Voyons voir ce qui arrive. <end>',
#  "<start> C'est moi qui ai commencé. <end>",
#  "<start> Tom n'était pas sûr. <end>",
#  '<start> Tom est habile en affaires. <end>',
#  '<start> Nous devons détruire les preuves. <end>',
#  '<start> Tom s’est corrigé lui-même. <end>',
#  '<start> Maîtrise-toi ! <end>',
#  '<start> Ils peuvent chanter. <end>',
#  '<start> Que vous ai-je dit ? <end>',
#  '<start> Soyez fière de vous. <end>',
#  "<start> Ils n'auraient pas reconnu Tom. <end>",
#  '<start> Ôte tes vêtements ! <end>',
#  '<start> Je vous licencie. <end>',
#  '<start> Elles sont inutiles. <end>',
#  "<start> J'étais à l'école. <end>",
#  "<start> J'ai un petit peu faim. <end>",
#  '<start> Je dois trouver ça. <end>',
#  '<start> Tu seras parfait pour ça. <end>',
#  '<start> Tu as beaucoup de livres. <end>',
#  "<start> Ce n'est pas mon affaire. <end>",
#  "<start> Je l'aime ainsi. <end>",
#  '<start> Faites comme ça vous chante. <end>',
#  "<start> J'adore faire la nouba. <end>",
#  "<start> C'est ce qui surviendra. <end>",
#  '<start> Nous exécutâmes ce plan. <end>',
#  '<start> Je suis choquée. <end>',
#  '<start> Voulez-vous un bonbon ? <end>',
#  '<start> Elles ont déjà commencé. <end>',
#  "<start> Laisse-moi m'en charger ! <end>",
#  "<start> Ce n'était qu'un rêve. <end>",
#  "<start> Je t'ai vraiment mal jugé. <end>",
#  '<start> Le pire est déjà passé. <end>',
#  '<start> Avec quoi jouez-vous\xa0? <end>',
#  "<start> Ce n'est plus autorisé. <end>",
#  '<start> Ils étaient soldats. <end>',
#  "<start> C'est idiot\u202f! <end>",
#  "<start> Ça n'a pas de parallèle. <end>",
#  '<start> Maintenant tout va bien. <end>',
#  '<start> Qui étaient-ils exactement\xa0? <end>',
#  '<start> Je vous le prouverai. <end>',
#  "<start> Il ne m'écoute pas. <end>",
#  "<start> J'étais en train d'étudier. <end>",
#  '<start> Appelle un plombier ! <end>',
#  '<start> Comment tout se déroule-t-il ? <end>',
#  '<start> Elles cherchent Tom. <end>',
#  "<start> Tu m'as prise au dépourvu. <end>",
#  '<start> Je ne vais nulle part. <end>',
#  '<start> Tu as des preuves ? <end>',
#  "<start> J'ai des tas d'amis. <end>",
#  '<start> Poursuivons. <end>',
#  "<start> La natation m'intéresse. <end>",
#  "<start> Je veux faire de l'exercice. <end>",
#  "<start> J'ai acheté une montre. <end>",
#  '<start> Pouvez-vous comprendre Tom ? <end>',
#  '<start> Il entendit un bruit. <end>',
#  '<start> Il aime chasser. <end>',
#  '<start> Mon vélo est ici. <end>',
#  '<start> Pourrait-on parler en privé\xa0? <end>',
#  '<start> Quand est-elle née\u202f? <end>',
#  '<start> Donne-le-moi immédiatement. <end>',
#  '<start> Tom détestait ça. <end>',
#  "<start> Je n'étais pas assez compétitive. <end>",
#  '<start> Vous nous avez toutes sauvées. <end>',
#  '<start> Montez dans la voiture ! <end>',
#  '<start> Il ressemble à ton frère. <end>',
#  '<start> Tom est agressif. <end>',
#  '<start> Mes articulations me font mal. <end>',
#  "<start> Personne n'a répondu. <end>",
#  '<start> Il est subitement tombé malade. <end>',
#  '<start> Comment je mange ça\xa0? <end>',
#  '<start> Nous sommes debout. <end>',
#  "<start> Tu n'es pas très amusante. <end>",
#  "<start> Tom est professeur d'histoire. <end>",
#  "<start> J'étais indemne. <end>",
#  "<start> Qu'est-ce ? <end>",
#  '<start> Mon idée était bien meilleure. <end>',
#  '<start> Ils avaient des idées différentes. <end>',
#  "<start> Qu'est-ce que l'art ? <end>",
#  '<start> Nous avons toutes des défauts. <end>',
#  "<start> C'est un bon médecin. <end>",
#  '<start> La nourriture est bonne. <end>',
#  '<start> Nous sommes de retour tôt. <end>',
#  "<start> Disposez-vous d'un passeport ? <end>",
#  '<start> Cela fait toute la différence. <end>',
#  '<start> Cela te rendrait-il heureux ? <end>',
#  "<start> On s'est trop rapprochés. <end>",
#  '<start> La récréation est terminée. <end>',
#  '<start> Ne te déprécie pas. <end>',
#  '<start> Le déjeuner est inclus. <end>',
#  '<start> Le résultat a été décevant. <end>',
#  "<start> Tu n'as pas idée. <end>",
#  "<start> Je n'oublierai jamais cette expérience. <end>",
#  '<start> Sait-il parler anglais\u202f? <end>',
#  '<start> Tout le monde le savait. <end>',
#  '<start> Je n’habite plus ici. <end>',
#  '<start> Nous avons décidé ensemble. <end>',
#  "<start> J'aime beaucoup l'ail. <end>",
#  "<start> J'ai une petite amie. <end>",
#  '<start> Tous les hommes naissent égaux. <end>',
#  "<start> C'est celle-là qu'on veut. <end>",
#  '<start> Je songe à démissionner. <end>',
#  "<start> Le brouillard s'est levé. <end>",
#  "<start> Il a besoin de l'argent. <end>",
#  "<start> C'est malheureux. <end>",
#  "<start> Comment nous sentons-nous, aujourd'hui ? <end>",
#  '<start> Combien devraient-ils obtenir\u202f? <end>',
#  "<start> Ce n'est pas si profond. <end>",
#  '<start> Amenez-moi du café. <end>',
#  "<start> L'ai-je blessé\u202f? <end>",
#  '<start> Faites de votre mieux. <end>',
#  '<start> Cet oiseau déployait ses ailes. <end>',
#  "<start> Je n'ai pas copié. <end>",
#  '<start> Je mets mon pantalon. <end>',
#  '<start> Vous avez une amie canon. <end>',
#  '<start> Montre-moi ta main. <end>',
#  '<start> Mon travail est presque fini. <end>',
#  '<start> Pourrais-tu conduire plus lentement\xa0? <end>',
#  "<start> Ils ont perdu l'esprit. <end>",
#  "<start> C'est vraiment terrible. <end>",
#  '<start> Est-ce sans danger ? <end>',
#  '<start> Tu attends quelque chose\xa0? <end>',
#  '<start> Arrête-moi si tu peux ! <end>',
#  '<start> Tom a résolu le mystère. <end>',
#  '<start> As-tu du papier ? <end>',
#  '<start> Pardon\u202f? <end>',
#  "<start> À quoi s'attendaient-ils\xa0? <end>",
#  '<start> Il a accepté à contrecœur. <end>',
#  '<start> La rumeur était sans fondement. <end>',
#  "<start> Elles l'ont questionné. <end>",
#  '<start> Vous appartient-il ? <end>',
#  '<start> Soyez gentils ! <end>',
#  "<start> Je t'autorise à y aller. <end>",
#  '<start> Ce bâtiment est ancien. <end>',
#  "<start> L'électricité est fort utile. <end>",
#  '<start> Nous sommes simplement nerveux. <end>',
#  '<start> Pouvez-vous battre cela\xa0? <end>',
#  '<start> Tom a éteint ses phares. <end>',
#  "<start> Mon frère a astiqué l'argenterie. <end>",
#  '<start> Vous avez promis. <end>',
#  "<start> Tom est parti pour l'Australie. <end>",
#  '<start> Je dormirai sur le canapé. <end>',
#  '<start> Vous semblez heureux. <end>',
#  '<start> Ce sont de chics types. <end>',
#  '<start> Ta braguette est ouverte ! <end>',
#  "<start> Qu'est-il arrivé au chien\xa0? <end>",
#  '<start> Nous avons tous nos secrets. <end>',
#  '<start> Mary est extrêmement attrayante. <end>',
#  "<start> C'est notre maison. <end>",
#  '<start> Tom prépare le dîner. <end>',
#  "<start> Mais je n'avais pas peur. <end>",
#  "<start> J'y suis entré. <end>",
#  '<start> Les portes sont fermées. <end>',
#  '<start> Quand viendra-t-il\xa0? <end>',
#  "<start> Ce sont d'excellentes nouvelles. <end>",
#  '<start> Essuie ton visage. <end>',
#  '<start> Je sais comment gagner. <end>',
#  '<start> Vous me payez très bien. <end>',
#  "<start> J'ai mal partout. <end>",
#  "<start> C'est un signe. <end>",
#  '<start> Tom était fier de toi. <end>',
#  "<start> Nous venons d'arriver. <end>",
#  '<start> Il vous faut travailler ensemble. <end>',
#  '<start> Partageons la note. <end>',
#  '<start> Je suis le patron. <end>',
#  "<start> J'ai eu une matinée chargée. <end>",
#  '<start> Ce film est classé X. <end>',
#  "<start> C'est ma partie préférée. <end>",
#  '<start> Elle pleurait amèrement. <end>',
#  "<start> Elle a l'air d'une enseignante. <end>",
#  '<start> Est-ce votre chatte ? <end>',
#  '<start> Es-tu suivie\xa0? <end>',
#  '<start> Je sais quoi dire. <end>',
#  '<start> Tom acquiesça rapidement. <end>',
#  '<start> Asseyez-vous, je vous prie. <end>',
#  '<start> Tom arriva à minuit. <end>',
#  '<start> Le fusible a brûlé. <end>',
#  "<start> J'ai eu tort. <end>",
#  '<start> Êtes-vous productifs ? <end>',
#  "<start> J'aime cuisiner. <end>",
#  '<start> Tom est médecin. <end>',
#  '<start> Ne soyez pas aussi bête. <end>',
#  '<start> Il nous a toutes sauvées. <end>',
#  "<start> Elle m'a pris par surprise. <end>",
#  "<start> Ne me demande pas d'argent. <end>",
#  '<start> Je vous écrirai bientôt. <end>',
#  '<start> Vous y voici. <end>',
#  '<start> Je laisse entrer le chat. <end>',
#  '<start> La baleine est un mammifère. <end>',
#  "<start> Garde-le à l'œil ! <end>",
#  "<start> J'adore les défis. <end>",
#  '<start> Un homme doit être honnête. <end>',
#  '<start> Le chômage augmente. <end>',
#  "<start> J'étais très nerveux. <end>",
#  '<start> Nos invités arrivent. <end>',
#  '<start> Je lis souvent. <end>',
#  "<start> Aujourd'hui c'est le premier septembre. <end>",
#  '<start> Je me sens protégée. <end>',
#  '<start> Tu peux y aller. <end>',
#  '<start> Vous rappelez-vous ? <end>',
#  '<start> Elle avait mal partout. <end>',
#  '<start> Pouvons-nous le prouver\xa0? <end>',
#  "<start> Il s'est mordu la lèvre. <end>",
#  '<start> Veuillez me donner la lettre. <end>',
#  "<start> Sa mère l'accompagne toujours. <end>",
#  '<start> Il a cherché la clé. <end>',
#  "<start> C'est laid. <end>",
#  '<start> Pourquoi étiez-vous en prison ? <end>',
#  '<start> As-tu bien dormi ? <end>',
#  "<start> Il dispose d'un joker. <end>",
#  '<start> Bien joué\u202f! <end>',
#  '<start> Tom est milliardaire. <end>',
#  '<start> Sois calme ! <end>',
#  '<start> Elles vivent en-dessous. <end>',
#  '<start> Fais une offre. <end>',
#  '<start> Pourrais-je changer de chambre ? <end>',
#  "<start> L'avez-vous invité ? <end>",
#  '<start> Jouer aux cartes est intéressant. <end>',
#  '<start> Tu parles, Charles. <end>',
#  '<start> Comment le traduiriez-vous\xa0? <end>',
#  "<start> J'ai pris une prune. <end>",
#  '<start> Cela devient pénible. <end>',
#  '<start> Je dois insister. <end>',
#  '<start> Elle vit dans le confort. <end>',
#  "<start> Nous n'aimons pas la pluie. <end>",
#  '<start> Tom est consultant RH. <end>',
#  '<start> Il est trop tôt. <end>',
#  '<start> Qui a commandé ça ? <end>',
#  '<start> Le système a fonctionné. <end>',
#  '<start> L’enfant dort. <end>',
#  '<start> Il souffle une douce brise. <end>',
#  '<start> Vous avez une bonne avocate. <end>',
#  "<start> T'ai-je manqué\u202f? <end>",
#  '<start> Pourquoi Tom le voulait ? <end>',
#  "<start> J'ai un mauvais rhume. <end>",
#  '<start> Comment appellerais-tu ça\xa0? <end>',
#  '<start> Sois gentil. <end>',
#  "<start> Que pouvez-vous m'enseigner ? <end>",
#  '<start> Ils regardent un film. <end>',
#  '<start> Tom, tu devrais voir ceci. <end>',
#  '<start> Ce fut magnifique. <end>',
#  '<start> Je ne démens pas cela. <end>',
#  '<start> Bien fait pour toi. <end>',
#  "<start> Ce n'est pas correct. <end>",
#  "<start> Ce n'est qu'une mode passagère. <end>",
#  '<start> Tu rougis ! <end>',
#  '<start> Comment avez-vous fait\u202f? <end>',
#  "<start> T'as loupé le coche. <end>",
#  '<start> Est-ce naturel ? <end>',
#  '<start> Elles font ça parfois. <end>',
#  "<start> Servez-vous s'il vous plaît. <end>",
#  '<start> Ouvrez la porte ! <end>',
#  "<start> La jauge d'essence est cassée. <end>",
#  "<start> J'étais très fatigué. <end>",
#  '<start> Marions-nous. <end>',
#  '<start> Pourquoi sont-elles si énervées ? <end>',
#  "<start> La canalisation d'eau a explosé. <end>",
#  '<start> Je suis faible. <end>',
#  "<start> Je t'ai appelée. <end>",
#  '<start> La guerre dura deux ans. <end>',
#  "<start> Comment s'est passé l'examen\u202f? <end>",
#  "<start> J'espère que Tom dira non. <end>",
#  '<start> Nous souffrons. <end>',
#  '<start> Tom est mort. <end>',
#  '<start> Ils sont tous semblables. <end>',
#  "<start> Je n'ai aucun ami. <end>",
#  '<start> Nous\xa0avons\xa0été\xa0averties. <end>',
#  '<start> Cet homme est fort. <end>',
#  "<start> C'est une drôle de question. <end>",
#  "<start> Personne n'est venu. <end>",
#  '<start> Quel homme étrange ! <end>',
#  "<start> Aimez-vous les films d'horreur ? <end>",
#  '<start> Faites votre propre travail ! <end>',
#  '<start> Elle parle aussi le français. <end>',
#  "<start> J'adore l'hiver. <end>",
#  '<start> Quand êtes-vous née ? <end>',
#  '<start> Vous êtes le plus vieux. <end>',
#  "<start> C'est à peine croyable. <end>",
#  '<start> On aurait pu faire fortune. <end>',
#  '<start> Je vis en ville. <end>',
#  '<start> Mettez-vous à genoux ! <end>',
#  "<start> Je suis disposé à l'aider. <end>",
#  '<start> Ils ont annulé. <end>',
#  '<start> Elle lui donna un chandail. <end>',
#  "<start> Nous ne pouvons par l'emporter. <end>",
#  '<start> Tom acheta un dictionnaire japonais-chinois. <end>',
#  '<start> Conduis prudemment. <end>',
#  '<start> La longue attente est terminée. <end>',
#  '<start> Vous êtes sauve. <end>',
#  '<start> Veuillez ouvrir la fenêtre ! <end>',
#  '<start> Vous étiez heureux. <end>',
#  '<start> Il est photographe professionnel. <end>',
#  "<start> Vous avez l'air nerveux. <end>",
#  '<start> Elles sont miennes. <end>',
#  "<start> J'y vais maintenant. <end>",
#  "<start> Cela t'a-t-il amusé ? <end>",
#  '<start> Tu es un homme bon. <end>',
#  '<start> Mon père est taciturne. <end>',
#  '<start> Soyez prudente, je vous prie. <end>',
#  '<start> Est-il décédé ? <end>',
#  '<start> Je te déteste. <end>',
#  '<start> Il veut beaucoup cela. <end>',
#  '<start> Elles vont le tenter. <end>',
#  '<start> Votre comportement a été honteux. <end>',
#  '<start> Je suis toubib. <end>',
#  "<start> Elle s'excusa pour son retard. <end>",
#  '<start> On peut toujours essayer. <end>',
#  '<start> Nous avons sympathisé avec eux. <end>',
#  '<start> Pas touche\u202f! <end>',
#  "<start> Il ne s'agit que d'argent. <end>",
#  '<start> La société abandonna ce projet. <end>',
#  "<start> Il s'agit d'une incompréhension. <end>",
#  '<start> Laissez-moi mettre quelque chose. <end>',
#  "<start> Elle l'a fait à nouveau. <end>",
#  '<start> Regarde donc ! <end>',
#  '<start> Fais attention\u202f! <end>',
#  '<start> Nous sommes bourrés. <end>',
#  "<start> Je m’inquiète pour l'avenir. <end>",
#  '<start> Saute. <end>',
#  "<start> Mes enfants aiment l'école. <end>",
#  '<start> On est fauchés. <end>',
#  '<start> Vous avez un brillant avenir. <end>',
#  '<start> Elle vend des légumes. <end>',
#  '<start> Restez éloignés de cela. <end>',
#  '<start> Tom ne peux pas gagner. <end>',
#  '<start> As-tu sommeil ? <end>',
#  '<start> Vous pouvez faire cela. <end>',
#  '<start> Qui veut ça ? <end>',
#  "<start> C'est décevant. <end>",
#  "<start> J'ai besoin de vous sur-le-champ. <end>",
#  "<start> N'êtes-vous toujours pas convaincu ? <end>",
#  '<start> Téléphone-moi demain. <end>',
#  '<start> Pouvez-vous vous renseigner ? <end>',
#  '<start> Que pouvez-vous voir\xa0? <end>',
#  "<start> C'est une honte. <end>",
#  "<start> Je t'arrêterai. <end>",
#  '<start> Il te faut le faire. <end>',
#  '<start> Jouer ici est dangereux. <end>',
#  '<start> Quel toupet\xa0! <end>',
#  '<start> Celles-ci sont probablement les tiennes. <end>',
#  '<start> Nous entretenons une relation. <end>',
#  '<start> Elles sont mauvaises. <end>',
#  "<start> Ce n'était que le début. <end>",
#  '<start> Je ne mange pas ça. <end>',
#  "<start> Il n'est pas à l'intérieur. <end>",
#  '<start> À qui le tour\u202f? <end>',
#  "<start> J'ai entendu la rumeur. <end>",
#  "<start> Je l'ai attrapée. <end>",
#  '<start> Tu es très timide. <end>',
#  '<start> Voulez-vous une autre bière ? <end>',
#  "<start> J'espère qu'il a tort. <end>",
#  "<start> C'était une expérience incroyable. <end>",
#  "<start> N'exagérons pas la situation. <end>",
#  '<start> Combien devraient-ils en obtenir\u202f? <end>',
#  '<start> As-tu réussi ? <end>',
#  "<start> On ne s'est pas embrassés. <end>",
#  '<start> Croyez-vous que je plaisante\u202f? <end>',
#  '<start> Votre collier est beau. <end>',
#  "<start> Il m'a dépassé. <end>",
#  "<start> Tom t'a choisi. <end>",
#  '<start> Je ne crois pas ça. <end>',
#  "<start> Nous avons besoin d'un volontaire. <end>",
#  '<start> Ils ont été occupés. <end>',
#  "<start> Il a échoué à l'examen. <end>",
#  '<start> Comment avance la situation? <end>',
#  '<start> Excusez-moi une minute. <end>',
#  "<start> C'est juste un presse-papier. <end>",
#  '<start> Je veux être remarqué. <end>',
#  "<start> Je n'ai pas d'alibi. <end>",
#  "<start> J'ai raison. <end>",
#  '<start> Ils sont devenus fous. <end>',
#  '<start> Ne bougez pas. <end>',
#  "<start> La circulation est mauvaise aujourd'hui. <end>",
#  "<start> N'importe quoi pouvait arriver. <end>",
#  '<start> Ceci est mon ancien vélo. <end>',
#  '<start> La pauvre fille devint aveugle. <end>',
#  '<start> Nouez votre chaussure. <end>',
#  "<start> Elle l'a immédiatement reconnu. <end>",
#  "<start> S'agit-il d'un fait ? <end>",
#  '<start> Je le fais pour elles. <end>',
#  '<start> Sa fille aînée est mariée. <end>',
#  '<start> Vous êtes insupportable. <end>',
#  '<start> Tom est déjà revenu. <end>',
#  "<start> Je vous ai laissé m'attraper. <end>",
#  '<start> Mettez le chapeau. <end>',
#  '<start> Vous êtes méchant. <end>',
#  '<start> Il lui indiqua le chemin. <end>',
#  '<start> Tu es un survivant. <end>',
#  '<start> Il ne reste aucune nourriture. <end>',
#  '<start> Vous devez garder la forme. <end>',
#  '<start> Je suis extravertie. <end>',
#  "<start> C'est vous l'enseignant. <end>",
#  '<start> Il a le torse poilu. <end>',
#  "<start> Tu es vraiment tête-en-l'air. <end>",
#  '<start> Il ne me battra jamais. <end>',
#  '<start> Tom est parti. <end>',
#  "<start> J'ai perdu mes lunettes. <end>",
#  "<start> Vous n'avez jamais abandonné. <end>",
#  '<start> Laisse-moi y réfléchir. <end>',
#  "<start> Je n'ai tiré sur personne. <end>",
#  '<start> Êtes-vous golfeuse ? <end>',
#  '<start> Le bus était presque vide. <end>',
#  '<start> Vous réagissez de manière excessive. <end>',
#  '<start> Ses cheveux deviennent gris. <end>',
#  '<start> Nous avons sympathisé avec elles. <end>',
#  '<start> Lâchez-moi ! <end>',
#  '<start> Tu es cernée. <end>',
#  '<start> Pouvez-vous préparer une salade\u202f? <end>',
#  '<start> Avez-vous des crayons\u202f? <end>',
#  "<start> J'apprécie un défi. <end>",
#  '<start> Est-ce clair ? <end>',
#  '<start> Je tins ma langue. <end>',
#  '<start> Elle a abandonné ses enfants. <end>',
#  '<start> Qui est au régime ? <end>',
#  '<start> Leur rencontre était inévitable. <end>',
#  '<start> Je reste. <end>',
#  "<start> N'essaie pas de me duper. <end>",
#  '<start> Tous les fauteuils sont réservés. <end>',
#  "<start> Je l'ai vu nu. <end>",
#  '<start> Vous êtes un prisonnier. <end>',
#  "<start> Vous n'êtes pas seules. <end>",
#  '<start> Écris de la main gauche. <end>',
#  '<start> Vous avez grandi, Tom. <end>',
#  '<start> Honte à toi\u202f! <end>',
#  "<start> Il a l'air fatigué. <end>",
#  "<start> C'est assez bonnard, en vérité. <end>",
#  "<start> J'ai entendu la bonne nouvelle. <end>",
#  '<start> Était-ce votre idée\u202f? <end>',
#  "<start> C'est trop. <end>",
#  '<start> Il est juste derrière toi. <end>',
#  "<start> J'aime la musique classique. <end>",
#  '<start> Elles ont refusé. <end>',
#  '<start> Elle est tombée enceinte. <end>',
#  "<start> L'alarme-incendie sonna. <end>",
#  '<start> Vous avez bu ? <end>',
#  '<start> Tom semble être objectif. <end>',
#  '<start> Êtes-vous inscrits ? <end>',
#  "<start> C'est une suggestion constructive ! <end>",
#  '<start> Ce chapeau est à moi. <end>',
#  "<start> Vous n'êtes pas si intéressants. <end>",
#  "<start> C'était long. <end>",
#  "<start> Vous n'êtes pas un lâche. <end>",
#  '<start> Je tiens toujours parole. <end>',
#  '<start> Nous pouvons parler dehors. <end>',
#  "<start> Il reste peu d'eau. <end>",
#  '<start> Elles veulent ceci. <end>',
#  '<start> Fiça ! <end>',
#  '<start> Il céda. <end>',
#  '<start> Suis-moi. <end>',
#  '<start> Nous travaillions ensemble. <end>',
#  '<start> Les avez-vous ? <end>',
#  "<start> N'allumez pas la bougie ! <end>",
#  '<start> Je suis sincère. <end>',
#  "<start> T'es une chouette gonzesse. <end>",
#  "<start> C'était vraiment trop cher. <end>",
#  "<start> C'était moi la responsable. <end>",
#  '<start> Reste juste là ! <end>',
#  '<start> Qui parle\xa0? <end>',
#  '<start> Je peux le faire. <end>',
#  "<start> Qu'est-ce qui cause ça\xa0? <end>",
#  "<start> Il n'y avait pas d'emploi. <end>",
#  '<start> Surveilles-tu ton poids ? <end>',
#  '<start> Conséquemment, les prix ont augmenté. <end>',
#  '<start> Rattrape-le. <end>',
#  '<start> Où est votre argent ? <end>',
#  '<start> Ça serait parfait. <end>',
#  '<start> Pouvez-vous éclairer le chemin ? <end>',
#  '<start> Personne ne goûte ton humour. <end>',
#  '<start> Frappe à la porte ! <end>',
#  '<start> Veuillez nous facturer séparément. <end>',
#  '<start> Elle a amèrement pleuré. <end>',
#  '<start> Ils se sourirent. <end>',
#  "<start> C'est l'étape logique suivante. <end>",
#  '<start> Personne ne le fait. <end>',
#  '<start> Je fais trop la fête. <end>',
#  "<start> J'ai regardé dans le placard. <end>",
#  '<start> Prépare-toi à baiser. <end>',
#  '<start> Ma femme est végétarienne. <end>',
#  '<start> Mets-le sur le mur. <end>',
#  '<start> Les temps changent. <end>',
#  '<start> Aucun canadien ne fut blessé. <end>',
#  '<start> Ce cas est important. <end>',
#  '<start> Tu es très effrontée. <end>',
#  "<start> J'ai mal au genou. <end>",
#  '<start> Il est sexy. <end>',
#  '<start> La femme est nue. <end>',
#  '<start> Vous êtes très peureux. <end>',
#  '<start> Elle dort avec deux oreillers. <end>',
#  "<start> J'étais là en premier. <end>",
#  '<start> Thomas est un bon vivant. <end>',
#  '<start> Elle fit pousser des roses. <end>',
#  '<start> Mes enfants sont adultes maintenant. <end>',
#  "<start> J'ai laissé tomber l'équipe. <end>",
#  "<start> Pas de quoi s'inquiéter. <end>",
#  "<start> J'arrangerai ça. <end>",
#  "<start> Comment vous sentez-vous, aujourd'hui ? <end>",
#  '<start> As-tu assez dormi ? <end>',
#  '<start> Thomas est devenu catholique. <end>',
#  '<start> Tu es fort effronté. <end>',
#  "<start> Quelqu'un est-il là ? <end>",
#  '<start> Nous avons affrété un car. <end>',
#  '<start> Nous devons faire ceci. <end>',
#  "<start> Comme c'est excitant ! <end>",
#  '<start> Tom adore Marie. <end>',
#  '<start> Il était comptable. <end>',
#  '<start> Où est la police\xa0? <end>',
#  '<start> Attrapez Tom. <end>',
#  '<start> Vous êtes fort élégant. <end>',
#  "<start> C'était extrêmement simple. <end>",
#  '<start> Elle est agressive. <end>',
#  '<start> Je veux que tu parles. <end>',
#  "<start> J'ai reconsidéré la question. <end>",
#  '<start> Mon beau-père était diabétique. <end>',
#  '<start> Où sont les fourchettes ? <end>',
#  '<start> Il plaisante toujours. <end>',
#  "<start> C'est bien peu dire. <end>",
#  '<start> Je possède cette voiture. <end>',
#  '<start> Tom déteste le sport. <end>',
#  '<start> Elle a aimé ça. <end>',
#  '<start> Attrapez mon fusil ! <end>',
#  '<start> Ton opinion est sans importance. <end>',
#  '<start> Heureusement, le temps était beau. <end>',
#  '<start> Tout le monde le fait. <end>',
#  '<start> Il a la mâchoire carrée. <end>',
#  '<start> Que voulez-vous dire\u202f? <end>',
#  '<start> Sont-ils contents ? <end>',
#  '<start> Quels sont les symptômes\u202f? <end>',
#  '<start> Il était outré. <end>',
#  '<start> Je veux de nombreuses choses. <end>',
#  "<start> Les banques sont fermées, aujourd'hui. <end>",
#  "<start> J'ai peur de voler. <end>",
#  "<start> Quand arrêteras-tu d'intriguer ? <end>",
#  '<start> Nous aimons Tom. <end>',
#  '<start> En voudrais-tu une ? <end>',
#  '<start> Puis-je changer de chaîne ? <end>',
#  "<start> Aucune enquête n'est requise. <end>",
#  "<start> Ce n'était pas mon intention. <end>",
#  '<start> Ceci est pour mon amie. <end>',
#  "<start> Je viens d'avoir un boulot. <end>",
#  "<start> Les gens tape-à-l'œil l'irritent. <end>",
#  "<start> Où t'es-tu rendu, exactement ? <end>",
#  "<start> Je te laisse t'en occuper. <end>",
#  '<start> Nous serons heureux de coopérer. <end>',
#  '<start> Tu veux une voiture ? <end>',
#  '<start> Vous êtes arrogants. <end>',
#  '<start> Elle a visé la cible. <end>',
#  '<start> Vous avez une bonne mémoire. <end>',
#  '<start> Prenez tout. <end>',
#  '<start> Ramène-moi mon chapeau. <end>',
#  "<start> Personne n'a rien vu. <end>",
#  '<start> Tom plaisante tout le temps. <end>',
#  "<start> J'ai pleuré toute la matinée. <end>",
#  '<start> Cette lampe-torche faiblit. <end>',
#  '<start> Je sais où elle est. <end>',
#  "<start> Je n'ai rien fait d'illégal. <end>",
#  "<start> S'il te plaît, calme-toi. <end>",
#  '<start> Il se trompe complètement. <end>',
#  "<start> Il s'agit d'une rumeur. <end>",
#  "<start> C'est un beau travail. <end>",
#  "<start> J'irai, de toutes façons. <end>",
#  "<start> Qu'avez-vous dit à l'instant ? <end>",
#  '<start> Les chambres sont désertes. <end>',
#  '<start> Comment allez-vous tous ? <end>',
#  "<start> Qu'est-ce qui te préoccupe ? <end>",
#  '<start> Êtes-vous blessés ? <end>',
#  "<start> Je n'emploie jamais plus ceci. <end>",
#  "<start> J'ai préparé le petit-déjeuner. <end>",
#  "<start> J'ai appris quelque chose aujourd'hui. <end>",
#  '<start> Voulez-vous avoir des enfants\xa0? <end>',
#  "<start> Vous êtes tiré d'affaire. <end>",
#  "<start> N'en perds pas le sommeil. <end>",
#  '<start> Du café, je vous prie. <end>',
#  '<start> Ne triche pas. <end>',
#  '<start> Vous êtes incroyablement talentueux. <end>',
#  '<start> Je sais skier. <end>',
#  '<start> Nous mentons tous. <end>',
#  '<start> Il a une personnalité intrigante. <end>',
#  "<start> Elle l'embrassa. <end>",
#  '<start> Ça goûtait sucré. <end>',
#  '<start> Voici ton chien. <end>',
#  '<start> Vous êtes très craintives. <end>',
#  "<start> Ça m'est arrivé. <end>",
#  '<start> Tom ne me dérange pas. <end>',
#  '<start> Repose-toi. <end>',
#  "<start> L'époux de Marie la maltraitait. <end>",
#  '<start> Nous nous entraînons ensemble. <end>',
#  "<start> Tout le monde s'amuse. <end>",
#  '<start> Je pourrais intervenir. <end>',
#  '<start> Ça semble fort tentant. <end>',
#  '<start> Je ne suis pas fou. <end>',
#  '<start> Je cours tous les matins. <end>',
#  "<start> C'est faux. <end>",
#  "<start> C'est vraiment énervant. <end>",
#  "<start> Qu'as-tu dit ? <end>",
#  '<start> Achète bas, vends haut ! <end>',
#  '<start> Demandons à un voyagiste. <end>',
#  '<start> Il fallait avoir les tripes. <end>',
#  '<start> Je vais mener la discussion. <end>',
#  '<start> Je veux cette veste bleue. <end>',
#  '<start> Je peux me débrouiller. <end>',
#  '<start> Pourquoi as-tu été renvoyé\xa0? <end>',
#  "<start> Quelqu'un vous attend. <end>",
#  '<start> Je resterai ici. <end>',
#  '<start> Ma mère était furieuse. <end>',
#  '<start> Elles étaient occupées. <end>',
#  '<start> Étiez-vous vraiment énervée ? <end>',
#  "<start> Ce n'est pas notre problème. <end>",
#  '<start> Puis-je vous parler ? <end>',
#  '<start> Donne-moi un peu de lait. <end>',
#  '<start> Hier était une bonne journée. <end>',
#  '<start> Fais ton propre travail ! <end>',
#  '<start> Nous le ferons ensemble. <end>',
#  '<start> Il cite souvent Shakespeare. <end>',
#  '<start> Ne méprise pas les autres. <end>',
#  "<start> C'est une histoire vraie. <end>",
#  '<start> Il a plu depuis hier. <end>',
#  "<start> Aucun argent n'a été volé. <end>",
#  "<start> C'est notre maison. <end>",
#  '<start> Ça ne se produit pas. <end>',
#  '<start> Nous sommes intelligentes. <end>',
#  "<start> Il décida d'arrêter de fumer. <end>",
#  '<start> Ça se passe très bien. <end>',
#  '<start> Je ne te décevrai jamais. <end>',
#  '<start> Je suis désorganisée. <end>',
#  '<start> Celui-ci est vraiment bien. <end>',
#  '<start> Vous êtes très courageuse. <end>',
#  '<start> Elle lui serra la main. <end>',
#  '<start> Avez-vous même été tentés ? <end>',
#  '<start> Lis-la-moi ! <end>',
#  '<start> Laisse-moi y faire ! <end>',
#  "<start> T'es remonté. <end>",
#  '<start> Nous avons raté notre chance. <end>',
#  '<start> Nous vous avons vus. <end>',
#  '<start> Ne dites cela à personne. <end>',
#  '<start> Mary est une mère célibataire. <end>',
#  "<start> Tom n'a pas quitté Mary. <end>",
#  "<start> J'ai besoin de votre aide. <end>",
#  "<start> L'eau est-elle profonde ? <end>",
#  '<start> Qui vous a embrassée ? <end>',
#  '<start> Venez immédiatement ! <end>',
#  '<start> Il y eut trente survivants. <end>',
#  '<start> Sont-ce là vos filles ? <end>',
#  '<start> Il est un peu éméché. <end>',
#  "<start> C'est ainsi qu'il en allait. <end>",
#  "<start> Avez-vous assez d'énergie ? <end>",
#  '<start> Tout a un prix. <end>',
#  '<start> De quoi vous parlez\xa0? <end>',
#  '<start> Quelque chose se produit-il ? <end>',
#  '<start> Es-tu détendue ? <end>',
#  '<start> Ils relâchèrent la prisonnière. <end>',
#  "<start> Tout le monde l'aime. <end>",
#  "<start> J'aimerais quelques pommes de terre. <end>",
#  '<start> Je risquai tout. <end>',
#  '<start> Je suis mécontente. <end>',
#  '<start> Je dispose de temps. <end>',
#  "<start> J'allumai la chandelle. <end>",
#  '<start> Qui est aux commandes ? <end>',
#  '<start> Cet ordinateur ne fonctionne pas. <end>',
#  '<start> De quoi avez-vous besoin ? <end>',
#  '<start> Le panier était vide. <end>',
#  "<start> Je ne m'en vais pas. <end>",
#  '<start> Où est le téléphone\xa0? <end>',
#  '<start> Je me sens tellement impuissante. <end>',
#  "<start> J'ai cessé de fumer. <end>",
#  "<start> J'ai eu les foies. <end>",
#  '<start> Vous êtes fiables. <end>',
#  '<start> Pourquoi es-tu si inquiet ? <end>',
#  '<start> Des chiens aboient. <end>',
#  '<start> Reste dans le coup. <end>',
#  '<start> Ils nous ont demandé conseil. <end>',
#  "<start> C'est l'une des miennes. <end>",
#  "<start> J'ai pris une décision. <end>",
#  "<start> C'est juste une solution temporaire. <end>",
#  "<start> J'y étais heureuse. <end>",
#  "<start> Vous n'êtes pas ma mère. <end>",
#  '<start> Personne ne peut vous aider. <end>',
#  "<start> C'est un excellent vin. <end>",
#  '<start> Vous ai-je blessés ? <end>',
#  "<start> Nous partons d'ici. <end>",
#  '<start> Le penses-tu réellement\u202f? <end>',
#  '<start> Ne me taquinez pas ! <end>',
#  "<start> T'ai-je fait mal ? <end>",
#  "<start> J'ai déjà pris un café. <end>",
#  '<start> Je suis étudiant. <end>',
#  '<start> Je serai gentille. <end>',
#  '<start> Tom aime vraiment son pays. <end>',
#  '<start> Vous appréciez tout le monde. <end>',
#  '<start> Sont-ils morts\u202f? <end>',
#  "<start> Votre français s'améliore. <end>",
#  '<start> Ça arrivera. <end>',
#  "<start> Ils disposent d'un lit supplémentaire. <end>",
#  "<start> C'est ma bicyclette. <end>",
#  "<start> J'étudie l'histoire japonaise. <end>",
#  '<start> Cette rue est très bruyante. <end>',
#  '<start> Je me sens vraiment fier. <end>',
#  "<start> J'ai confiance en toi. <end>",
#  '<start> Tom vous aime toutes. <end>',
#  '<start> Il a les yeux marron. <end>',
#  '<start> Je les ai toutes. <end>',
#  "<start> Je n'ai rien écrit. <end>",
#  '<start> Ils auraient dû me remarquer. <end>',
#  '<start> Personne ne nous croira. <end>',
#  '<start> Elle a crié. <end>',
#  "<start> J'ai beaucoup raté. <end>",
#  '<start> Sauve-toi ! <end>',
#  "<start> Vous avez l'air japonais. <end>",
#  '<start> Je le vis nu. <end>',
#  "<start> J'attendrai ici. <end>",
#  "<start> Tom n'a jamais dit non. <end>",
#  '<start> Puis-je voir ça ? <end>',
#  "<start> J'ai quitté la pièce. <end>",
#  "<start> C'est très impressionnant. <end>",
#  "<start> C'est extrêmement dur. <end>",
#  '<start> Tom et Mary étaient effrayés. <end>',
#  '<start> Rends-moi heureuse. <end>',
#  '<start> Elle est trop bruyante. <end>',
#  '<start> Un cheval est un animal. <end>',
#  '<start> Aimez-vous chanter\u202f? <end>',
#  '<start> Pourquoi es-tu si têtu? <end>',
#  '<start> Ouvre les fenêtres ! <end>',
#  '<start> Est-ce normal ? <end>',
#  '<start> Je dois la peindre. <end>',
#  "<start> Je l'ai réparée. <end>",
#  "<start> J'ai effectivement une question. <end>",
#  '<start> Je veux entendre ça. <end>',
#  "<start> Je t'entends toujours. <end>",
#  "<start> J'étais très choqué. <end>",
#  "<start> Il m'a flouée. <end>",
#  "<start> Je ne m'y rends pas. <end>",
#  "<start> L'oratrice est jeune. <end>",
#  '<start> Je suis claustrophobe. <end>',
#  "<start> C'était incroyablement dangereux. <end>",
#  '<start> Ils jouaient au tennis. <end>',
#  '<start> Ils ont déjà commencé. <end>',
#  '<start> Tom avait raison après tout. <end>',
#  '<start> Je vais chez ma sœur. <end>',
#  "<start> L'expérience échoua. <end>",
#  '<start> Il a manqué la classe. <end>',
#  "<start> C'est une situation très difficile. <end>",
#  "<start> J'ai trop faim pour étudier. <end>",
#  '<start> Vous aimez le poisson? <end>',
#  '<start> Éloigne-toi de moi ! <end>',
#  "<start> Tom vient d'avouer. <end>",
#  '<start> Quel navigateur utilises-tu\u202f? <end>',
#  '<start> À demain matin ! <end>',
#  '<start> Thomas travaille trop. <end>',
#  '<start> Les défis sont énormes. <end>',
#  "<start> C'est ennuyeux. <end>",
#  '<start> Hasarde une hypothèse ! <end>',
#  "<start> J'ai besoin de temps. <end>",
#  '<start> Il pleut depuis lundi. <end>',
#  '<start> Je me sentis apeurée. <end>',
#  '<start> Il a été emprisonné. <end>',
#  '<start> Nous comptons tout. <end>',
#  '<start> Elle détourna les yeux, terrifiée. <end>',
#  '<start> Écoute ta mère ! <end>',
#  '<start> Tom est devenu faible. <end>',
#  "<start> J'ai oublié mon porte-monnaie. <end>",
#  "<start> Je n'ai pas encore faim. <end>",
#  '<start> Il a relu mon manuscrit. <end>',
#  "<start> J'étais dégoûté. <end>",
#  '<start> Ça me gratte de partout. <end>',
#  '<start> Vous avez une heure. <end>',
#  '<start> Ma porte est toujours ouverte. <end>',
#  '<start> Je conduirai Tom chez lui. <end>',
#  "<start> Elles n'y arrivent pas. <end>",
#  '<start> Il semble penser cela. <end>',
#  '<start> Vous êtes fort compréhensif. <end>',
#  "<start> Je n'aime pas les enfants. <end>",
#  "<start> Tu n'as pas l'air Japonais. <end>",
#  "<start> Tu t'exprimes bien. <end>",
#  '<start> Vos mains sont-elles propres\u202f? <end>',
#  '<start> Il semblait vraiment nerveux. <end>',
#  '<start> Comment puis-je vous aider ? <end>',
#  '<start> Nous restons. <end>',
#  '<start> Tu as foiré, Tom. <end>',
#  "<start> Ce n'est plus mon problème. <end>",
#  ...]

# %% [markdown]
# ##  Text Preprocessing

# %%
# Tokenizating and padding input language
[]
fre_token = Tokenizer(filters="",lower=False)
fre_token.fit_on_texts(frence_train)

fre_tokenized = fre_token.texts_to_sequences(frence_train)
fre_padded = pad_sequences(fre_tokenized,padding="post")


# Tokenizating and padding output language:
eng_token = Tokenizer(filters="",lower=False)
eng_token.fit_on_texts(english_train)

eng_tokenized = eng_token.texts_to_sequences(english_train)
eng_padded = pad_sequences(eng_tokenized,padding="post")

# %%
# number of a  unique tokens   in input  adn output language:
num_op_token  = len(fre_token.word_index)
num_in_token = len(eng_token.word_index)


#maximum length of a sentence  inn both language:
max_len_op = fre_padded.shape[1]  # french
max_len_ip = eng_padded.shape[1]  #enlgish

# %%
frence_train[0]
# Out:
# "<start> Rien ne l'arrêtera. <end>"

# %%
num_op_token
# Out:
# 17268

# %%
num_in_token
# Out:
# 10480

# %%
max_len_ip
# Out:
# 7

# %%
max_len_op
# Out:
# 7

# %%
fre_padded[0]
# Out:
# array([   1,  396,   18, 8053,    2,    0,    0])

# %%
frence_train[0]
# Out:
# "<start> Rien ne l'arrêtera. <end>"

# %%
english_train[0]
# Out:
# '<start> Nothing will stop his going. <end>'

# %%
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# Define the parameters for TextVectorization
max_words = 11148
max_sequence_length = 7

# Initialize TextVectorization layer
english_pp = TextVectorization(max_tokens=max_words, output_sequence_length=max_sequence_length)

# Fit the TextVectorization layer on your training data
english_pp.adapt(english_train)

# Transform your training data using the fitted TextVectorization layer
english_train_vecs = english_pp(english_train)

# %%
english_train_vecs
# Out:
# <tf.Tensor: shape=(34695, 7), dtype=int64, numpy=
# array([[   2,  200,   53, ...,   48,   79,    3],
#        [   2,   26,   82, ...,    0,    0,    0],
#        [   2,    4, 1652, ..., 2526,    3,    0],
#        ...,
#        [   2,   16,  304, ...,    5,    3,    0],
#        [   2,   19,    6, ...,    3,    0,    0],
#        [   2,   15,   17, ...,    6, 1091,    3]], dtype=int64)>

# %%
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

# Define the parameters for TextVectorization
max_words = 18825
max_sequence_length = 7

# Initialize TextVectorization layer with append_indicator and padding options
french_pp = TextVectorization(
    max_tokens=max_words,
    output_sequence_length=max_sequence_length,
    output_mode='int',  # You may adjust the output_mode as needed
    pad_to_max_tokens=True,  # You may adjust the pad_value as needed
)

# Fit the TextVectorization layer on your training data
french_pp.adapt(frence_train)

# Transform your training data using the fitted TextVectorization layer
french_train_vec = french_pp(frence_train)

# %%
french_train_vec
# Out:
# <tf.Tensor: shape=(34695, 7), dtype=int64, numpy=
# array([[   2,   76,   15, ...,    3,    0,    0],
#        [   2,   12,  132, ...,    0,    0,    0],
#        [   2,   17, 1846, ...,    3,    0,    0],
#        ...,
#        [   2,  183,  113, ...,   13,    6,    3],
#        [   2,  264,   19, ...,    3,    0,    0],
#        [   2,   68,   16, ..., 1204,    3,    0]], dtype=int64)>

# %%
import dill as dpickle
import pickle

# %%
# pip install dill

# %%
# Define a filename for your model
model_filename = "english_pp.dpkl.pkl"

# Use pickle to save the model to a file
with open(model_filename, 'wb') as file:
    pickle.dump(english_pp, file)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Input In [53], in <cell line: 5>()
#       4 # Use pickle to save the model to a file
#       5 with open(model_filename, 'wb') as file:
# ----> 6     pickle.dump(english_pp, file)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1085, in _EagerTensorBase.__reduce__(self)
#    1084 def __reduce__(self):
# -> 1085   return convert_to_tensor, (self._numpy(),)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py:1128, in _EagerTensorBase._numpy(self)
#    1126   return self._numpy_internal()
#    1127 except core._NotOkStatusException as e:  # pylint: disable=protected-access
# -> 1128   raise core._status_to_exception(e) from None
#
# InvalidArgumentError: Cannot convert a Tensor of dtype resource to a NumPy array.

# %%
    
# Define a filename for your model
model_filename = "french_pp.dpkl"

# Use pickle to save the model to a file
with open(model_filename, 'wb') as file:
    pickle.dump(french_pp, file)

# %%
# # save the preprossec:
with open("english_pp.dpkl","wb") 
    dpickle.dump(english_pp,f)
    
with open("french_pp.dpkl","wb") 
    dpickle.dump(french_pp,f)
    
    
#save the processed data:
np.save("French_train_vecs.npy",french_train_vec)
np.save("English_train_vecs.npy", english_train_vecs)

# %%
def load_decoder_inputs(decoder_np_vecs="French_train_vecs.npy"):
    vectorized_title = np.load(decoder_np_vecs)
    
    decoder_input_data = vectorized_title[:,:-1]
    
    decoder_target_data = vectorized_title[:,1:]
    
    print(f'Shape of decoder input:{decoder_input_data.shape}')
    print(f'Shape of the decoder target: {decoder_target_data}')
    return decoder_input_data , decoder_target_data
          
def load_encoder_input(encoder_np_vecs = "English_train_vecs.npy"):
    vectorized_body = np.load(encoder_np_vecs)
          
    encoder_input_data = vectorized_body
    doc_length = encoder_input_data.shape[1]
    print(f"Shape of the encoder input: {encoder_input_data.shape}")
    return encoder_input_data , doc_length

# %%
def load_text_processor()
